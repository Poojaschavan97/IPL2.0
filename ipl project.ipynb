# %% [markdown]
# # while attaching this code to the project convert loads and dumps into jsonify

# %%
#importing essential librabries

# data gathering,cleaning and analysis libraries
import pandas as pd
import numpy as np
# for converting datatype to json for API
import json

# %% [markdown]
# `Column` | Description
# :-|:-
# `match_id` |	Unique identifier for each match, used to link with match details.
# `inning`|	Indicates the innings (1 or 2) in the match.
# `batting_team`|Name of the team batting in the given inning.
# `bowling_team`|	Name of the team bowling in the given inning.
# `over`|	The over number in the current inning (e.g., 1, 2, ..., 20).
# `ball`|	The ball number within the over (1 to 6).
# `batter`|	Name of the player currently batting.
# `bowler`	|Name of the player currently bowling.
# `non_striker`|	Name of the non-striker at the other end of the pitch.
# `batsman_runs`|	Number of runs scored```` by the batsman on the current delivery (can include 0 for dot balls or 4/6 for boundaries).
# `extra_runs`	|Number of extra runs (such as no-balls, wides) on this delivery.
# `total_runs`	|Total runs scored on this ball (sum of batsman runs and extra runs).
# `extras_type`	|Type of extra run, if applicable (e.g., wide, no-ball, bye, legbye).
# `is_wicket`	|Indicates if the delivery resulted in a wicket (1 for wicket, 0 for no wicket).
# `player_dismissed`|	Name of the player dismissed on the ball (if applicable, otherwise null).
# `dismissal_kind`	|Type of dismissal (e.g., bowled, caught, run out, LBW).
# `fielder`	|Name of the fielder involved in the dismissal (for dismissals like catch, run out, etc.; null for dismissals not involving a fielder).

# %%
# Gathering IPL data from 2008-2024
ipl1=pd.read_csv(r"C:\Users\pooja\Downloads\archive (9)\deliveries.csv")
ipl1.sample(5)
# Out:
#         match_id  inning                 batting_team  \
# 226886   1359478       2          Sunrisers Hyderabad
# 27031     392239       2  Royal Challengers Bangalore
# 22343     392220       2             Rajasthan Royals
# 93304     598068       2          Chennai Super Kings
# 51673     501241       1               Mumbai Indians
#
#                        bowling_team  over  ball       batter         bowler  \
# 226886             Rajasthan Royals    14     6      B Kumar        KM Asif
# 27031               Deccan Chargers     9     3  LRPL Taylor  Harmeet Singh
# 22343               Deccan Chargers     2     5  SA Asnodkar       RP Singh
# 93304   Royal Challengers Bangalore     2     7      M Vijay     JD Unadkat
# 51673                 Pune Warriors    14     4   KA Pollard       R Sharma
#
#           non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 226886    Abdul Samad             1           0           1         NaN
# 27031        R Dravid             4           0           4         NaN
# 22343   LA Carseldine             4           0           4         NaN
# 93304        DJ Bravo             4           0           4         NaN
# 51673        TL Suman             0           0           0         NaN
#
#         is_wicket player_dismissed dismissal_kind fielder
# 226886          0              NaN            NaN     NaN
# 27031           0              NaN            NaN     NaN
# 22343           0              NaN            NaN     NaN
# 93304           0              NaN            NaN     NaN
# 51673           0              NaN            NaN     NaN

# %% [markdown]
# `Column`	|Description
# :-|:-
# `id`	|Unique identifier for each match, similar to match_id in the ball-by-ball dataset, useful for linking datasets.
# `season`|	Year in which the IPL season took place.
# `city`	|City where the match was played.
# `date`	|Date of the match.
# `match_type`|	Type of match (could indicate regular season, playoff, or final).
# `player_of_match`|	Name of the player awarded "Player of the Match."
# `venue`|	Stadium where the match was played.
# `team1`	|Name of the first team (order doesn’t imply batting or bowling first).
# `team2`	|Name of the second team.
# `toss_winner`|	Team that won the toss.
# `toss_decision`|	Decision taken by the toss-winning team (bat or field).
# `winner`|Name of the team that won the match.
# `result`|	Outcome type of the match (e.g., normal, tie, no result).
# `result_margin`|	Margin by which the team won (e.g., runs or wickets).
# `target_runs`	|Target runs set for the chasing team (null if not applicable).
# `target_overs`	|Target overs if the match is shortened (e.g., in rain-affected matches; null if not applicable).
# `super_over`	|Indicates if the match had a super over (1 for yes, 0 for no).
# `method`	|Method used to determine the result in rain-affected games (e.g., Duckworth-Lewis-Stern, or null if not applicable).
# `umpire1`	|Name of the first on-field umpire.
# `umpire2`	|Name of the second on-field umpire.

# %%
ipl2=pd.read_csv(r"C:\Users\pooja\Downloads\archive (9)\matches.csv")
ipl2.sample(5)
# Out:
#           id   season        city        date match_type  player_of_match  \
# 766  1216532  2020/21   Abu Dhabi  2020-09-29     League      Rashid Khan
# 262   548320     2012     Kolkata  2012-04-13     League  Shakib Al Hasan
# 858  1254103     2021       Dubai  2021-09-29     League        YS Chahal
# 877  1304048     2022      Mumbai  2022-03-27     League    Kuldeep Yadav
# 13    335995  2007/08  Chandigarh  2008-04-27     League        SM Katich
#
#                                           venue                  team1  \
# 766                        Sheikh Zayed Stadium    Sunrisers Hyderabad
# 262                                Eden Gardens  Kolkata Knight Riders
# 858         Dubai International Cricket Stadium       Rajasthan Royals
# 877                   Brabourne Stadium, Mumbai         Mumbai Indians
# 13   Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# 766               Delhi Capitals               Delhi Capitals         field
# 262             Rajasthan Royals             Rajasthan Royals           bat
# 858  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 877               Delhi Capitals               Delhi Capitals         field
# 13              Delhi Daredevils             Delhi Daredevils           bat
#
#                           winner   result  result_margin  target_runs  \
# 766          Sunrisers Hyderabad     runs           15.0        163.0
# 262        Kolkata Knight Riders  wickets            5.0        132.0
# 858  Royal Challengers Bangalore  wickets            7.0        150.0
# 877               Delhi Capitals  wickets            4.0        178.0
# 13               Kings XI Punjab  wickets            4.0        159.0
#
#      target_overs super_over method      umpire1                umpire2
# 766          20.0          N    NaN    VK Sharma                 S Ravi
# 262          20.0          N    NaN    Asad Rauf               S Asnani
# 858          20.0          N    NaN  AY Dandekar  KN Ananthapadmanabhan
# 877          20.0          N    NaN    RJ Tucker             HAS Khalid
# 13           20.0          N    NaN  RE Koertzen              I Shivram

# %% [markdown]
# #### cleaning data

# %% [markdown]
# changing repeating names to one

# %%
def change_name(team_name):
    if team_name== 'Rising Pune Supergiants':
        return 'Rising Pune Supergiant'
    elif team_name=='Royal Challengers Bengaluru':
        return 'Royal Challengers Bangalore'
    else:
        return team_name

# %%
# appling changed team names to the dat set
ipl2['team1']=ipl2['team1'].apply(change_name)
ipl2['team2']=ipl2['team2'].apply(change_name)
ipl1['batting_team']=ipl1['batting_team'].apply(change_name)
ipl1['bowling_team']=ipl1['bowling_team'].apply(change_name)

# %% [markdown]
# to convert into only seasons

# %%
# since season column has year and sometimes month too
ipl2['season'] = ipl2['season'].astype(str).str[:4]

# %%
ipl2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %% [markdown]
# - here date is in object form we have to convert it to datetime

# %%
ipl2['date']=pd.to_datetime(ipl2['date'])
ipl2['season']=ipl2['date'].dt.year

# %%
# ipl2['season']=ipl2['season'].astype(int)

# %%
ipl2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   int32
#  2   city             1095 non-null   object
#  3   date             1095 non-null   datetime64[ns]
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(14)
# memory usage: 166.9+ KB

# %% [markdown]
# - for my convinience i repeatedly am using season column so in ipl1 i added new column named season

# %%
ipl1['season'] = ipl1['match_id'].map(ipl2.set_index('id')['season']).astype(int)

# %%
ipl1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
#  17  season            260920 non-null  int32
# dtypes: int32(1), int64(8), object(9)
# memory usage: 34.8+ MB

# %%
# Mapping dictionary for cleaning
venue_mapping = {
    'M Chinnaswamy Stadium, Bengaluru': 'M Chinnaswamy Stadium',
    'M.Chinnaswamy Stadium': 'M Chinnaswamy Stadium',
    'Punjab Cricket Association Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh': 'Punjab Cricket Association IS Bindra Stadium',
    'MA Chidambaram Stadium, Chepauk': 'MA Chidambaram Stadium',
    'MA Chidambaram Stadium, Chepauk, Chennai': 'MA Chidambaram Stadium',
    'Wankhede Stadium, Mumbai': 'Wankhede Stadium',
    'Arun Jaitley Stadium, Delhi': 'Arun Jaitley Stadium',
    'Eden Gardens, Kolkata': 'Eden Gardens',
    'Rajiv Gandhi International Stadium, Uppal': 'Rajiv Gandhi International Stadium',
    'Rajiv Gandhi International Stadium, Uppal, Hyderabad': 'Rajiv Gandhi International Stadium',
    'Dr DY Patil Sports Academy, Mumbai': 'Dr DY Patil Sports Academy',
    'Maharashtra Cricket Association Stadium, Pune': 'Maharashtra Cricket Association Stadium',
    'Himachal Pradesh Cricket Association Stadium, Dharamsala': 'Himachal Pradesh Cricket Association Stadium',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam': 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
    'Brabourne Stadium, Mumbai':'Brabourne Stadium',
    'Sawai Mansingh Stadium, Jaipur':'Sawai Mansingh Stadium',
    'Narendra Modi Stadium, Ahmedabad': 'Narendra Modi Stadium',
    'Zayed Cricket Stadium, Abu Dhabi': 'Zayed Cricket Stadium',
    'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow': 'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium',
    'Barsapara Cricket Stadium, Guwahati': 'Barsapara Cricket Stadium',
    'Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur': 'Maharaja Yadavindra Singh International Cricket Stadium'
    
    # Add more mappings as necessary
}

# Replace venue names
ipl2['venue']=ipl2['venue'].replace(venue_mapping)

# %%
venue_to_city = {
    'M Chinnaswamy Stadium': 'Bengaluru',
    'Punjab Cricket Association IS Bindra Stadium': 'Mohali',
    'Feroz Shah Kotla': 'Delhi',
    'Wankhede Stadium': 'Mumbai',
    'Eden Gardens': 'Kolkata',
    'Sawai Mansingh Stadium': 'Jaipur',
    'Rajiv Gandhi International Stadium': 'Hyderabad',
    'MA Chidambaram Stadium': 'Chennai',
    'Dr DY Patil Sports Academy': 'Mumbai',
    'Newlands': 'Cape Town',
    "St George's Park": 'Port Elizabeth',
    'Kingsmead': 'Durban',
    'SuperSport Park': 'Centurion',
    'Buffalo Park': 'East London',
    'New Wanderers Stadium': 'Johannesburg',
    'De Beers Diamond Oval': 'Kimberley',
    'OUTsurance Oval': 'Bloemfontein',
    'Brabourne Stadium': 'Mumbai',
    'Sardar Patel Stadium, Motera': 'Ahmedabad',
    'Barabati Stadium': 'Cuttack',
    'Vidarbha Cricket Association Stadium, Jamtha': 'Nagpur',
    'Himachal Pradesh Cricket Association Stadium': 'Dharamshala',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': 'Visakhapatnam',
    'Subrata Roy Sahara Stadium': 'Pune',
    'Shaheed Veer Narayan Singh International Stadium': 'Raipur',
    'JSCA International Stadium Complex': 'Ranchi',
    'Sheikh Zayed Stadium': 'Abu Dhabi',
    'Sharjah Cricket Stadium': 'Sharjah',
    'Dubai International Cricket Stadium': 'Dubai',
    'Maharashtra Cricket Association Stadium': 'Pune',
    'Saurashtra Cricket Association Stadium': 'Rajkot',
    'Green Park': 'Kanpur',
    'Holkar Cricket Stadium': 'Indore',
    'Arun Jaitley Stadium': 'Delhi',
    'Narendra Modi Stadium': 'Ahmedabad',
    'Zayed Cricket Stadium': 'Abu Dhabi',
    'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium': 'Lucknow',
    'Barsapara Cricket Stadium': 'Guwahati',
    'Maharaja Yadavindra Singh International Cricket Stadium': 'Chandigarh',
    'Nehru Stadium':'Kerala'
}

ipl2['city']=ipl2['venue'].map(venue_to_city)

# %%
ipl2['date']
# Out:
# 0      2008-04-18
# 1      2008-04-19
# 2      2008-04-19
# 3      2008-04-20
# 4      2008-04-20
#           ...
# 1090   2024-05-19
# 1091   2024-05-21
# 1092   2024-05-22
# 1093   2024-05-24
# 1094   2024-05-26
# Name: date, Length: 1095, dtype: datetime64[ns]

# %% [markdown]
# ## A)Basic API's

# %% [markdown]
# ### 1) Team Names:
# - for teams name I created a dict with all teams name from team1 and team2 column then to get uniques from them converted it to set and then converted it to dict and finnaly to json

# %%
def team_name():
    a=set(list(ipl2['team1'])+list(ipl2['team2']))
    dict1={'Team_Name':list(a)}
    return dict1

# %%
team_name()
# Out:
# {'Team_Name': ['Rising Pune Supergiant',
#   'Royal Challengers Bangalore',
#   'Gujarat Titans',
#   'Pune Warriors',
#   'Rajasthan Royals',
#   'Gujarat Lions',
#   'Deccan Chargers',
#   'Kolkata Knight Riders',
#   'Sunrisers Hyderabad',
#   'Punjab Kings',
#   'Delhi Daredevils',
#   'Lucknow Super Giants',
#   'Mumbai Indians',
#   'Kochi Tuskers Kerala',
#   'Delhi Capitals',
#   'Chennai Super Kings',
#   'Kings XI Punjab']}

# %% [markdown]
# ### 2) Player Names
# -  for players I merged both columns named batter and bowler to get list of players

# %%
def players():
    a=set(list(ipl1['batter'])+list(ipl1['bowler']))
    players={'Players':list(a)}
    return players

# %%
players()
# Out:
# {'Players': ['M Theekshana',
#   'BMAJ Mendis',
#   'Mohammad Hafeez',
#   'N Thushara',
#   'RV Uthappa',
#   'WPUJC Vaas',
#   'LRPL Taylor',
#   'MA Starc',
#   'C Green',
#   'BAW Mendis',
#   'A Mishra',
#   'Umar Gul',
#   'MC Henriques',
#   'SJ Srivastava',
#   'Misbah-ul-Haq',
#   'UT Khawaja',
#   'T Taibu',
#   'V Pratap Singh',
#   'TS Mills',
#   'SS Cottrell',
#   'T Kohli',
#   'MK Tiwary',
#   'NL McCullum',
#   'Mohsin Khan',
#   'JE Root',
#   'ER Dwivedi',
#   'HH Pandya',
#   'SS Mundhe',
#   'B Stanlake',
#   'KH Pandya',
#   'ST Jayasuriya',
#   'Ramandeep Singh',
#   'L Wood',
#   'VR Iyer',
#   'BA Stokes',
#   'PJ Sangwan',
#   'S Badree',
#   'KC Cariappa',
#   'TP Sudhindra',
#   'Yuvraj Singh',
#   'A Nortje',
#   'JC Buttler',
#   'Shivam Mavi',
#   'Shahid Afridi',
#   'BR Sharath',
#   'RR Sarwan',
#   'N Wadhera',
#   'N Burger',
#   'Shivam Singh',
#   'M Klinger',
#   'VH Zol',
#   'Arshdeep Singh',
#   'BR Dunk',
#   'JP Duminy',
#   'Akash Deep',
#   'Shubman Gill',
#   'Shahbaz Ahmed',
#   'MDKJ Perera',
#   'MC Juneja',
#   'DP Nannes',
#   'A Nehra',
#   'R Rampaul',
#   'AD Mascarenhas',
#   'DNT Zoysa',
#   'PBB Rajapaksa',
#   'D Jansen',
#   'CJ Green',
#   'JM Sharma',
#   'BB Sran',
#   'GH Vihari',
#   'Harpreet Brar',
#   'G Gambhir',
#   'S Narwal',
#   'CM Gautam',
#   'YS Chahal',
#   'Shoaib Akhtar',
#   'S Aravind',
#   'MA Agarwal',
#   'IK Pathan',
#   'B Sumanth',
#   'HR Shokeen',
#   'R Tewatia',
#   'JPR Scantlebury-Searles',
#   'EJG Morgan',
#   'KP Appanna',
#   'D du Preez',
#   'B Akhil',
#   'PWH de Silva',
#   'Arjun Tendulkar',
#   'PV Tambe',
#   'M Muralitharan',
#   'Tanush Kotian',
#   'Mustafizur Rahman',
#   'MA Khote',
#   'RS Gavaskar',
#   'Abdul Samad',
#   'Abishek Porel',
#   'KM Jadhav',
#   'AS Roy',
#   'Naman Dhir',
#   'TM Head',
#   'AU Rashid',
#   'P Parameswaran',
#   'OF Smith',
#   'A Raghuvanshi',
#   'Gurnoor Brar',
#   'MN Samuels',
#   'Anuj Rawat',
#   'RR Raje',
#   'CJ McKay',
#   'AA Noffke',
#   'Mohammad Asif',
#   'Harpreet Singh',
#   'N Pooran',
#   'T Banton',
#   'TL Seifert',
#   'RG More',
#   'S Sandeep Warrier',
#   'TM Dilshan',
#   'Akash Madhwal',
#   'MP Stoinis',
#   'DJ Jacobs',
#   'S Vidyut',
#   'D Kalyankrishna',
#   'M de Lange',
#   'Sameer Rizvi',
#   'R Ravindra',
#   'S Lamichhane',
#   'DPMD Jayawardene',
#   'Mujeeb Ur Rahman',
#   'UA Birla',
#   'B Kumar',
#   'TA Boult',
#   'SR Tendulkar',
#   'T Stubbs',
#   'JA Richardson',
#   'A Flintoff',
#   'AM Salvi',
#   'KR Sen',
#   'HH Gibbs',
#   'RR Rossouw',
#   'NB Singh',
#   'Basil Thampi',
#   'JE Taylor',
#   'VY Mahesh',
#   'ML Hayden',
#   'CL White',
#   'AR Bawne',
#   'LJ Wright',
#   'P Negi',
#   'Navdeep Saini',
#   'AT Rayudu',
#   'SE Marsh',
#   'Arshad Khan',
#   'F Behardien',
#   'YA Abdulla',
#   'S Randiv',
#   'NA Saini',
#   'LR Shukla',
#   'KJ Abbott',
#   'SC Kuggeleijn',
#   'PN Mankad',
#   'Imran Tahir',
#   'F du Plessis',
#   'R Bhatia',
#   'Mohammad Nabi',
#   'N Saini',
#   'BJ Haddin',
#   'RA Jadeja',
#   'RK Singh',
#   'M Siddharth',
#   'AB Dinda',
#   'RJ Harris',
#   'Simarjeet Singh',
#   'Iqbal Abdulla',
#   'GC Smith',
#   'YK Pathan',
#   'Tejas Baroka',
#   'Sikandar Raza',
#   'MK Pandey',
#   'C Ganapathy',
#   'AF Milne',
#   'Tilak Varma',
#   'PA Reddy',
#   'MM Patel',
#   'A Chopra',
#   'DAJ Bracewell',
#   'SM Curran',
#   'KA Pollard',
#   'AS Rajpoot',
#   'SE Bond',
#   'A Chandila',
#   'Anureet Singh',
#   'M Prasidh Krishna',
#   'JR Hazlewood',
#   'K Goel',
#   'NK Patel',
#   'KW Richardson',
#   'E Lewis',
#   'MD Shanaka',
#   'M Rawat',
#   'RV Patel',
#   'Yashpal Singh',
#   'MR Marsh',
#   'S Badrinath',
#   'KL Rahul',
#   'Shoaib Ahmed',
#   'KA Jamieson',
#   'M Pathirana',
#   'A Manohar',
#   'AD Nath',
#   'AD Hales',
#   'Shivam Sharma',
#   'Mayank Dagar',
#   'Abdul Basith',
#   'Abhishek Sharma',
#   'FY Fazal',
#   'V Sehwag',
#   'JR Hopes',
#   'JJ van der Wath',
#   'B Sai Sudharsan',
#   'STR Binny',
#   'AC Voges',
#   'SP Jackson',
#   'Sandeep Sharma',
#   'Virat Singh',
#   'JD Ryder',
#   'RA Bawa',
#   'J Fraser-McGurk',
#   'Salman Butt',
#   'CR Woakes',
#   'MP Yadav',
#   'KAJ Roach',
#   'WD Parnell',
#   'Rasikh Salam',
#   'RE van der Merwe',
#   'JDP Oram',
#   'Q de Kock',
#   'B Indrajith',
#   'I Malhotra',
#   'DM Bravo',
#   'Nithish Kumar Reddy',
#   'RS Sodhi',
#   'JP Faulkner',
#   'SV Samson',
#   'Sanvir Singh',
#   'SA Abbott',
#   'SP Narine',
#   'MV Boucher',
#   'R Goyal',
#   'SP Goswami',
#   'MN van Wyk',
#   'LH Ferguson',
#   'IC Pandey',
#   'MS Dhoni',
#   'HF Gurney',
#   'V Kohli',
#   'RN ten Doeschate',
#   'GJ Bailey',
#   'Mohammed Siraj',
#   'DJ Muthuswami',
#   'JP Behrendorff',
#   'KL Nagarkoti',
#   'RJ Gleeson',
#   'Mohit Rathee',
#   'N Rana',
#   'Sohail Tanvir',
#   'Gulbadin Naib',
#   'L Ngidi',
#   'KP Pietersen',
#   'SA Yadav',
#   'D Brevis',
#   'MF Maharoof',
#   'S Ladda',
#   'Ankit Soni',
#   'R Dravid',
#   'BA Bhatt',
#   'DT Patil',
#   'BE Hendricks',
#   'Umran Malik',
#   'Harbhajan Singh',
#   'MJ Clarke',
#   'L Ablish',
#   'MJ Santner',
#   'B Geeves',
#   'SB Jakati',
#   'I Udana',
#   'DB Ravi Teja',
#   'H Das',
#   'B Laughlin',
#   'Sunny Gupta',
#   'GC Viljoen',
#   'R Powell',
#   'LB Williams',
#   'RA Shaikh',
#   'JW Hastings',
#   'AM Rahane',
#   'Naveen-ul-Haq',
#   'MS Gony',
#   'VS Malik',
#   'PD Salt',
#   'Y Gnaneswara Rao',
#   'P Kumar',
#   'Vijaykumar Vyshak',
#   'Younis Khan',
#   'KR Mayers',
#   'SR Watson',
#   'IS Sodhi',
#   'MJ Suthar',
#   'P Suyal',
#   'SN Thakur',
#   'DJM Short',
#   'DG Nalkande',
#   'H Klaasen',
#   'LMP Simmons',
#   'K Rabada',
#   'A Badoni',
#   'D Wiese',
#   'Sumit Kumar',
#   'MM Sharma',
#   'SB Bangar',
#   'SA Asnodkar',
#   'SS Shaikh',
#   'Sunny Singh',
#   'U Kaul',
#   'D Salunkhe',
#   'RG Sharma',
#   'VVS Laxman',
#   'JH Kallis',
#   'C Sakariya',
#   'AJ Tye',
#   'A Singh',
#   'RD Gaikwad',
#   'RV Gomez',
#   'SD Lad',
#   'WG Jacks',
#   'KC Sangakkara',
#   'BJ Rohrer',
#   'AB Barath',
#   'CJ Dala',
#   'Harshit Rana',
#   'SS Sarkar',
#   'IC Porel',
#   'B Chipli',
#   'Azhar Mahmood',
#   'DS Lehmann',
#   'S Anirudha',
#   'HC Brook',
#   'RK Bhui',
#   'KD Karthik',
#   'PP Ojha',
#   'AS Raut',
#   'MB Parmar',
#   'AL Menaria',
#   'S Sriram',
#   'Sachin Baby',
#   'C Madan',
#   'P Dogra',
#   'R Sharma',
#   'Yash Thakur',
#   'PSP Handscomb',
#   'J Yadav',
#   'CA Ingram',
#   'NJ Rimmington',
#   'GS Sandhu',
#   'S Midhun',
#   'Pankaj Singh',
#   'SM Harwood',
#   'JO Holder',
#   'J Botha',
#   'C Munro',
#   'S Gopal',
#   'MG Johnson',
#   'YV Dhull',
#   'OA Shah',
#   'J Theron',
#   'Shashank Singh',
#   'SO Hetmyer',
#   'R Sai Kishore',
#   'CJ Ferguson',
#   'Mohammad Ashraful',
#   'Y Venugopal Rao',
#   'MJ Henry',
#   'J Suchith',
#   'Ravi Bishnoi',
#   'JL Denly',
#   'T Kohler-Cadmore',
#   'Mukesh Kumar',
#   'R Vinay Kumar',
#   'MM Ali',
#   'DL Vettori',
#   'JDS Neesham',
#   'Vishnu Vinod',
#   'G Coetzee',
#   'A Kamboj',
#   'K Kartikeya',
#   'AD Mathews',
#   'M Shahrukh Khan',
#   'DJ Mitchell',
#   'Z Khan',
#   'L Balaji',
#   'A Uniyal',
#   'D Pretorius',
#   'RT Ponting',
#   'RJ Quiney',
#   'RS Bopara',
#   'Jaskaran Singh',
#   'P Awana',
#   'KS Williamson',
#   'S Sreesanth',
#   'MA Wood',
#   'SB Styris',
#   'TM Srivastava',
#   'Shakib Al Hasan',
#   'W Jaffer',
#   'KK Nair',
#   'Shoaib Malik',
#   'Abdur Razzak',
#   'AA Bilakhia',
#   'PP Chawla',
#   'P Dubey',
#   'A Mithun',
#   'SS Agarwal',
#   'KT Maphaka',
#   'Ankit Sharma',
#   'JJ Roy',
#   'MK Lomror',
#   'Kuldeep Yadav',
#   'WA Mota',
#   'AP Tare',
#   'K Yadav',
#   'Mohammed Shami',
#   'SK Raina',
#   'DR Shorey',
#   'SD Hope',
#   'X Thalaivan Sargunam',
#   'Kumar Kushagra',
#   'Atharva Taide',
#   'DJ Bravo',
#   'B Lee',
#   'UBT Chand',
#   'Vivrant Sharma',
#   'DP Conway',
#   'DJ Harris',
#   'BB McCullum',
#   'SK Warne',
#   'GR Napier',
#   'LS Livingstone',
#   'Y Nagar',
#   'Azmatullah Omarzai',
#   'PA Patel',
#   'I Sharma',
#   'LI Meriwala',
#   'L Ronchi',
#   'SMSM Senanayake',
#   'SB Joshi',
#   'DJ Malan',
#   'Karanveer Singh',
#   'PK Garg',
#   'JD Unadkat',
#   'S Sohal',
#   'Arshad Khan (2)',
#   'JM Bairstow',
#   'CK Langeveldt',
#   'AN Ghosh',
#   'IR Jaggi',
#   'P Chopra',
#   'AC Thomas',
#   'PM Sarvesh Kumar',
#   'CRD Fernando',
#   'AP Majumdar',
#   'ND Doshi',
#   'Dhruv Jurel',
#   'JM Kemp',
#   'P Ray Barman',
#   'GD Phillips',
#   'RS Hangargekar',
#   'RR Powar',
#   'Liton Das',
#   'J Syed Mohammad',
#   'M Markande',
#   'R Sathish',
#   'Monu Kumar',
#   'M Manhas',
#   'KS Sharma',
#   'R Sanjay Yadav',
#   'AB Agarkar',
#   'Gurkeerat Singh',
#   'GHS Garton',
#   'Ashutosh Sharma',
#   'DL Chahar',
#   'J Little',
#   'Anirudh Singh',
#   'KM Asif',
#   'RM Patidar',
#   'Kamran Khan',
#   'KB Arun Karthik',
#   'CH Morris',
#   'GJ Maxwell',
#   'RP Meredith',
#   'DA Warner',
#   'Suyash Sharma',
#   'S Dube',
#   'HE van der Dussen',
#   'SC Ganguly',
#   'AJ Finch',
#   'M Ntini',
#   'S Dhawan',
#   'AC Gilchrist',
#   'WP Saha',
#   'Lalit Yadav',
#   'V Viyaskanth',
#   'DR Martyn',
#   'GD McGrath',
#   'R Ninan',
#   'NT Ellis',
#   'TL Suman',
#   'M Vijay',
#   'P Prasanth',
#   'SB Wagh',
#   'K Khejroliya',
#   'SM Katich',
#   'SW Tait',
#   'CJ Anderson',
#   'DT Christian',
#   'R McLaren',
#   'AA Kazi',
#   'MJ McClenaghan',
#   'AS Joseph',
#   'P Simran Singh',
#   'UT Yadav',
#   'Avesh Khan',
#   'C Nanda',
#   'LPC Silva',
#   'A Choudhary',
#   'AK Markram',
#   'PR Shah',
#   'MS Bisla',
#   'Anand Rajan',
#   'DR Sams',
#   'DJ Hussey',
#   'RR Bose',
#   'M Kartik',
#   'Aman Hakim Khan',
#   'AB de Villiers',
#   'Yash Dayal',
#   'AA Kulkarni',
#   'CV Varun',
#   'LA Pomersbach',
#   'DJ Willey',
#   'S Kaushik',
#   'FA Allen',
#   'A Dananjaya',
#   'V Shankar',
#   'AD Russell',
#   'TK Curran',
#   'AS Yadav',
#   'M Vohra',
#   'A Zampa',
#   'K Gowtham',
#   'KA Maharaj',
#   'P Sahu',
#   'BB Samantray',
#   'YBK Jaiswal',
#   'RP Singh',
#   'AC Blizzard',
#   'AUK Pathan',
#   'S Nadeem',
#   'TD Paine',
#   'FH Edwards',
#   'TR Birt',
#   'JR Philippe',
#   'NS Naik',
#   'RW Price',
#   'MEK Hussey',
#   'Gagandeep Singh',
#   'H Sharma',
#   'RE Levi',
#   'MG Neser',
#   'JEC Franklin',
#   'Kartik Tyagi',
#   'M Morkel',
#   'NJ Maddinson',
#   'R Dhawan',
#   'AT Carey',
#   'T Henderson',
#   'RJW Topley',
#   'Parvez Rasool',
#   'DP Vijaykumar',
#   'M Ashwin',
#   'SM Boland',
#   'KK Cooper',
#   'JJ Bumrah',
#   'DR Smith',
#   'AG Murtaza',
#   'Mukesh Choudhary',
#   'Swapnil Singh',
#   'K Santokie',
#   'YV Takawale',
#   'AJ Turner',
#   'BCJ Cutting',
#   'AP Dole',
#   'DE Bollinger',
#   'PVD Chameera',
#   'PH Solanki',
#   'Rashid Khan',
#   'CA Pujara',
#   'AN Ahmed',
#   'SSB Magala',
#   'A Kumble',
#   'Washington Sundar',
#   'SK Trivedi',
#   'T Shamsi',
#   'VG Arora',
#   'MW Short',
#   'Yudhvir Singh',
#   'PJ Cummins',
#   'R Ashwin',
#   'Joginder Sharma',
#   'CH Gayle',
#   'BJ Hodge',
#   'Bipul Sharma',
#   'AA Jhunjhunwala',
#   'T Natarajan',
#   'N Jagadeesan',
#   'NM Coulter-Nile',
#   'Ishan Kishan',
#   'Akash Singh',
#   'SZ Mulani',
#   'CK Kapugedera',
#   'NLTC Perera',
#   'JC Archer',
#   'SB Dubey',
#   'SL Malinga',
#   'SPD Smith',
#   'A Nel',
#   'PD Collingwood',
#   'DJG Sammy',
#   'RJ Peterson',
#   'DB Das',
#   'DH Yagnik',
#   'R Parag',
#   'Jalaj S Saxena',
#   'MG Bracewell',
#   'RR Bhatkal',
#   'SP Fleming',
#   'RR Pant',
#   'M Kaif',
#   'KK Ahmed',
#   'R Shukla',
#   'Mandeep Singh',
#   'M Jansen',
#   'VRV Singh',
#   'SN Khan',
#   'SS Prabhudessai',
#   'S Tyagi',
#   'MJ Guptill',
#   'MD Mishra',
#   'AB McDonald',
#   'A Mukund',
#   'BW Hilfenhaus',
#   'DS Kulkarni',
#   'KMA Paul',
#   'KMDN Kulasekara',
#   'DJ Thornely',
#   'Kamran Akmal',
#   'VR Aaron',
#   'AJ Hosein',
#   'T Thushara',
#   'R Bishnoi',
#   'S Joseph',
#   'A Symonds',
#   'J Arunkumar',
#   'R Shepherd',
#   'Noor Ahmad',
#   'S Rana',
#   'CR Brathwaite',
#   'SM Pollock',
#   'A Tomar',
#   'OC McCoy',
#   'Anmolpreet Singh',
#   'Harmeet Singh',
#   'LA Carseldine',
#   'VS Yeligati',
#   'MJ Lumb',
#   'CA Lynn',
#   'Fazalhaq Farooqi',
#   'SD Chitnis',
#   'TH David',
#   'RD Chahar',
#   'RA Tripathi',
#   'O Thomas',
#   'D Ferreira',
#   'DA Miller',
#   'SS Iyer',
#   'SH Johnson',
#   'SE Rutherford',
#   'JA Morkel',
#   'JL Pattinson',
#   'Mashrafe Mortaza',
#   'K Upadhyay',
#   'SS Tiwary',
#   'A Ashish Reddy',
#   'S Kaul',
#   'CJ Jordan',
#   'AM Nayar',
#   'D Padikkal',
#   'C de Grandhomme',
#   'Rahmanullah Gurbaz',
#   'V Kaverappa',
#   'NV Ojha',
#   'S Chanderpaul',
#   'LE Plunkett',
#   'TU Deshpande',
#   'P Amarnath',
#   'GB Hogg',
#   'Saurav Chauhan',
#   'AG Paunikar',
#   'TG Southee',
#   'DJ Hooda',
#   'PP Shaw',
#   'KS Bharat',
#   'PC Valthaty',
#   'SW Billings',
#   'Y Prithvi Raj',
#   'HM Amla',
#   'KV Sharma',
#   'DW Steyn',
#   'MS Wade',
#   'AA Chavan',
#   'HV Patel',
#   'AR Patel']}

# %% [markdown]
# ## B) Match API's

# %% [markdown]
# ### 1) match summary

# %% [markdown]
# - here we fetch match summary by using teams name and date when they played the match taking these things as input we can give summary of corresponding match

# %%
ipl2.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
def match_summary(team1, team2, date):
    # fetching match details with respective data
    data = ipl2[(ipl2['team1'] == team1) & (ipl2['team2'] == team2) & (ipl2['date'] == date)]

    if not data.empty:  # Check if data is not empty to avoid errors
        match = {
            'match_id': data['id'].iloc[0],
            'team1': data['team1'].iloc[0],
            'team2': data['team2'].iloc[0],
            'season': data['season'].iloc[0],
            'date': str(data['date'].iloc[0]),
            'city': data['city'].iloc[0],
            'venue': data['venue'].iloc[0],
            'toss_winner': data['toss_winner'].iloc[0],
            'toss_decision': data['toss_decision'].iloc[0],
            'winner': data['winner'].iloc[0],
            'result_margin': data['result_margin'].iloc[0],
            'target_runs': data['target_runs'].iloc[0]
        } # iloc is used to avoid index number
        return (match)
    else:
        return {"error": "No match found with the given details."}

# %%
output=match_summary('Royal Challengers Bangalore','Kings XI Punjab','2008-05-05')

# %%
output
# Out:
# {'match_id': 336006,
#  'team1': 'Royal Challengers Bangalore',
#  'team2': 'Kings XI Punjab',
#  'season': 2008,
#  'date': '2008-05-05 00:00:00',
#  'city': 'Bengaluru',
#  'venue': 'M Chinnaswamy Stadium',
#  'toss_winner': 'Kings XI Punjab',
#  'toss_decision': 'field',
#  'winner': 'Kings XI Punjab',
#  'result_margin': 6.0,
#  'target_runs': 127.0}

# %%
ipl2['date']
# Out:
# 0      2008-04-18
# 1      2008-04-19
# 2      2008-04-19
# 3      2008-04-20
# 4      2008-04-20
#           ...
# 1090   2024-05-19
# 1091   2024-05-21
# 1092   2024-05-22
# 1093   2024-05-24
# 1094   2024-05-26
# Name: date, Length: 1095, dtype: datetime64[ns]

# %%
ipl2[(ipl2['team1'] == 'Royal Challengers Bangalore') & (ipl2['team2'] == 'Kings XI Punjab')]
# Out:
#           id  season       city                 date match_type  \
# 24    336006    2008  Bengaluru  2008-05-05 00:00:00     League
# 67    392191    2009     Durban  2009-04-24 00:00:00     League
# 79    392204    2009     Durban  2009-05-01 00:00:00     League
# 121   419112    2010  Bengaluru  2010-03-16 00:00:00     League
# 220   501244    2011  Bengaluru  2011-05-06 00:00:00     League
# 289   548350    2012  Bengaluru  2012-05-02 00:00:00     League
# 384   598045    2013  Bengaluru  2013-05-14 00:00:00     League
# 428   733991    2014  Bengaluru  2014-05-09 00:00:00     League
# 496   829785    2015  Bengaluru  2015-05-06 00:00:00     League
# 566   980999    2016  Bengaluru  2016-05-18 00:00:00     League
# 618  1082633    2017  Bengaluru  2017-05-05 00:00:00     League
# 737  1178417    2019  Bengaluru  2019-04-24 00:00:00     League
# 786  1216531    2020    Sharjah  2020-10-15 00:00:00     League
#
#     player_of_match                    venue                        team1  \
# 24      S Sreesanth    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 67        RS Bopara                Kingsmead  Royal Challengers Bangalore
# 79     Yuvraj Singh                Kingsmead  Royal Challengers Bangalore
# 121       JH Kallis    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 220        CH Gayle    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 289   Azhar Mahmood    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 384    AC Gilchrist    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 428  Sandeep Sharma    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 496        CH Gayle    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 566         V Kohli    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 618  Sandeep Sharma    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 737  AB de Villiers    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 786        KL Rahul  Sharjah Cricket Stadium  Royal Challengers Bangalore
#
#                team2                  toss_winner toss_decision  \
# 24   Kings XI Punjab              Kings XI Punjab         field
# 67   Kings XI Punjab  Royal Challengers Bangalore           bat
# 79   Kings XI Punjab  Royal Challengers Bangalore           bat
# 121  Kings XI Punjab              Kings XI Punjab           bat
# 220  Kings XI Punjab              Kings XI Punjab         field
# 289  Kings XI Punjab              Kings XI Punjab         field
# 384  Kings XI Punjab              Kings XI Punjab         field
# 428  Kings XI Punjab  Royal Challengers Bangalore         field
# 496  Kings XI Punjab              Kings XI Punjab         field
# 566  Kings XI Punjab              Kings XI Punjab         field
# 618  Kings XI Punjab  Royal Challengers Bangalore         field
# 737  Kings XI Punjab              Kings XI Punjab         field
# 786  Kings XI Punjab  Royal Challengers Bangalore           bat
#
#                           winner   result  result_margin  target_runs  \
# 24               Kings XI Punjab  wickets            6.0        127.0
# 67               Kings XI Punjab  wickets            7.0        169.0
# 79   Royal Challengers Bangalore     runs            8.0        146.0
# 121  Royal Challengers Bangalore  wickets            8.0        204.0
# 220  Royal Challengers Bangalore     runs           85.0        206.0
# 289              Kings XI Punjab  wickets            4.0        159.0
# 384              Kings XI Punjab  wickets            7.0        175.0
# 428              Kings XI Punjab     runs           32.0        199.0
# 496  Royal Challengers Bangalore     runs          138.0        227.0
# 566  Royal Challengers Bangalore     runs           82.0        203.0
# 618              Kings XI Punjab     runs           19.0        139.0
# 737  Royal Challengers Bangalore     runs           17.0        203.0
# 786              Kings XI Punjab  wickets            8.0        172.0
#
#      target_overs super_over method                umpire1         umpire2
# 24           20.0          N    NaN               SJ Davis     BR Doctrove
# 67           20.0          N    NaN            BR Doctrove  TH Wijewardene
# 79           20.0          N    NaN        HDPK Dharmasena          S Ravi
# 121          20.0          N    NaN                  S Das       DJ Harper
# 220          20.0          N    NaN              Aleem Dar       RB Tiffin
# 289          20.0          N    NaN              BF Bowden   C Shamshuddin
# 384          20.0          N    NaN        HDPK Dharmasena          S Ravi
# 428          20.0          N    NaN                 S Ravi       K Srinath
# 496          20.0          N    NaN         RK Illingworth     VA Kulkarni
# 566          14.0          N    D/L  KN Ananthapadmanabhan       M Erasmus
# 618          20.0          N    NaN            CB Gaffaney   C Shamshuddin
# 737          20.0          N    NaN           BNJ Oxenford   C Shamshuddin
# 786          20.0          N    NaN  KN Ananthapadmanabhan   C Shamshuddin

# %% [markdown]
# ### 2) match details

# %% [markdown]
# - here we will display ball-by-ball details of respective match

# %%
ipl1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season'],
#       dtype='object')

# %%
def match_details(team1,team2,date):
    """to get respective match details we compare find the date in second dataset for match id 
    and search the data in 1st dataset cause ipl1 does not have date column""" 
    id=ipl2[(ipl2['team1'] == team1) & (ipl2['team2'] == team2) & (ipl2['date'] == date)]['id']
    if not id.empty:
        id=id.iloc[0]
        match_detail=ipl1[ipl1['match_id']==id] # searched respective match in ipl1
        return json.loads(match_detail.to_json(orient='records',index=False)) # else return result, orientation removes index
    else:
        return {'error':'please check whether the details are correct'} #if data not matches

# %%
match_details('Royal Challengers Bangalore','Kings XI Punjab','2016-05-18')
# Out:
# [{'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 0,
#   'ball': 1,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 0,
#   'ball': 2,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 0,
#   'ball': 3,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 0,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 0,
#   'ball': 5,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 0,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 1,
#   'ball': 1,
#   'batter': 'CH Gayle',
#   'bowler': 'MM Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 1,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 1,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 1,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'MM Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 1,
#   'ball': 5,
#   'batter': 'CH Gayle',
#   'bowler': 'MM Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 1,
#   'ball': 6,
#   'batter': 'CH Gayle',
#   'bowler': 'MM Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 2,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 2,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 2,
#   'ball': 3,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 2,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 2,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 2,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 1,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 1,
#   'total_runs': 1,
#   'extras_type': 'wides',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 2,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 3,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 5,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 3,
#   'ball': 7,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 4,
#   'ball': 1,
#   'batter': 'CH Gayle',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 4,
#   'ball': 2,
#   'batter': 'CH Gayle',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 4,
#   'ball': 3,
#   'batter': 'CH Gayle',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 4,
#   'ball': 4,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 4,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 4,
#   'ball': 6,
#   'batter': 'CH Gayle',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 5,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 5,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 5,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 5,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 5,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 5,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 1,
#   'batter': 'CH Gayle',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 4,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 6,
#   'extra_runs': 1,
#   'total_runs': 7,
#   'extras_type': 'noballs',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 6,
#   'ball': 7,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 7,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 7,
#   'ball': 2,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 7,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 7,
#   'ball': 4,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 7,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 7,
#   'ball': 6,
#   'batter': 'CH Gayle',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 3,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 1,
#   'total_runs': 1,
#   'extras_type': 'wides',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 1,
#   'total_runs': 1,
#   'extras_type': 'wides',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'AR Patel',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 7,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 8,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 1,
#   'total_runs': 1,
#   'extras_type': 'wides',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 8,
#   'ball': 9,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 9,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 9,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 9,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 9,
#   'ball': 4,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 9,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 9,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'KC Cariappa',
#   'non_striker': 'CH Gayle',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 10,
#   'ball': 1,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 10,
#   'ball': 2,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 10,
#   'ball': 3,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 10,
#   'ball': 4,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 10,
#   'ball': 5,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 10,
#   'ball': 6,
#   'batter': 'CH Gayle',
#   'bowler': 'AR Patel',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'CH Gayle',
#   'dismissal_kind': 'caught',
#   'fielder': 'DA Miller',
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'AB de Villiers',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'AB de Villiers',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 3,
#   'batter': 'AB de Villiers',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 4,
#   'batter': 'AB de Villiers',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'AB de Villiers',
#   'dismissal_kind': 'bowled',
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 5,
#   'batter': 'KL Rahul',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 0,
#   'extra_runs': 2,
#   'total_runs': 2,
#   'extras_type': 'wides',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 7,
#   'batter': 'V Kohli',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 1,
#   'extra_runs': 1,
#   'total_runs': 2,
#   'extras_type': 'noballs',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 11,
#   'ball': 8,
#   'batter': 'KL Rahul',
#   'bowler': 'KJ Abbott',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 12,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 12,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 12,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 12,
#   'ball': 4,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 12,
#   'ball': 5,
#   'batter': 'KL Rahul',
#   'bowler': 'MM Sharma',
#   'non_striker': 'V Kohli',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 12,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 13,
#   'ball': 1,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 2,
#   'extra_runs': 0,
#   'total_runs': 2,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 13,
#   'ball': 2,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 2,
#   'extra_runs': 0,
#   'total_runs': 2,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 13,
#   'ball': 3,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 13,
#   'ball': 4,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 13,
#   'ball': 5,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 13,
#   'ball': 6,
#   'batter': 'V Kohli',
#   'bowler': 'Sandeep Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'V Kohli',
#   'dismissal_kind': 'caught',
#   'fielder': 'DA Miller',
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 14,
#   'ball': 1,
#   'batter': 'KL Rahul',
#   'bowler': 'MM Sharma',
#   'non_striker': 'SR Watson',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 14,
#   'ball': 2,
#   'batter': 'KL Rahul',
#   'bowler': 'MM Sharma',
#   'non_striker': 'SR Watson',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 14,
#   'ball': 3,
#   'batter': 'SR Watson',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 14,
#   'ball': 4,
#   'batter': 'SR Watson',
#   'bowler': 'MM Sharma',
#   'non_striker': 'KL Rahul',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 14,
#   'ball': 5,
#   'batter': 'KL Rahul',
#   'bowler': 'MM Sharma',
#   'non_striker': 'SR Watson',
#   'batsman_runs': 2,
#   'extra_runs': 0,
#   'total_runs': 2,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 1,
#   'batting_team': 'Royal Challengers Bangalore',
#   'bowling_team': 'Kings XI Punjab',
#   'over': 14,
#   'ball': 6,
#   'batter': 'KL Rahul',
#   'bowler': 'MM Sharma',
#   'non_striker': 'SR Watson',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 0,
#   'ball': 1,
#   'batter': 'M Vijay',
#   'bowler': 'STR Binny',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 0,
#   'ball': 2,
#   'batter': 'M Vijay',
#   'bowler': 'STR Binny',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 0,
#   'ball': 3,
#   'batter': 'M Vijay',
#   'bowler': 'STR Binny',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 0,
#   'ball': 4,
#   'batter': 'HM Amla',
#   'bowler': 'STR Binny',
#   'non_striker': 'M Vijay',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 0,
#   'ball': 5,
#   'batter': 'HM Amla',
#   'bowler': 'STR Binny',
#   'non_striker': 'M Vijay',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 0,
#   'ball': 6,
#   'batter': 'M Vijay',
#   'bowler': 'STR Binny',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 1,
#   'ball': 1,
#   'batter': 'M Vijay',
#   'bowler': 'S Aravind',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 1,
#   'ball': 2,
#   'batter': 'M Vijay',
#   'bowler': 'S Aravind',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 1,
#   'ball': 3,
#   'batter': 'M Vijay',
#   'bowler': 'S Aravind',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 1,
#   'ball': 4,
#   'batter': 'M Vijay',
#   'bowler': 'S Aravind',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'M Vijay',
#   'dismissal_kind': 'bowled',
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 1,
#   'ball': 5,
#   'batter': 'WP Saha',
#   'bowler': 'S Aravind',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 1,
#   'ball': 6,
#   'batter': 'HM Amla',
#   'bowler': 'S Aravind',
#   'non_striker': 'WP Saha',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 2,
#   'ball': 1,
#   'batter': 'HM Amla',
#   'bowler': 'CJ Jordan',
#   'non_striker': 'WP Saha',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 2,
#   'ball': 2,
#   'batter': 'WP Saha',
#   'bowler': 'CJ Jordan',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 2,
#   'extra_runs': 0,
#   'total_runs': 2,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 2,
#   'ball': 3,
#   'batter': 'WP Saha',
#   'bowler': 'CJ Jordan',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 2,
#   'ball': 4,
#   'batter': 'WP Saha',
#   'bowler': 'CJ Jordan',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 2,
#   'ball': 5,
#   'batter': 'WP Saha',
#   'bowler': 'CJ Jordan',
#   'non_striker': 'HM Amla',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
# ...
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 7,
#   'ball': 6,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'SR Watson',
#   'non_striker': 'F Behardien',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 8,
#   'ball': 1,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'YS Chahal',
#   'non_striker': 'F Behardien',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 8,
#   'ball': 2,
#   'batter': 'F Behardien',
#   'bowler': 'YS Chahal',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'F Behardien',
#   'dismissal_kind': 'caught',
#   'fielder': 'AB de Villiers',
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 8,
#   'ball': 3,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'YS Chahal',
#   'non_striker': 'KJ Abbott',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 8,
#   'ball': 4,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'YS Chahal',
#   'non_striker': 'KJ Abbott',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 8,
#   'ball': 5,
#   'batter': 'KJ Abbott',
#   'bowler': 'YS Chahal',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'KJ Abbott',
#   'dismissal_kind': 'caught',
#   'fielder': 'AB de Villiers',
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 8,
#   'ball': 6,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'YS Chahal',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 9,
#   'ball': 1,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 9,
#   'ball': 2,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'CH Gayle',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 9,
#   'ball': 3,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 9,
#   'ball': 4,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'CH Gayle',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 9,
#   'ball': 5,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 0,
#   'extra_runs': 1,
#   'total_runs': 1,
#   'extras_type': 'legbyes',
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 9,
#   'ball': 6,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'CH Gayle',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 10,
#   'ball': 1,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'YS Chahal',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 10,
#   'ball': 2,
#   'batter': 'MM Sharma',
#   'bowler': 'YS Chahal',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 10,
#   'ball': 3,
#   'batter': 'MM Sharma',
#   'bowler': 'YS Chahal',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 10,
#   'ball': 4,
#   'batter': 'MM Sharma',
#   'bowler': 'YS Chahal',
#   'non_striker': 'Gurkeerat Singh',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 10,
#   'ball': 5,
#   'batter': 'Gurkeerat Singh',
#   'bowler': 'YS Chahal',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'Gurkeerat Singh',
#   'dismissal_kind': 'caught',
#   'fielder': 'CH Gayle',
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 10,
#   'ball': 6,
#   'batter': 'KC Cariappa',
#   'bowler': 'YS Chahal',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 11,
#   'ball': 1,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 11,
#   'ball': 2,
#   'batter': 'KC Cariappa',
#   'bowler': 'CH Gayle',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 11,
#   'ball': 3,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 4,
#   'extra_runs': 0,
#   'total_runs': 4,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 11,
#   'ball': 4,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 11,
#   'ball': 5,
#   'batter': 'KC Cariappa',
#   'bowler': 'CH Gayle',
#   'non_striker': 'MM Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 11,
#   'ball': 6,
#   'batter': 'MM Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 12,
#   'ball': 1,
#   'batter': 'MM Sharma',
#   'bowler': 'Sachin Baby',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 12,
#   'ball': 2,
#   'batter': 'MM Sharma',
#   'bowler': 'Sachin Baby',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 0,
#   'extra_runs': 0,
#   'total_runs': 0,
#   'extras_type': None,
#   'is_wicket': 1,
#   'player_dismissed': 'MM Sharma',
#   'dismissal_kind': 'run out',
#   'fielder': 'SR Watson',
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 12,
#   'ball': 3,
#   'batter': 'KC Cariappa',
#   'bowler': 'Sachin Baby',
#   'non_striker': 'Sandeep Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 12,
#   'ball': 4,
#   'batter': 'Sandeep Sharma',
#   'bowler': 'Sachin Baby',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 12,
#   'ball': 5,
#   'batter': 'KC Cariappa',
#   'bowler': 'Sachin Baby',
#   'non_striker': 'Sandeep Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 12,
#   'ball': 6,
#   'batter': 'Sandeep Sharma',
#   'bowler': 'Sachin Baby',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 13,
#   'ball': 1,
#   'batter': 'Sandeep Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 13,
#   'ball': 2,
#   'batter': 'KC Cariappa',
#   'bowler': 'CH Gayle',
#   'non_striker': 'Sandeep Sharma',
#   'batsman_runs': 6,
#   'extra_runs': 0,
#   'total_runs': 6,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 13,
#   'ball': 3,
#   'batter': 'KC Cariappa',
#   'bowler': 'CH Gayle',
#   'non_striker': 'Sandeep Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 13,
#   'ball': 4,
#   'batter': 'Sandeep Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 13,
#   'ball': 5,
#   'batter': 'KC Cariappa',
#   'bowler': 'CH Gayle',
#   'non_striker': 'Sandeep Sharma',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016},
#  {'match_id': 980999,
#   'inning': 2,
#   'batting_team': 'Kings XI Punjab',
#   'bowling_team': 'Royal Challengers Bangalore',
#   'over': 13,
#   'ball': 6,
#   'batter': 'Sandeep Sharma',
#   'bowler': 'CH Gayle',
#   'non_striker': 'KC Cariappa',
#   'batsman_runs': 1,
#   'extra_runs': 0,
#   'total_runs': 1,
#   'extras_type': None,
#   'is_wicket': 0,
#   'player_dismissed': None,
#   'dismissal_kind': None,
#   'fielder': None,
#   'season': 2016}]

# %%
ipl2[(ipl2['team1'] == 'Royal Challengers Bangalore') & (ipl2['team2'] == 'Kings XI Punjab') & (ipl2['date'] == '2016-05-18')]['id'].iloc[0]
# Out:
# 980999

# %% [markdown]
# ### 3) Season Matches

# %% [markdown]
# - here by taking input as season we will display every match details of that season like teams, winner, result, resultmargin, venue,man of the match,date

# %%
"""
    this function firstly checks whether we have data of respective season or not if yes then return the records else return error
"""
def season_record(season):
    seasons_played=ipl2['season'].unique()
    if season in seasons_played:
        records=ipl2[ipl2['season']==season]
        # json.loads is used to convert inner string value to json
        response=json.loads(records.to_json(orient='records',index=False))
        return response
    else:
        return {'error':"Sorry we don't have data of this season"}

# %%
season_record(2011)
# Out:
# [{'id': 501198,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1302220800000,
#   'match_type': 'League',
#   'player_of_match': 'S Anirudha',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 2.0,
#   'target_runs': 154.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'BR Doctrove',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501199,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1302307200000,
#   'match_type': 'League',
#   'player_of_match': 'SK Trivedi',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Rajasthan Royals',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 138.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'RE Koertzen',
#   'umpire2': 'SK Tarapore'},
#  {'id': 501200,
#   'season': 2011,
#   'city': 'Kerala',
#   'date': 1302307200000,
#   'match_type': 'League',
#   'player_of_match': 'AB de Villiers',
#   'venue': 'Nehru Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'bat',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 162.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'K Hariharan'},
#  {'id': 501201,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1302393600000,
#   'match_type': 'League',
#   'player_of_match': 'SL Malinga',
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 96.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'AM Saheba',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501202,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1302393600000,
#   'match_type': 'League',
#   'player_of_match': 'SB Wagh',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'bat',
#   'winner': 'Pune Warriors',
#   'result': 'wickets',
#   'result_margin': 7.0,
#   'target_runs': 113.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'BR Doctrove',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501203,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1302480000000,
#   'match_type': 'League',
#   'player_of_match': 'JH Kallis',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'bat',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'runs',
#   'result_margin': 9.0,
#   'target_runs': 164.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'RE Koertzen',
#   'umpire2': 'SK Tarapore'},
#  {'id': 501204,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1302566400000,
#   'match_type': 'League',
#   'player_of_match': 'SK Warne',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 152.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501205,
#   'season': 2011,
#   'city': 'Bengaluru',
#   'date': 1302566400000,
#   'match_type': 'League',
#   'player_of_match': 'SR Tendulkar',
#   'venue': 'M Chinnaswamy Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'wickets',
#   'result_margin': 9.0,
#   'target_runs': 141.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'AL Hill'},
#  {'id': 501206,
#   'season': 2011,
#   'city': 'Mohali',
#   'date': 1302652800000,
#   'match_type': 'League',
#   'player_of_match': 'PC Valthaty',
#   'venue': 'Punjab Cricket Association IS Bindra Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Kings XI Punjab',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 189.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SL Shastri'},
#  {'id': 501207,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1302652800000,
#   'match_type': 'League',
#   'player_of_match': 'MD Mishra',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'bat',
#   'winner': 'Pune Warriors',
#   'result': 'wickets',
#   'result_margin': 4.0,
#   'target_runs': 149.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Asnani',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501208,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1302739200000,
#   'match_type': 'League',
#   'player_of_match': 'DW Steyn',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Royal Challengers Bangalore',
#   'toss_decision': 'field',
#   'winner': 'Deccan Chargers',
#   'result': 'runs',
#   'result_margin': 33.0,
#   'target_runs': 176.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'RE Koertzen',
#   'umpire2': 'S Ravi'},
#  {'id': 501209,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1302825600000,
#   'match_type': 'League',
#   'player_of_match': 'G Gambhir',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'field',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'wickets',
#   'result_margin': 9.0,
#   'target_runs': 160.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'SS Hazare'},
#  {'id': 501210,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1302825600000,
#   'match_type': 'League',
#   'player_of_match': 'BB McCullum',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'field',
#   'winner': 'Kochi Tuskers Kerala',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 183.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'BR Doctrove',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501211,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1302912000000,
#   'match_type': 'League',
#   'player_of_match': 'MEK Hussey',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 21.0,
#   'target_runs': 184.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'AL Hill'},
#  {'id': 501212,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1302912000000,
#   'match_type': 'League',
#   'player_of_match': 'PC Valthaty',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Kings XI Punjab',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 166.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'RE Koertzen',
#   'umpire2': 'S Ravi'},
#  {'id': 501213,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1302998400000,
#   'match_type': 'League',
#   'player_of_match': 'Yuvraj Singh',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'field',
#   'winner': 'Delhi Daredevils',
#   'result': 'wickets',
#   'result_margin': 3.0,
#   'target_runs': 188.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501214,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1302998400000,
#   'match_type': 'League',
#   'player_of_match': 'L Balaji',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Rajasthan Royals',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'field',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 82.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501215,
#   'season': 2011,
#   'city': 'Kerala',
#   'date': 1303084800000,
#   'match_type': 'League',
#   'player_of_match': 'BB McCullum',
#   'venue': 'Nehru Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'field',
#   'winner': 'Kochi Tuskers Kerala',
#   'result': 'wickets',
#   'result_margin': 7.0,
#   'target_runs': 135.0,
#   'target_overs': 17.0,
#   'super_over': 'N',
#   'method': 'D/L',
#   'umpire1': 'K Hariharan',
#   'umpire2': 'AL Hill'},
#  {'id': 501216,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1303171200000,
#   'match_type': 'League',
#   'player_of_match': 'S Sohal',
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Deccan Chargers',
#   'toss_decision': 'bat',
#   'winner': 'Deccan Chargers',
#   'result': 'runs',
#   'result_margin': 16.0,
#   'target_runs': 169.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'PR Reiffel',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501218,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1303257600000,
#   'match_type': 'League',
#   'player_of_match': 'MM Patel',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Pune Warriors',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'result': 'wickets',
#   'result_margin': 7.0,
#   'target_runs': 119.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501219,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1303257600000,
#   'match_type': 'League',
#   'player_of_match': 'DPMD Jayawardene',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'field',
#   'winner': 'Kochi Tuskers Kerala',
#   'result': 'runs',
#   'result_margin': 6.0,
#   'target_runs': 133.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501220,
#   'season': 2011,
#   'city': 'Mohali',
#   'date': 1303344000000,
#   'match_type': 'League',
#   'player_of_match': 'SE Marsh',
#   'venue': 'Punjab Cricket Association IS Bindra Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Rajasthan Royals',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Kings XI Punjab',
#   'result': 'runs',
#   'result_margin': 48.0,
#   'target_runs': 196.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Asnani',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501221,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1303430400000,
#   'match_type': 'League',
#   'player_of_match': 'Harbhajan Singh',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'runs',
#   'result_margin': 8.0,
#   'target_runs': 165.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501222,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1303430400000,
#   'match_type': 'League',
#   'player_of_match': 'CH Gayle',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Royal Challengers Bangalore',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 9.0,
#   'target_runs': 172.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SS Hazare',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501223,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1303516800000,
#   'match_type': 'League',
#   'player_of_match': 'DA Warner',
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Delhi Daredevils',
#   'result': 'runs',
#   'result_margin': 29.0,
#   'target_runs': 232.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Asnani',
#   'umpire2': 'RE Koertzen'},
#  {'id': 501224,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1303603200000,
#   'match_type': 'League',
#   'player_of_match': 'SL Malinga',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Deccan Chargers',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'runs',
#   'result_margin': 37.0,
#   'target_runs': 173.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'AL Hill'},
#  {'id': 501225,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1303603200000,
#   'match_type': 'League',
#   'player_of_match': 'SK Warne',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 110.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'BR Doctrove',
#   'umpire2': 'SK Tarapore'},
#  {'id': 501226,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1303689600000,
#   'match_type': 'League',
#   'player_of_match': 'MEK Hussey',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Pune Warriors',
#   'toss_decision': 'field',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 25.0,
#   'target_runs': 143.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501227,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1303776000000,
#   'match_type': 'League',
#   'player_of_match': 'V Kohli',
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Royal Challengers Bangalore',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 3.0,
#   'target_runs': 161.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Asnani',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501228,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1303862400000,
#   'match_type': 'League',
#   'player_of_match': 'DE Bollinger',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Pune Warriors',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 142.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SL Shastri'},
#  {'id': 501229,
#   'season': 2011,
#   'city': 'Kerala',
#   'date': 1303862400000,
#   'match_type': 'League',
#   'player_of_match': 'I Sharma',
#   'venue': 'Nehru Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'field',
#   'winner': 'Deccan Chargers',
#   'result': 'runs',
#   'result_margin': 55.0,
#   'target_runs': 130.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'AL Hill'},
#  {'id': 501230,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1303948800000,
#   'match_type': 'League',
#   'player_of_match': 'MK Tiwary',
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'field',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'runs',
#   'result_margin': 17.0,
#   'target_runs': 149.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'PR Reiffel',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501231,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1304035200000,
#   'match_type': 'League',
#   'player_of_match': 'J Botha',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'result': 'wickets',
#   'result_margin': 7.0,
#   'target_runs': 95.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SK Tarapore'},
#  {'id': 501232,
#   'season': 2011,
#   'city': 'Bengaluru',
#   'date': 1304035200000,
#   'match_type': 'League',
#   'player_of_match': 'V Kohli',
#   'venue': 'M Chinnaswamy Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Pune Warriors',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'runs',
#   'result_margin': 26.0,
#   'target_runs': 182.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'SS Hazare'},
#  {'id': 501233,
#   'season': 2011,
#   'city': 'Kerala',
#   'date': 1304121600000,
#   'match_type': 'League',
#   'player_of_match': 'V Sehwag',
#   'venue': 'Nehru Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'bat',
#   'winner': 'Delhi Daredevils',
#   'result': 'runs',
#   'result_margin': 38.0,
#   'target_runs': 158.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'AL Hill'},
#  {'id': 501234,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1304121600000,
#   'match_type': 'League',
#   'player_of_match': 'Iqbal Abdulla',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'field',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 120.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'AM Saheba',
#   'umpire2': 'SL Shastri'},
#  {'id': 501235,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1304208000000,
#   'match_type': 'League',
#   'player_of_match': 'LRPL Taylor',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 144.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SK Tarapore',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501236,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1304208000000,
#   'match_type': 'League',
#   'player_of_match': 'JA Morkel',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 19.0,
#   'target_runs': 166.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501237,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1304294400000,
#   'match_type': 'League',
#   'player_of_match': 'KA Pollard',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'runs',
#   'result_margin': 23.0,
#   'target_runs': 160.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501238,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1304294400000,
#   'match_type': 'League',
#   'player_of_match': 'P Parameswaran',
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'field',
#   'winner': 'Kochi Tuskers Kerala',
#   'result': 'wickets',
#   'result_margin': 7.0,
#   'target_runs': 141.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SL Shastri'},
#  {'id': 501239,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1304380800000,
#   'match_type': 'League',
#   'player_of_match': 'YK Pathan',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Deccan Chargers',
#   'toss_decision': 'field',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'runs',
#   'result_margin': 20.0,
#   'target_runs': 170.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Asnani',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501240,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1304467200000,
#   'match_type': 'League',
#   'player_of_match': 'MEK Hussey',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Rajasthan Royals',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 148.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SS Hazare',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501241,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1304467200000,
#   'match_type': 'League',
#   'player_of_match': 'R Sharma',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Pune Warriors',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'runs',
#   'result_margin': 21.0,
#   'target_runs': 161.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501242,
#   'season': 2011,
#   'city': 'Kerala',
#   'date': 1304553600000,
#   'match_type': 'League',
#   'player_of_match': 'BJ Hodge',
#   'venue': 'Nehru Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'field',
#   'winner': 'Kochi Tuskers Kerala',
#   'result': 'runs',
#   'result_margin': 17.0,
#   'target_runs': 157.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Ravi',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501243,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1304553600000,
#   'match_type': 'League',
#   'player_of_match': 'V Sehwag',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'field',
#   'winner': 'Delhi Daredevils',
#   'result': 'wickets',
#   'result_margin': 4.0,
#   'target_runs': 176.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501244,
#   'season': 2011,
#   'city': 'Bengaluru',
#   'date': 1304640000000,
#   'match_type': 'League',
#   'player_of_match': 'CH Gayle',
#   'venue': 'M Chinnaswamy Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'runs',
#   'result_margin': 85.0,
#   'target_runs': 206.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501245,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1304726400000,
#   'match_type': 'League',
#   'player_of_match': 'Iqbal Abdulla',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'runs',
#   'result_margin': 10.0,
#   'target_runs': 52.0,
#   'target_overs': 10.0,
#   'super_over': 'N',
#   'method': 'D/L',
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501246,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1304726400000,
#   'match_type': 'League',
#   'player_of_match': 'AT Rayudu',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'runs',
#   'result_margin': 32.0,
#   'target_runs': 179.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'K Hariharan',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501247,
#   'season': 2011,
#   'city': 'Bengaluru',
#   'date': 1304812800000,
#   'match_type': 'League',
#   'player_of_match': 'CH Gayle',
#   'venue': 'M Chinnaswamy Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'bat',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 9.0,
#   'target_runs': 126.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Aleem Dar',
#   'umpire2': 'SS Hazare'},
#  {'id': 501248,
#   'season': 2011,
#   'city': 'Mohali',
#   'date': 1304812800000,
#   'match_type': 'League',
#   'player_of_match': 'R Sharma',
#   'venue': 'Punjab Cricket Association IS Bindra Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'bat',
#   'winner': 'Pune Warriors',
#   'result': 'wickets',
#   'result_margin': 5.0,
#   'target_runs': 120.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SK Tarapore',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501249,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1304899200000,
#   'match_type': 'League',
#   'player_of_match': 'M Vijay',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 63.0,
#   'target_runs': 197.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'K Hariharan',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501250,
#   'season': 2011,
#   'city': 'Hyderabad',
#   'date': 1304985600000,
#   'match_type': 'League',
#   'player_of_match': 'MR Marsh',
#   'venue': 'Rajiv Gandhi International Stadium',
#   'team1': 'Deccan Chargers',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Deccan Chargers',
#   'toss_decision': 'bat',
#   'winner': 'Pune Warriors',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 137.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501251,
#   'season': 2011,
#   'city': 'Mohali',
#   'date': 1304985600000,
#   'match_type': 'League',
#   'player_of_match': 'BA Bhatt',
#   'venue': 'Punjab Cricket Association IS Bindra Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Kings XI Punjab',
#   'result': 'runs',
#   'result_margin': 76.0,
#   'target_runs': 164.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SK Tarapore',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501252,
#   'season': 2011,
#   'city': 'Jaipur',
#   'date': 1305072000000,
#   'match_type': 'League',
#   'player_of_match': 'S Aravind',
#   'venue': 'Sawai Mansingh Stadium',
#   'team1': 'Rajasthan Royals',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Royal Challengers Bangalore',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 9.0,
#   'target_runs': 147.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'K Hariharan'},
#  {'id': 501253,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1305158400000,
#   'match_type': 'League',
#   'player_of_match': 'MS Dhoni',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 18.0,
#   'target_runs': 177.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'AM Saheba',
#   'umpire2': 'SL Shastri'},
#  {'id': 501254,
#   'season': 2011,
#   'city': 'Indore',
#   'date': 1305244800000,
#   'match_type': 'League',
#   'player_of_match': 'KD Karthik',
#   'venue': 'Holkar Cricket Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Kings XI Punjab',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Kings XI Punjab',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 179.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Asnani',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501255,
#   'season': 2011,
#   'city': 'Bengaluru',
#   'date': 1305331200000,
#   'match_type': 'League',
#   'player_of_match': 'CH Gayle',
#   'venue': 'M Chinnaswamy Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Royal Challengers Bangalore',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 4.0,
#   'target_runs': 102.0,
#   'target_overs': 13.0,
#   'super_over': 'N',
#   'method': 'D/L',
#   'umpire1': 'RE Koertzen',
#   'umpire2': 'RB Tiffin'},
#  {'id': 501256,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1305331200000,
#   'match_type': 'League',
#   'player_of_match': 'A Mishra',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Deccan Chargers',
#   'toss_decision': 'bat',
#   'winner': 'Deccan Chargers',
#   'result': 'runs',
#   'result_margin': 10.0,
#   'target_runs': 136.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Ravi',
#   'umpire2': 'SK Tarapore'},
#  {'id': 501257,
#   'season': 2011,
#   'city': 'Dharamshala',
#   'date': 1305417600000,
#   'match_type': 'League',
#   'player_of_match': 'PP Chawla',
#   'venue': 'Himachal Pradesh Cricket Association Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Delhi Daredevils',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'field',
#   'winner': 'Kings XI Punjab',
#   'result': 'runs',
#   'result_margin': 29.0,
#   'target_runs': 171.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SL Shastri'},
#  {'id': 501258,
#   'season': 2011,
#   'city': 'Indore',
#   'date': 1305417600000,
#   'match_type': 'League',
#   'player_of_match': 'BJ Hodge',
#   'venue': 'Holkar Cricket Stadium',
#   'team1': 'Kochi Tuskers Kerala',
#   'team2': 'Rajasthan Royals',
#   'toss_winner': 'Kochi Tuskers Kerala',
#   'toss_decision': 'field',
#   'winner': 'Kochi Tuskers Kerala',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 98.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'PR Reiffel',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501259,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1305504000000,
#   'match_type': 'League',
#   'player_of_match': 'A Mishra',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Deccan Chargers',
#   'toss_decision': 'field',
#   'winner': 'Deccan Chargers',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 137.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Ravi',
#   'umpire2': 'SK Tarapore'},
#  {'id': 501260,
#   'season': 2011,
#   'city': 'Dharamshala',
#   'date': 1305590400000,
#   'match_type': 'League',
#   'player_of_match': 'AC Gilchrist',
#   'venue': 'Himachal Pradesh Cricket Association Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'bat',
#   'winner': 'Kings XI Punjab',
#   'result': 'runs',
#   'result_margin': 111.0,
#   'target_runs': 233.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501261,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1305676800000,
#   'match_type': 'League',
#   'player_of_match': 'WP Saha',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Kochi Tuskers Kerala',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 11.0,
#   'target_runs': 153.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'HDPK Dharmasena',
#   'umpire2': 'RE Koertzen'},
#  {'id': 501262,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1305763200000,
#   'match_type': 'League',
#   'player_of_match': 'YK Pathan',
#   'venue': 'Dr DY Patil Sports Academy',
#   'team1': 'Pune Warriors',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Kolkata Knight Riders',
#   'toss_decision': 'field',
#   'winner': 'Kolkata Knight Riders',
#   'result': 'wickets',
#   'result_margin': 7.0,
#   'target_runs': 119.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'S Ravi',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501263,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1305849600000,
#   'match_type': 'League',
#   'player_of_match': 'SR Watson',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Rajasthan Royals',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'result': 'wickets',
#   'result_margin': 10.0,
#   'target_runs': 134.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'RE Koertzen',
#   'umpire2': 'PR Reiffel'},
#  {'id': 501264,
#   'season': 2011,
#   'city': 'Dharamshala',
#   'date': 1305936000000,
#   'match_type': 'League',
#   'player_of_match': 'S Dhawan',
#   'venue': 'Himachal Pradesh Cricket Association Stadium',
#   'team1': 'Kings XI Punjab',
#   'team2': 'Deccan Chargers',
#   'toss_winner': 'Kings XI Punjab',
#   'toss_decision': 'field',
#   'winner': 'Deccan Chargers',
#   'result': 'runs',
#   'result_margin': 82.0,
#   'target_runs': 199.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'AM Saheba'},
#  {'id': 501265,
#   'season': 2011,
#   'city': 'Delhi',
#   'date': 1305936000000,
#   'match_type': 'League',
#   'player_of_match': None,
#   'venue': 'Feroz Shah Kotla',
#   'team1': 'Delhi Daredevils',
#   'team2': 'Pune Warriors',
#   'toss_winner': 'Delhi Daredevils',
#   'toss_decision': 'bat',
#   'winner': None,
#   'result': 'no result',
#   'result_margin': None,
#   'target_runs': None,
#   'target_overs': None,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SS Hazare',
#   'umpire2': 'RJ Tucker'},
#  {'id': 501266,
#   'season': 2011,
#   'city': 'Bengaluru',
#   'date': 1306022400000,
#   'match_type': 'League',
#   'player_of_match': 'CH Gayle',
#   'venue': 'M Chinnaswamy Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Royal Challengers Bangalore',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'wickets',
#   'result_margin': 8.0,
#   'target_runs': 129.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'K Hariharan',
#   'umpire2': 'RE Koertzen'},
#  {'id': 501267,
#   'season': 2011,
#   'city': 'Kolkata',
#   'date': 1306022400000,
#   'match_type': 'League',
#   'player_of_match': 'JEC Franklin',
#   'venue': 'Eden Gardens',
#   'team1': 'Kolkata Knight Riders',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'wickets',
#   'result_margin': 5.0,
#   'target_runs': 176.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'SK Tarapore',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501268,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1306195200000,
#   'match_type': 'Qualifier 1',
#   'player_of_match': 'SK Raina',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Chennai Super Kings',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'field',
#   'winner': 'Chennai Super Kings',
#   'result': 'wickets',
#   'result_margin': 6.0,
#   'target_runs': 176.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501269,
#   'season': 2011,
#   'city': 'Mumbai',
#   'date': 1306281600000,
#   'match_type': 'Elimination Final',
#   'player_of_match': 'MM Patel',
#   'venue': 'Wankhede Stadium',
#   'team1': 'Mumbai Indians',
#   'team2': 'Kolkata Knight Riders',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'result': 'wickets',
#   'result_margin': 4.0,
#   'target_runs': 148.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501270,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1306454400000,
#   'match_type': 'Qualifier 2',
#   'player_of_match': 'CH Gayle',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Royal Challengers Bangalore',
#   'team2': 'Mumbai Indians',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Royal Challengers Bangalore',
#   'result': 'runs',
#   'result_margin': 43.0,
#   'target_runs': 186.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SJA Taufel'},
#  {'id': 501271,
#   'season': 2011,
#   'city': 'Chennai',
#   'date': 1306540800000,
#   'match_type': 'Final',
#   'player_of_match': 'M Vijay',
#   'venue': 'MA Chidambaram Stadium',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Royal Challengers Bangalore',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'result': 'runs',
#   'result_margin': 58.0,
#   'target_runs': 206.0,
#   'target_overs': 20.0,
#   'super_over': 'N',
#   'method': None,
#   'umpire1': 'Asad Rauf',
#   'umpire2': 'SJA Taufel'}]

# %% [markdown]
# ## B)Teams API

# %% [markdown]
# ### 1) Team Performance

# %% [markdown]
# a) overall team performance

# %% [markdown]
# - by taking input as team name it will return total matches played by the team, season wins losses, winning percentages, total runsmade by team, players name, top 5 scores ie runs scored respective seasons, average score (median)

# %%
ipl2.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
def team_performance(team):
    if team in team_name()['Team_Name']:
        # to find sum of runs in respective season by the team
        team_runs_season=dict(ipl1.groupby(['batting_team','season'])['total_runs'].sum()[team])

        #List of batters aggregate of all seasons
        batters=list(ipl1[ipl1['batting_team']==team]['batter'].unique())

        # List of bowlers aggregate of all seasons
        bowlers=list(ipl1[ipl1['bowling_team']==team]['bowler'].unique())

        # total matches played by team between 2008-2024
        total_matches=ipl2[(ipl2['team1']==team) | (ipl2['team2']==team)]['id'].nunique()

        # number matches they played as qualifier
        qualifier=ipl2[ipl2['match_type']!='League']
        qualifier_team=qualifier[(qualifier['team1']==team)|(qualifier['team2']==team)]
        if not qualifier_team.empty:
            qualifier_team_season=list(qualifier[(qualifier['team1']==team)|(qualifier['team2']==team)]['season'].unique())
        else:
            qualifier_team_season=f'{team} never qualified' 

        # Number of matches they when to finals
        finals=ipl2[ipl2['match_type']=='Final']
        final_team=finals[(finals['team1']==team)|(finals['team2']==team)]
        finalized=final_team.shape[0]

        # Number of matches they won
        if not final_team.empty:
            final_win_count=final_team[final_team['winner']==team].shape[0]
            if final_win_count ==0:
                winned_matches=f'{team} never won the finals'
            else:
                winned_matches=final_win_count
        else:
            winned_matches=f'this team never went to finals'
            
        # Number of matches they lossed
        lossed_matches=finalized-winned_matches

        # Winning percentage according to all matches.
        matches_played=ipl2[(ipl2['team1']==team) | (ipl2['team2']==team)]
        winned_matches_overall=matches_played[matches_played['winner']==team]
        
        winning_percentage=(winned_matches_overall.shape[0]/matches_played.shape[0])*100

        # A dictionary of details of all information fetched above
        final_response={'seasonwise runs':team_runs_season,
                        'batters':batters,
                        'bowlers':bowlers,
                        'total_matches':total_matches,
                        'qualified_matches_season':qualifier_team_season,
                        'finals played':finalized,
                        'wins':winned_matches,
                        'losses':lossed_matches,
                        'winning_percentage_overall':f'{round(winning_percentage,2)}%'
                       }
        return final_response

# %%
team_performance('Mumbai Indians')
# Out:
# {'seasonwise runs': {2008: 2080,
#   2009: 1897,
#   2010: 2738,
#   2011: 2288,
#   2012: 2462,
#   2013: 2975,
#   2014: 2353,
#   2015: 2734,
#   2016: 2194,
#   2017: 2800,
#   2018: 2380,
#   2019: 2670,
#   2020: 2758,
#   2021: 2117,
#   2022: 2217,
#   2023: 2945,
#   2024: 2568},
#  'batters': ['L Ronchi',
#   'ST Jayasuriya',
#   'DJ Thornely',
#   'RV Uthappa',
#   'PR Shah',
#   'AM Nayar',
#   'SM Pollock',
#   'Harbhajan Singh',
#   'DJ Bravo',
#   'MA Khote',
#   'A Nehra',
#   'SS Tiwary',
#   'DS Kulkarni',
#   'AM Rahane',
#   'MK Pandey',
#   'YV Takawale',
#   'RR Raje',
#   'SR Tendulkar',
#   'DR Smith',
#   'SD Chitnis',
#   'CRD Fernando',
#   'VS Yeligati',
#   'S Dhawan',
#   'JP Duminy',
#   'Z Khan',
#   'GR Napier',
#   'C Nanda',
#   'SL Malinga',
#   'Mohammad Ashraful',
#   'AP Tare',
#   'AT Rayudu',
#   'R Sathish',
#   'R McLaren',
#   'KA Pollard',
#   'AN Ahmed',
#   'C Madan',
#   'STR Binny',
#   'DJ Jacobs',
#   'RG Sharma',
#   'JEC Franklin',
#   'A Symonds',
#   'AG Murtaza',
#   'AC Blizzard',
#   'TL Suman',
#   'MM Patel',
#   'RE Levi',
#   'KD Karthik',
#   'SA Yadav',
#   'PP Ojha',
#   'CJ McKay',
#   'RP Singh',
#   'NLTC Perera',
#   'RJ Peterson',
#   'HH Gibbs',
#   'RT Ponting',
#   'R Dhawan',
#   'MG Johnson',
#   'GJ Maxwell',
#   'NM Coulter-Nile',
#   'MEK Hussey',
#   'CJ Anderson',
#   'CM Gautam',
#   'JJ Bumrah',
#   'BR Dunk',
#   'LMP Simmons',
#   'S Gopal',
#   'M de Lange',
#   'P Kumar',
#   'AJ Finch',
#   'J Suchith',
#   'PA Patel',
#   'UBT Chand',
#   'R Vinay Kumar',
#   'HH Pandya',
#   'MJ McClenaghan',
#   'JC Buttler',
#   'KH Pandya',
#   'TG Southee',
#   'MJ Guptill',
#   'N Rana',
#   'KV Sharma',
#   'E Lewis',
#   'Ishan Kishan',
#   'BCJ Cutting',
#   'PJ Sangwan',
#   'M Markande',
#   'A Dananjaya',
#   'Mustafizur Rahman',
#   'Q de Kock',
#   'Yuvraj Singh',
#   'Rasikh Salam',
#   'RD Chahar',
#   'SD Lad',
#   'AS Joseph',
#   'BB Sran',
#   'JL Pattinson',
#   'TA Boult',
#   'CA Lynn',
#   'M Jansen',
#   'J Yadav',
#   'JDS Neesham',
#   'PP Chawla',
#   'AF Milne',
#   'Anmolpreet Singh',
#   'Tilak Varma',
#   'TH David',
#   'DR Sams',
#   'M Ashwin',
#   'D Brevis',
#   'Ramandeep Singh',
#   'JD Unadkat',
#   'TS Mills',
#   'FA Allen',
#   'HR Shokeen',
#   'K Kartikeya',
#   'RP Meredith',
#   'T Stubbs',
#   'R Sanjay Yadav',
#   'C Green',
#   'N Wadhera',
#   'Arshad Khan',
#   'JC Archer',
#   'Arjun Tendulkar',
#   'JP Behrendorff',
#   'Vishnu Vinod',
#   'CJ Jordan',
#   'Naman Dhir',
#   'G Coetzee',
#   'SZ Mulani',
#   'R Shepherd',
#   'Akash Madhwal',
#   'Mohammad Nabi',
#   'L Wood',
#   'A Kamboj'],
#  'bowlers': ['A Nehra',
#   'SM Pollock',
#   'DS Kulkarni',
#   'ST Jayasuriya',
#   'Harbhajan Singh',
#   'AM Nayar',
#   'DJ Bravo',
#   'VS Yeligati',
#   'MA Khote',
#   'SD Chitnis',
#   'CRD Fernando',
#   'DJ Thornely',
#   'RR Raje',
#   'DR Smith',
#   'A Nel',
#   'SL Malinga',
#   'Z Khan',
#   'SR Tendulkar',
#   'JP Duminy',
#   'GR Napier',
#   'C Nanda',
#   'AM Rahane',
#   'RA Shaikh',
#   'R McLaren',
#   'AG Murtaza',
#   'R Sathish',
#   'KA Pollard',
#   'AN Ahmed',
#   'STR Binny',
#   'MM Patel',
#   'JEC Franklin',
#   'RG Sharma',
#   'TL Suman',
#   'A Symonds',
#   'RW Price',
#   'PP Ojha',
#   'RP Singh',
#   'CJ McKay',
#   'NLTC Perera',
#   'RJ Peterson',
#   'R Shukla',
#   'MG Johnson',
#   'JJ Bumrah',
#   'JDP Oram',
#   'R Dhawan',
#   'YS Chahal',
#   'P Suyal',
#   'GJ Maxwell',
#   'NM Coulter-Nile',
#   'CJ Anderson',
#   'P Kumar',
#   'LMP Simmons',
#   'K Santokie',
#   'S Gopal',
#   'M de Lange',
#   'R Vinay Kumar',
#   'J Suchith',
#   'MJ McClenaghan',
#   'HH Pandya',
#   'TG Southee',
#   'KH Pandya',
#   'N Rana',
#   'KV Sharma',
#   'Mustafizur Rahman',
#   'M Markande',
#   'PJ Sangwan',
#   'BCJ Cutting',
#   'A Dananjaya',
#   'Rasikh Salam',
#   'JP Behrendorff',
#   'RD Chahar',
#   'AS Joseph',
#   'J Yadav',
#   'AS Roy',
#   'BB Sran',
#   'TA Boult',
#   'JL Pattinson',
#   'M Jansen',
#   'AF Milne',
#   'JDS Neesham',
#   'PP Chawla',
#   'DR Sams',
#   'Basil Thampi',
#   'M Ashwin',
#   'TS Mills',
#   'Tilak Varma',
#   'JD Unadkat',
#   'D Brevis',
#   'FA Allen',
#   'RP Meredith',
#   'HR Shokeen',
#   'K Kartikeya',
#   'Ramandeep Singh',
#   'R Sanjay Yadav',
#   'Arshad Khan',
#   'JC Archer',
#   'C Green',
#   'Arjun Tendulkar',
#   'D Jansen',
#   'Akash Madhwal',
#   'R Goyal',
#   'T Stubbs',
#   'CJ Jordan',
#   'L Wood',
#   'SZ Mulani',
#   'Naman Dhir',
#   'G Coetzee',
#   'KT Maphaka',
#   'R Shepherd',
#   'Mohammad Nabi',
#   'N Thushara',
#   'A Kamboj',
#   'N Wadhera'],
#  'total_matches': 261,
#  'qualified_matches_season': [2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2017,
#   2019,
#   2020,
#   2023],
#  'finals played': 6,
#  'wins': 5,
#  'losses': 1,
#  'winning_percentage_overall': '55.17%'}

# %% [markdown]
# ## 2) Head-to-Head performance:

# %% [markdown]
# ### i. SeasonWise

# %%
def HTH_season(team1,team2,season):

    # fetched both teams from team1 and team2 column according to the season
    possiblity1=ipl2[(ipl2['team1']==team1)&(ipl2['team2']==team2)&(ipl2['season']==season)]
    possiblity2=ipl2[(ipl2['team1']==team2)&(ipl2['team2']==team1)&(ipl2['season']==season)]

    # checked whether details are available for the details or not and showed result
    if not possiblity1.empty and not possiblity2.empty:
        matches=pd.concat([possiblity1,possiblity2])
        records=matches[['id','season','date','match_type','city','venue','toss_winner','toss_decision','winner','target_runs','player_of_match']]
        response=json.loads(records.to_json(index=False,orient='records'))
        return response
    else:
        return {'error':'no records founds regarding to data'}

# %%
HTH_season('Mumbai Indians','Chennai Super Kings',2015)
# Out:
# [{'id': 829729,
#   'season': 2015,
#   'date': 1429228800000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Chennai Super Kings',
#   'target_runs': 184.0,
#   'player_of_match': 'A Nehra'},
#  {'id': 829823,
#   'season': 2015,
#   'date': 1432425600000,
#   'match_type': 'Final',
#   'city': 'Kolkata',
#   'venue': 'Eden Gardens',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 203.0,
#   'player_of_match': 'RG Sharma'},
#  {'id': 829789,
#   'season': 2015,
#   'date': 1431043200000,
#   'match_type': 'League',
#   'city': 'Chennai',
#   'venue': 'MA Chidambaram Stadium',
#   'toss_winner': 'Chennai Super Kings',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 159.0,
#   'player_of_match': 'HH Pandya'},
#  {'id': 829817,
#   'season': 2015,
#   'date': 1431993600000,
#   'match_type': 'Qualifier 1',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 188.0,
#   'player_of_match': 'KA Pollard'}]

# %% [markdown]
# ### ii. for all Seasons

# %%
def HTH_Overall(team1,team2):

    # extracting data with respect to teams
    matches=ipl2[((ipl2['team1']==team1)&(ipl2['team2']==team2))|
    ((ipl2['team2']==team1)&(ipl2['team1']==team2))]

    #checking emptiness
    if not matches.empty:

        # fetching the columns want to return
        records=matches[['id','season','date','match_type','city','venue','toss_winner','toss_decision','winner','target_runs','player_of_match']]
    
        # Number of matches they played against
        total_matches=records.shape[0]
    
        # Number of wins of team1
        team1_win=records[records['winner']==team1].shape[0]
    
        # Number of wins of team2
        team2_win=records[records['winner']==team2].shape[0]
    
        # Winning percentage of both teams
        winning_rate_team1=(team1_win/total_matches)*100
        winning_rate_team2=(team2_win/total_matches)*100
    
        # converted dataframe to json and to add further details converted to list 
        response=list(json.loads(records.to_json(orient='records')))
        result=response+([{'total_matches':total_matches},
                           {'wins_of_team1':team1_win},
                           {'wins_of_team2':team2_win},
                           {'winning_rate_team1':round(winning_rate_team1,2)},
                          {'winning_rate_team2':round(winning_rate_team2,2)}])
        return result
    else:
        return {'error':'data not available'}

# %%
HTH_Overall('Rajasthan Royals','Mumbai Indians')
# Out:
# [{'id': 336008,
#   'season': 2008,
#   'date': 1210118400000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Dr DY Patil Sports Academy',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 104.0,
#   'player_of_match': 'A Nehra'},
#  {'id': 336036,
#   'season': 2008,
#   'date': 1211760000000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 146.0,
#   'player_of_match': 'Sohail Tanvir'},
#  {'id': 392225,
#   'season': 2009,
#   'date': 1242259200000,
#   'match_type': 'League',
#   'city': 'Durban',
#   'venue': 'Kingsmead',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 146.0,
#   'player_of_match': 'SK Warne'},
#  {'id': 419107,
#   'season': 2010,
#   'date': 1268438400000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Brabourne Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 213.0,
#   'player_of_match': 'YK Pathan'},
#  {'id': 419150,
#   'season': 2010,
#   'date': 1270944000000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 175.0,
#   'player_of_match': 'SR Tendulkar'},
#  {'id': 501231,
#   'season': 2011,
#   'date': 1304035200000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 95.0,
#   'player_of_match': 'J Botha'},
#  {'id': 501263,
#   'season': 2011,
#   'date': 1305849600000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 134.0,
#   'player_of_match': 'SR Watson'},
#  {'id': 548317,
#   'season': 2012,
#   'date': 1334102400000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 198.0,
#   'player_of_match': 'KA Pollard'},
#  {'id': 548377,
#   'season': 2012,
#   'date': 1337472000000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 163.0,
#   'player_of_match': 'DR Smith'},
#  {'id': 598019,
#   'season': 2013,
#   'date': 1366156800000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 180.0,
#   'player_of_match': 'AM Rahane'},
#  {'id': 598063,
#   'season': 2013,
#   'date': 1368576000000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 167.0,
#   'player_of_match': 'AP Tare'},
#  {'id': 598072,
#   'season': 2013,
#   'date': 1369353600000,
#   'match_type': 'Qualifier 2',
#   'city': 'Kolkata',
#   'venue': 'Eden Gardens',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 166.0,
#   'player_of_match': 'Harbhajan Singh'},
#  {'id': 734017,
#   'season': 2014,
#   'date': 1400457600000,
#   'match_type': 'League',
#   'city': 'Ahmedabad',
#   'venue': 'Sardar Patel Stadium, Motera',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 179.0,
#   'player_of_match': 'MEK Hussey'},
#  {'id': 734041,
#   'season': 2014,
#   'date': 1400976000000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 190.0,
#   'player_of_match': 'CJ Anderson'},
#  {'id': 829721,
#   'season': 2015,
#   'date': 1428969600000,
#   'match_type': 'League',
#   'city': 'Ahmedabad',
#   'venue': 'Sardar Patel Stadium, Motera',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 165.0,
#   'player_of_match': 'SPD Smith'},
#  {'id': 829769,
#   'season': 2015,
#   'date': 1430438400000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 188.0,
#   'player_of_match': 'AT Rayudu'},
#  {'id': 1136581,
#   'season': 2018,
#   'date': 1524355200000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 168.0,
#   'player_of_match': 'JC Archer'},
#  {'id': 1136607,
#   'season': 2018,
#   'date': 1526169600000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 169.0,
#   'player_of_match': 'JC Buttler'},
#  {'id': 1178402,
#   'season': 2019,
#   'date': 1555113600000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 188.0,
#   'player_of_match': 'JC Buttler'},
#  {'id': 1178411,
#   'season': 2019,
#   'date': 1555718400000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 162.0,
#   'player_of_match': 'SPD Smith'},
#  {'id': 1216511,
#   'season': 2020,
#   'date': 1601942400000,
#   'match_type': 'League',
#   'city': 'Abu Dhabi',
#   'venue': 'Sheikh Zayed Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 194.0,
#   'player_of_match': 'SA Yadav'},
#  {'id': 1216541,
#   'season': 2020,
#   'date': 1603584000000,
#   'match_type': 'League',
#   'city': 'Abu Dhabi',
#   'venue': 'Sheikh Zayed Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 196.0,
#   'player_of_match': 'BA Stokes'},
#  {'id': 1254081,
#   'season': 2021,
#   'date': 1619654400000,
#   'match_type': 'League',
#   'city': 'Delhi',
#   'venue': 'Arun Jaitley Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 172.0,
#   'player_of_match': 'Q de Kock'},
#  {'id': 1254093,
#   'season': 2021,
#   'date': 1633392000000,
#   'match_type': 'League',
#   'city': 'Sharjah',
#   'venue': 'Sharjah Cricket Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 91.0,
#   'player_of_match': 'NM Coulter-Nile'},
#  {'id': 1304055,
#   'season': 2022,
#   'date': 1648857600000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Dr DY Patil Sports Academy',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 194.0,
#   'player_of_match': 'JC Buttler'},
#  {'id': 1304090,
#   'season': 2022,
#   'date': 1651276800000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Dr DY Patil Sports Academy',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'field',
#   'winner': 'Mumbai Indians',
#   'target_runs': 159.0,
#   'player_of_match': 'SA Yadav'},
#  {'id': 1359516,
#   'season': 2023,
#   'date': 1682812800000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'bat',
#   'winner': 'Mumbai Indians',
#   'target_runs': 213.0,
#   'player_of_match': 'YBK Jaiswal'},
#  {'id': 1422132,
#   'season': 2024,
#   'date': 1711929600000,
#   'match_type': 'League',
#   'city': 'Mumbai',
#   'venue': 'Wankhede Stadium',
#   'toss_winner': 'Rajasthan Royals',
#   'toss_decision': 'field',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 126.0,
#   'player_of_match': 'TA Boult'},
#  {'id': 1426276,
#   'season': 2024,
#   'date': 1713744000000,
#   'match_type': 'League',
#   'city': 'Jaipur',
#   'venue': 'Sawai Mansingh Stadium',
#   'toss_winner': 'Mumbai Indians',
#   'toss_decision': 'bat',
#   'winner': 'Rajasthan Royals',
#   'target_runs': 180.0,
#   'player_of_match': 'Sandeep Sharma'},
#  {'total_matches': 29},
#  {'wins_of_team1': 14},
#  {'wins_of_team2': 15},
#  {'winning_rate_team1': 48.28},
#  {'winning_rate_team2': 51.72}]

# %% [markdown]
# 3) Toss Analysis:
# - this will return the analysis of toss wins, toss decisions, winning rate after winning toss.

# %%
def toss_analysis():
    """
    Analyzes toss decisions in IPL matches and computes statistics.
    Returns:
        dict: A dictionary containing percentages of toss decisions and their outcomes.
    """

    # Fetching details
    toss_bat = ipl2[ipl2['toss_decision'] == 'bat']
    toss_field = ipl2[ipl2['toss_decision'] == 'field']
    win_toss_match = ipl2[ipl2['toss_winner'] == ipl2['winner']].shape[0]
    win_bat_match = toss_bat[toss_bat['winner'] == toss_bat['toss_winner']].shape[0]
    win_field_match = toss_field[toss_field['winner'] == toss_field['toss_winner']].shape[0]

    # Converting to percentages
    rate_toss_bat = (toss_bat.shape[0] / ipl2.shape[0]) * 100
    rate_toss_field = (toss_field.shape[0] / ipl2.shape[0]) * 100
    rate_win_toss_match = (win_toss_match / ipl2.shape[0]) * 100
    rate_win_bat_match = (win_bat_match / toss_bat.shape[0] * 100) if toss_bat.shape[0] > 0 else 0
    rate_win_field_match = (win_field_match / toss_field.shape[0] * 100) if toss_field.shape[0] > 0 else 0

    # Preparing the response
    response = {
        'toss_bat_percentage': round(rate_toss_bat, 2),
        'toss_field_percentage': round(rate_toss_field, 2),
        'win_toss_match_percentage': round(rate_win_toss_match, 2),
        'bat_after_toss_win_percentage': round(rate_win_bat_match, 2),
        'field_after_toss_win_percentage': round(rate_win_field_match, 2),
    }

    return response

# %%
toss_analysis()
# Out:
# {'toss_bat_percentage': 35.71,
#  'toss_field_percentage': 64.29,
#  'win_toss_match_percentage': 50.59,
#  'bat_after_toss_win_percentage': 45.27,
#  'field_after_toss_win_percentage': 53.55}

# %% [markdown]
# ## C) Players API

# %% [markdown]
# # 1. Player Performance
# - gives overall players performance like total runs, ball faced, strike rate, boundaries, wickets, man of the match, Number of matches played, plays as

# %%
def players_performance(name):
    records1 = ipl1[ipl1['batter'] == name]
    records2 = ipl1[ipl1['bowler'] == name]
    records3 = ipl1[ipl1['fielder'] == name]
    plays_as = []

    # Initialize variables
    total_runs = 0
    min_score = 0
    max_score = 0
    avg_score = 0
    num_ball = 0
    boundary_4 = 0
    boundary_6 = 0
    strike_rate = 0
    wickets_taken = 0

    if not records1.empty:
        plays_as.append('batter')
        total_runs = records1['batsman_runs'].sum()
        min_score = records1.groupby('match_id')['batsman_runs'].sum().min()
        max_score = records1.groupby('match_id')['batsman_runs'].sum().max()
        avg_score = records1.groupby('match_id')['batsman_runs'].sum().mean()
        num_ball = records1['ball'].count()
        boundary_4 = records1[records1['batsman_runs'] == 4].shape[0]
        boundary_6 = records1[records1['batsman_runs'] == 6].shape[0]
        strike_rate = round((total_runs / num_ball) * 100, 2) if num_ball > 0 else 0

    if not records2.empty:
        plays_as.append('bowler')
        wickets_taken = records2[records2['is_wicket'] == 1].shape[0]

    if not records3.empty:
        plays_as.append('fielder')

    # Combine records to get matches played
    all_records = pd.concat([records1, records2, records3])
    matches_played = all_records['match_id'].nunique()

    # Get unique teams played for
    teams_played = pd.concat([
        records1['batting_team'], 
        records2['bowling_team'], 
        records3['bowling_team']
    ]).unique().tolist()

    # Number of times player was "Player of the Match"
    num_man_of_match = ipl2[ipl2['player_of_match'] == name].shape[0]

    response = {
        'teams_played': teams_played,
        'played_as': plays_as,
        'number_matches': matches_played,
        'total_runs': total_runs,
        'num_ball': num_ball,
        'highest_score': max_score,
        'lowest_score': min_score,
        'average_score': round(avg_score, 2),
        'boundaries_4': boundary_4,
         'boundaries_6': boundary_6,
        'strike_rate': strike_rate,
        'wickets_taken': wickets_taken,
        'player_of_match': num_man_of_match
        }
    return response

# %%
players_performance('V Kohli')
# Out:
# {'teams_played': ['Royal Challengers Bangalore'],
#  'played_as': ['batter', 'bowler', 'fielder'],
#  'number_matches': 247,
#  'total_runs': 8014,
#  'num_ball': 6236,
#  'highest_score': 113,
#  'lowest_score': 0,
#  'average_score': 32.84,
#  'boundaries_4': 708,
#  'boundaries_6': 273,
#  'strike_rate': 128.51,
#  'wickets_taken': 5,
#  'player_of_match': 18}

# %% [markdown]
# # 2) Top players
# - players List according to batting and bowling a descending list based on their strike rate and wickets

# %%
def top_players(player):
    if player == 'batter':
        # Grouping by batter to calculate runs and balls faced
        runs = ipl1.groupby('batter')['batsman_runs'].sum()
        balls = ipl1.groupby('batter')['ball'].count()
        
        # Calculating strike rate
        strike_rate = round((runs / balls) * 100, 2)
        
        # Creating a DataFrame
        batter_stats = pd.DataFrame({'runs': runs, 'balls': balls, 'strike_rate': strike_rate})
        
        # Filtering players who faced more than 20 balls
        filtered_batters = batter_stats[batter_stats['balls'] > 20]
        
        # Sorting by strike rate in descending order
        sorted_batters = filtered_batters.sort_values(by='strike_rate', ascending=False)
        
        # Creating a dictionary with player names as keys
        response = sorted_batters.to_dict(orient='index')
        
        return {name: details for name, details in response.items()}
    
    elif player == 'bowler':
        # Grouping by bowler to calculate balls bowled
        balls = ipl1.groupby('bowler')['ball'].count()
        
        # Filtering only dismissals (is_wicket == 1) and grouping by bowler
        wickets = ipl1[ipl1['is_wicket'] == 1].groupby('bowler')['is_wicket'].count()
        
        # Creating a DataFrame for bowlers
        bowler_stats = pd.DataFrame({'balls': balls, 'wickets': wickets}).fillna(0)
        
        # Filtering bowlers who have taken at least 1 wicket
        filtered_bowlers = bowler_stats[bowler_stats['wickets'] > 0]
        
        # Sorting by wickets taken in descending order
        sorted_bowlers = filtered_bowlers.sort_values(by='wickets', ascending=False)
        
        # Creating a dictionary with player names as keys
        response = sorted_bowlers.to_dict(orient='index')
        
        return {name: details for name, details in response.items()}

    else:
        return {'error': 'Invalid player type. Please use "batter" or "bowler".'}

# %%
top_players('bowler')
# Out:
# {'YS Chahal': {'balls': 3628, 'wickets': 213.0},
#  'DJ Bravo': {'balls': 3296, 'wickets': 207.0},
#  'PP Chawla': {'balls': 3895, 'wickets': 201.0},
#  'SP Narine': {'balls': 4146, 'wickets': 200.0},
#  'R Ashwin': {'balls': 4679, 'wickets': 198.0},
#  'B Kumar': {'balls': 4060, 'wickets': 195.0},
#  'SL Malinga': {'balls': 2974, 'wickets': 188.0},
#  'A Mishra': {'balls': 3444, 'wickets': 183.0},
#  'JJ Bumrah': {'balls': 3185, 'wickets': 182.0},
#  'RA Jadeja': {'balls': 3895, 'wickets': 169.0},
#  'UT Yadav': {'balls': 3190, 'wickets': 163.0},
#  'Harbhajan Singh': {'balls': 3496, 'wickets': 161.0},
#  'Rashid Khan': {'balls': 2901, 'wickets': 157.0},
#  'Sandeep Sharma': {'balls': 2925, 'wickets': 153.0},
#  'HV Patel': {'balls': 2284, 'wickets': 151.0},
#  'MM Sharma': {'balls': 2308, 'wickets': 147.0},
#  'Mohammed Shami': {'balls': 2521, 'wickets': 144.0},
#  'AR Patel': {'balls': 3152, 'wickets': 131.0},
#  'TA Boult': {'balls': 2428, 'wickets': 128.0},
#  'R Vinay Kumar': {'balls': 2186, 'wickets': 127.0},
#  'K Rabada': {'balls': 1907, 'wickets': 126.0},
#  'AD Russell': {'balls': 1771, 'wickets': 125.0},
#  'A Nehra': {'balls': 1974, 'wickets': 121.0},
#  'Z Khan': {'balls': 2276, 'wickets': 119.0},
#  'JD Unadkat': {'balls': 2194, 'wickets': 109.0},
#  'SR Watson': {'balls': 2137, 'wickets': 107.0},
#  'CH Morris': {'balls': 1801, 'wickets': 107.0},
#  'DW Steyn': {'balls': 2282, 'wickets': 105.0},
#  'P Kumar': {'balls': 2637, 'wickets': 102.0},
#  'SN Thakur': {'balls': 1979, 'wickets': 100.0},
#  'RP Singh': {'balls': 1874, 'wickets': 100.0},
#  'PP Ojha': {'balls': 1945, 'wickets': 99.0},
#  'IK Pathan': {'balls': 2113, 'wickets': 99.0},
#  'I Sharma': {'balls': 2429, 'wickets': 96.0},
#  'JA Morkel': {'balls': 1807, 'wickets': 96.0},
#  'Mohammed Siraj': {'balls': 2081, 'wickets': 96.0},
#  'DS Kulkarni': {'balls': 1876, 'wickets': 91.0},
#  'Kuldeep Yadav': {'balls': 1786, 'wickets': 90.0},
#  'M Morkel': {'balls': 1699, 'wickets': 88.0},
#  'Imran Tahir': {'balls': 1340, 'wickets': 86.0},
#  'CV Varun': {'balls': 1624, 'wickets': 85.0},
#  'L Balaji': {'balls': 1574, 'wickets': 85.0},
#  'Arshdeep Singh': {'balls': 1453, 'wickets': 84.0},
#  'R Bhatia': {'balls': 1661, 'wickets': 82.0},
#  'AB Dinda': {'balls': 1589, 'wickets': 82.0},
#  'KV Sharma': {'balls': 1520, 'wickets': 82.0},
#  'MM Patel': {'balls': 1382, 'wickets': 82.0},
#  'Avesh Khan': {'balls': 1390, 'wickets': 81.0},
#  'KA Pollard': {'balls': 1586, 'wickets': 81.0},
#  'KH Pandya': {'balls': 2183, 'wickets': 80.0},
#  'DL Chahar': {'balls': 1746, 'wickets': 79.0},
#  'KK Ahmed': {'balls': 1345, 'wickets': 78.0},
#  'JP Faulkner': {'balls': 1287, 'wickets': 76.0},
#  'RD Chahar': {'balls': 1697, 'wickets': 76.0},
#  'T Natarajan': {'balls': 1401, 'wickets': 76.0},
#  'MJ McClenaghan': {'balls': 1346, 'wickets': 75.0},
#  'JH Kallis': {'balls': 1799, 'wickets': 74.0},
#  'SK Trivedi': {'balls': 1557, 'wickets': 73.0},
#  'Shakib Al Hasan': {'balls': 1515, 'wickets': 71.0},
#  'Mustafizur Rahman': {'balls': 1353, 'wickets': 70.0},
#  'HH Pandya': {'balls': 1485, 'wickets': 70.0},
#  'Ravi Bishnoi': {'balls': 1460, 'wickets': 68.0},
#  'M Muralitharan': {'balls': 1581, 'wickets': 67.0},
#  'MG Johnson': {'balls': 1301, 'wickets': 66.0},
#  'PJ Cummins': {'balls': 1370, 'wickets': 66.0},
#  'S Kaul': {'balls': 1238, 'wickets': 63.0},
#  'SM Curran': {'balls': 1234, 'wickets': 62.0},
#  'A Nortje': {'balls': 1097, 'wickets': 62.0},
#  'SK Warne': {'balls': 1223, 'wickets': 60.0},
#  'MA Starc': {'balls': 879, 'wickets': 59.0},
#  'JO Holder': {'balls': 1049, 'wickets': 59.0},
#  'TG Southee': {'balls': 1262, 'wickets': 57.0},
#  'LH Ferguson': {'balls': 1002, 'wickets': 57.0},
#  'S Nadeem': {'balls': 1444, 'wickets': 54.0},
#  'M Prasidh Krishna': {'balls': 1231, 'wickets': 54.0},
#  'S Gopal': {'balls': 1000, 'wickets': 53.0},
#  'NM Coulter-Nile': {'balls': 892, 'wickets': 52.0},
#  'SB Jakati': {'balls': 1101, 'wickets': 50.0},
#  'JC Archer': {'balls': 987, 'wickets': 49.0},
#  'A Kumble': {'balls': 983, 'wickets': 49.0},
#  'AJ Tye': {'balls': 714, 'wickets': 48.0},
#  'S Aravind': {'balls': 788, 'wickets': 48.0},
#  'RJ Harris': {'balls': 865, 'wickets': 47.0},
#  'YK Pathan': {'balls': 1184, 'wickets': 46.0},
#  'VR Aaron': {'balls': 1065, 'wickets': 46.0},
#  'MC Henriques': {'balls': 979, 'wickets': 46.0},
#  'TU Deshpande': {'balls': 831, 'wickets': 46.0},
#  'MP Stoinis': {'balls': 831, 'wickets': 45.0},
#  'Iqbal Abdulla': {'balls': 943, 'wickets': 45.0},
#  'PJ Sangwan': {'balls': 905, 'wickets': 44.0},
#  'S Sreesanth': {'balls': 947, 'wickets': 43.0},
#  'DE Bollinger': {'balls': 600, 'wickets': 43.0},
#  'P Awana': {'balls': 774, 'wickets': 43.0},
#  'R Sharma': {'balls': 935, 'wickets': 42.0},
#  'GJ Maxwell': {'balls': 965, 'wickets': 41.0},
#  'MM Ali': {'balls': 770, 'wickets': 40.0},
#  'WD Parnell': {'balls': 758, 'wickets': 40.0},
#  'DT Christian': {'balls': 922, 'wickets': 40.0},
#  'Yuvraj Singh': {'balls': 882, 'wickets': 39.0},
#  'MS Gony': {'balls': 925, 'wickets': 39.0},
#  'Washington Sundar': {'balls': 1064, 'wickets': 39.0},
#  'M Kartik': {'balls': 1182, 'wickets': 39.0},
#  'DP Nannes': {'balls': 689, 'wickets': 38.0},
#  'M Pathirana': {'balls': 503, 'wickets': 38.0},
#  'P Negi': {'balls': 733, 'wickets': 38.0},
#  'M Markande': {'balls': 737, 'wickets': 37.0},
#  'MR Marsh': {'balls': 593, 'wickets': 37.0},
#  'NLTC Perera': {'balls': 715, 'wickets': 37.0},
#  'JR Hazlewood': {'balls': 622, 'wickets': 36.0},
#  'CJ Jordan': {'balls': 717, 'wickets': 36.0},
#  'KK Cooper': {'balls': 600, 'wickets': 36.0},
#  'PWH de Silva': {'balls': 557, 'wickets': 36.0},
#  'R Tewatia': {'balls': 866, 'wickets': 36.0},
#  'M Ashwin': {'balls': 898, 'wickets': 35.0},
#  'DL Vettori': {'balls': 785, 'wickets': 34.0},
#  'MF Maharoof': {'balls': 441, 'wickets': 33.0},
#  'AB Agarkar': {'balls': 820, 'wickets': 33.0},
#  'Shivam Mavi': {'balls': 687, 'wickets': 33.0},
#  'A Singh': {'balls': 486, 'wickets': 31.0},
#  'CR Woakes': {'balls': 463, 'wickets': 31.0},
#  'BA Stokes': {'balls': 723, 'wickets': 31.0},
#  'Mukesh Kumar': {'balls': 420, 'wickets': 31.0},
#  'Azhar Mahmood': {'balls': 552, 'wickets': 31.0},
#  'Harmeet Singh': {'balls': 574, 'wickets': 31.0},
#  'Umran Malik': {'balls': 519, 'wickets': 31.0},
#  'Yash Dayal': {'balls': 615, 'wickets': 31.0},
#  'A Zampa': {'balls': 425, 'wickets': 30.0},
#  'SK Raina': {'balls': 930, 'wickets': 30.0},
#  'B Lee': {'balls': 916, 'wickets': 30.0},
#  'STR Binny': {'balls': 611, 'wickets': 28.0},
#  'L Ngidi': {'balls': 342, 'wickets': 28.0},
#  'AD Mathews': {'balls': 807, 'wickets': 28.0},
#  'PV Tambe': {'balls': 674, 'wickets': 28.0},
#  'Mohsin Khan': {'balls': 507, 'wickets': 27.0},
#  'R Dhawan': {'balls': 693, 'wickets': 27.0},
#  'Yash Thakur': {'balls': 432, 'wickets': 27.0},
#  'Harshit Rana': {'balls': 403, 'wickets': 27.0},
#  'J Botha': {'balls': 709, 'wickets': 27.0},
#  'DR Smith': {'balls': 557, 'wickets': 27.0},
#  'Naveen-ul-Haq': {'balls': 407, 'wickets': 26.0},
#  'Navdeep Saini': {'balls': 682, 'wickets': 26.0},
#  'Basil Thampi': {'balls': 539, 'wickets': 26.0},
#  'SW Tait': {'balls': 534, 'wickets': 26.0},
#  'M Theekshana': {'balls': 631, 'wickets': 25.0},
#  'Harpreet Brar': {'balls': 692, 'wickets': 25.0},
#  'GB Hogg': {'balls': 466, 'wickets': 25.0},
#  'RE van der Merwe': {'balls': 455, 'wickets': 25.0},
#  'AS Rajpoot': {'balls': 567, 'wickets': 24.0},
#  'Noor Ahmad': {'balls': 513, 'wickets': 24.0},
#  'Sohail Tanvir': {'balls': 265, 'wickets': 24.0},
#  'BW Hilfenhaus': {'balls': 390, 'wickets': 23.0},
#  'A Symonds': {'balls': 540, 'wickets': 23.0},
#  'JP Duminy': {'balls': 701, 'wickets': 23.0},
#  'Akash Madhwal': {'balls': 279, 'wickets': 22.0},
#  'K Gowtham': {'balls': 599, 'wickets': 22.0},
#  'M Jansen': {'balls': 487, 'wickets': 22.0},
#  'Bipul Sharma': {'balls': 436, 'wickets': 22.0},
#  'AS Joseph': {'balls': 454, 'wickets': 22.0},
#  'VY Mahesh': {'balls': 359, 'wickets': 22.0},
#  'WPUJC Vaas': {'balls': 288, 'wickets': 22.0},
#  'JP Behrendorff': {'balls': 379, 'wickets': 22.0},
#  'RP Meredith': {'balls': 415, 'wickets': 21.0},
#  'Anureet Singh': {'balls': 430, 'wickets': 21.0},
#  'KW Richardson': {'balls': 345, 'wickets': 21.0},
#  'Shahbaz Ahmed': {'balls': 549, 'wickets': 21.0},
#  'BB Sran': {'balls': 516, 'wickets': 20.0},
#  'J Suchith': {'balls': 434, 'wickets': 20.0},
#  'Mujeeb Ur Rahman': {'balls': 452, 'wickets': 20.0},
#  'C Green': {'balls': 462, 'wickets': 20.0},
#  'VG Arora': {'balls': 418, 'wickets': 20.0},
#  'C Sakariya': {'balls': 460, 'wickets': 20.0},
#  'CH Gayle': {'balls': 584, 'wickets': 19.0},
#  'NT Ellis': {'balls': 365, 'wickets': 19.0},
#  'CRD Fernando': {'balls': 249, 'wickets': 19.0},
#  'AD Mascarenhas': {'balls': 310, 'wickets': 19.0},
#  'A Ashish Reddy': {'balls': 270, 'wickets': 19.0},
#  'IC Pandey': {'balls': 469, 'wickets': 19.0},
#  'BJ Hodge': {'balls': 238, 'wickets': 18.0},
#  'R Rampaul': {'balls': 278, 'wickets': 17.0},
#  'Vijaykumar Vyshak': {'balls': 243, 'wickets': 17.0},
#  'D Wiese': {'balls': 307, 'wickets': 17.0},
#  'LR Shukla': {'balls': 326, 'wickets': 17.0},
#  'Mukesh Choudhary': {'balls': 298, 'wickets': 16.0},
#  'AC Thomas': {'balls': 327, 'wickets': 16.0},
#  'ST Jayasuriya': {'balls': 301, 'wickets': 16.0},
#  'MJ Santner': {'balls': 370, 'wickets': 16.0},
#  'Kartik Tyagi': {'balls': 458, 'wickets': 16.0},
#  'VRV Singh': {'balls': 371, 'wickets': 16.0},
#  'RG Sharma': {'balls': 349, 'wickets': 16.0},
#  'CR Brathwaite': {'balls': 266, 'wickets': 16.0},
#  'SJ Srivastava': {'balls': 306, 'wickets': 15.0},
#  'YA Abdulla': {'balls': 222, 'wickets': 15.0},
#  'RR Powar': {'balls': 443, 'wickets': 15.0},
#  'AN Ahmed': {'balls': 362, 'wickets': 15.0},
#  'DR Sams': {'balls': 389, 'wickets': 15.0},
#  'Mohammad Nabi': {'balls': 419, 'wickets': 15.0},
#  'KR Sen': {'balls': 255, 'wickets': 14.0},
#  'JR Hopes': {'balls': 369, 'wickets': 14.0},
#  'Umar Gul': {'balls': 153, 'wickets': 14.0},
#  'Karanveer Singh': {'balls': 213, 'wickets': 14.0},
#  'Kamran Khan': {'balls': 177, 'wickets': 14.0},
#  'GD McGrath': {'balls': 329, 'wickets': 14.0},
#  'S Lamichhane': {'balls': 211, 'wickets': 14.0},
#  'AB McDonald': {'balls': 188, 'wickets': 14.0},
#  'R McLaren': {'balls': 372, 'wickets': 14.0},
#  'DJG Sammy': {'balls': 244, 'wickets': 14.0},
#  'CJ Anderson': {'balls': 315, 'wickets': 14.0},
#  'G Coetzee': {'balls': 216, 'wickets': 13.0},
#  'JDP Oram': {'balls': 244, 'wickets': 13.0},
#  'Joginder Sharma': {'balls': 272, 'wickets': 13.0},
#  'J Theron': {'balls': 235, 'wickets': 13.0},
#  'R Sai Kishore': {'balls': 191, 'wickets': 13.0},
#  'CK Langeveldt': {'balls': 165, 'wickets': 13.0},
#  'RS Bopara': {'balls': 213, 'wickets': 13.0},
#  'SM Pollock': {'balls': 280, 'wickets': 13.0},
#  'BA Bhatt': {'balls': 303, 'wickets': 13.0},
#  'TK Curran': {'balls': 252, 'wickets': 13.0},
#  'J Little': {'balls': 236, 'wickets': 13.0},
#  'SC Ganguly': {'balls': 280, 'wickets': 12.0},
#  'BCJ Cutting': {'balls': 288, 'wickets': 12.0},
#  'AG Murtaza': {'balls': 269, 'wickets': 12.0},
#  'Ankit Sharma': {'balls': 375, 'wickets': 12.0},
#  'V Shankar': {'balls': 258, 'wickets': 12.0},
#  'V Pratap Singh': {'balls': 211, 'wickets': 12.0},
#  'Abhishek Sharma': {'balls': 278, 'wickets': 11.0},
#  'OC McCoy': {'balls': 180, 'wickets': 11.0},
#  'KP Appanna': {'balls': 222, 'wickets': 11.0},
#  'Pankaj Singh': {'balls': 311, 'wickets': 11.0},
#  'PVD Chameera': {'balls': 297, 'wickets': 11.0},
#  'JL Pattinson': {'balls': 222, 'wickets': 11.0},
#  'S Badree': {'balls': 263, 'wickets': 11.0},
#  'MA Wood': {'balls': 127, 'wickets': 11.0},
#  'BE Hendricks': {'balls': 157, 'wickets': 11.0},
#  'A Chandila': {'balls': 234, 'wickets': 11.0},
#  'LS Livingstone': {'balls': 267, 'wickets': 11.0},
#  'Suyash Sharma': {'balls': 264, 'wickets': 11.0},
#  'JD Ryder': {'balls': 241, 'wickets': 11.0},
#  'Lalit Yadav': {'balls': 294, 'wickets': 11.0},
#  'TS Mills': {'balls': 218, 'wickets': 11.0},
#  'Simarjeet Singh': {'balls': 193, 'wickets': 10.0},
#  'K Kartikeya': {'balls': 241, 'wickets': 10.0},
#  'DJ Hussey': {'balls': 323, 'wickets': 10.0},
#  'N Rana': {'balls': 185, 'wickets': 10.0},
#  'KMA Paul': {'balls': 180, 'wickets': 10.0},
#  'B Laughlin': {'balls': 179, 'wickets': 10.0},
#  'MN Samuels': {'balls': 219, 'wickets': 10.0},
#  'J Syed Mohammad': {'balls': 196, 'wickets': 10.0},
#  'T Thushara': {'balls': 144, 'wickets': 10.0},
#  'Anand Rajan': {'balls': 162, 'wickets': 10.0},
#  'DJ Hooda': {'balls': 384, 'wickets': 10.0},
#  'BAW Mendis': {'balls': 248, 'wickets': 9.0},
#  'KA Jamieson': {'balls': 179, 'wickets': 9.0},
#  'SE Bond': {'balls': 191, 'wickets': 9.0},
#  'AF Milne': {'balls': 217, 'wickets': 9.0},
#  'SMSM Senanayake': {'balls': 195, 'wickets': 9.0},
#  'Mohammad Asif': {'balls': 199, 'wickets': 9.0},
#  'AM Nayar': {'balls': 239, 'wickets': 9.0},
#  'Shahid Afridi': {'balls': 185, 'wickets': 9.0},
#  'KP Pietersen': {'balls': 180, 'wickets': 9.0},
#  'Rasikh Salam': {'balls': 207, 'wickets': 9.0},
#  'J Yadav': {'balls': 398, 'wickets': 9.0},
#  'SB Styris': {'balls': 222, 'wickets': 9.0},
#  'IS Sodhi': {'balls': 182, 'wickets': 9.0},
#  'JEC Franklin': {'balls': 155, 'wickets': 9.0},
#  'P Parameswaran': {'balls': 159, 'wickets': 9.0},
#  'I Udana': {'balls': 182, 'wickets': 8.0},
#  'N Thushara': {'balls': 172, 'wickets': 8.0},
#  'S Sandeep Warrier': {'balls': 176, 'wickets': 8.0},
#  'Akash Deep': {'balls': 175, 'wickets': 8.0},
#  'S Randiv': {'balls': 180, 'wickets': 8.0},
#  'A Mithun': {'balls': 312, 'wickets': 8.0},
#  'GC Viljoen': {'balls': 146, 'wickets': 8.0},
#  'MP Yadav': {'balls': 76, 'wickets': 8.0},
#  'AA Chavan': {'balls': 255, 'wickets': 8.0},
#  'M Ntini': {'balls': 213, 'wickets': 8.0},
#  'JDS Neesham': {'balls': 222, 'wickets': 8.0},
#  'KC Cariappa': {'balls': 224, 'wickets': 8.0},
#  'AM Salvi': {'balls': 156, 'wickets': 7.0},
#  'RR Raje': {'balls': 144, 'wickets': 7.0},
#  'TL Suman': {'balls': 152, 'wickets': 7.0},
#  'N Burger': {'balls': 105, 'wickets': 7.0},
#  'B Akhil': {'balls': 193, 'wickets': 7.0},
#  'PC Valthaty': {'balls': 153, 'wickets': 7.0},
#  'Y Venugopal Rao': {'balls': 222, 'wickets': 7.0},
#  'Swapnil Singh': {'balls': 165, 'wickets': 7.0},
#  'D Pretorius': {'balls': 166, 'wickets': 7.0},
#  'C de Grandhomme': {'balls': 230, 'wickets': 7.0},
#  'R Shukla': {'balls': 130, 'wickets': 7.0},
#  'P Amarnath': {'balls': 132, 'wickets': 7.0},
#  'HF Gurney': {'balls': 169, 'wickets': 7.0},
#  'KM Asif': {'balls': 143, 'wickets': 7.0},
#  'DJ Willey': {'balls': 221, 'wickets': 7.0},
#  'B Stanlake': {'balls': 150, 'wickets': 7.0},
#  'OF Smith': {'balls': 95, 'wickets': 7.0},
#  'FH Edwards': {'balls': 150, 'wickets': 6.0},
#  'V Sehwag': {'balls': 138, 'wickets': 6.0},
#  'KMDN Kulasekara': {'balls': 107, 'wickets': 6.0},
#  'Ramandeep Singh': {'balls': 45, 'wickets': 6.0},
#  'AS Roy': {'balls': 142, 'wickets': 6.0},
#  'RV Gomez': {'balls': 97, 'wickets': 6.0},
#  'JE Taylor': {'balls': 122, 'wickets': 6.0},
#  'S Narwal': {'balls': 113, 'wickets': 6.0},
#  'R Shepherd': {'balls': 133, 'wickets': 6.0},
#  'S Dube': {'balls': 117, 'wickets': 6.0},
#  'S Kaushik': {'balls': 210, 'wickets': 6.0},
#  'VS Malik': {'balls': 212, 'wickets': 6.0},
#  'Fazalhaq Farooqi': {'balls': 162, 'wickets': 6.0},
#  'Jaskaran Singh': {'balls': 111, 'wickets': 6.0},
#  'M de Lange': {'balls': 116, 'wickets': 6.0},
#  'DG Nalkande': {'balls': 89, 'wickets': 6.0},
#  'S Tyagi': {'balls': 220, 'wickets': 6.0},
#  'MG Bracewell': {'balls': 66, 'wickets': 6.0},
#  'SB Bangar': {'balls': 153, 'wickets': 6.0},
#  'Arshad Khan': {'balls': 153, 'wickets': 6.0},
#  'SS Cottrell': {'balls': 131, 'wickets': 6.0},
#  'R Sathish': {'balls': 144, 'wickets': 6.0},
#  'A Choudhary': {'balls': 108, 'wickets': 5.0},
#  'RJW Topley': {'balls': 107, 'wickets': 5.0},
#  'V Kohli': {'balls': 264, 'wickets': 5.0},
#  'TM Dilshan': {'balls': 275, 'wickets': 5.0},
#  'Shoaib Akhtar': {'balls': 46, 'wickets': 5.0},
#  'Shoaib Ahmed': {'balls': 103, 'wickets': 5.0},
#  'SB Wagh': {'balls': 108, 'wickets': 5.0},
#  'S Ladda': {'balls': 141, 'wickets': 5.0},
#  'O Thomas': {'balls': 63, 'wickets': 5.0},
#  'PD Collingwood': {'balls': 90, 'wickets': 5.0},
#  'R Parag': {'balls': 181, 'wickets': 5.0},
#  'AP Dole': {'balls': 73, 'wickets': 5.0},
#  'KL Nagarkoti': {'balls': 185, 'wickets': 5.0},
#  'Gurkeerat Singh': {'balls': 82, 'wickets': 5.0},
#  'HR Shokeen': {'balls': 213, 'wickets': 5.0},
#  'K Khejroliya': {'balls': 129, 'wickets': 5.0},
#  'L Ablish': {'balls': 45, 'wickets': 5.0},
#  'Akash Singh': {'balls': 141, 'wickets': 5.0},
#  'S Dhawan': {'balls': 49, 'wickets': 4.0},
#  'DJ Muthuswami': {'balls': 84, 'wickets': 4.0},
#  'Nithish Kumar Reddy': {'balls': 118, 'wickets': 4.0},
#  'WA Mota': {'balls': 75, 'wickets': 4.0},
#  'SH Johnson': {'balls': 99, 'wickets': 4.0},
#  'Ankit Soni': {'balls': 112, 'wickets': 4.0},
#  'LE Plunkett': {'balls': 154, 'wickets': 4.0},
#  'D du Preez': {'balls': 43, 'wickets': 4.0},
#  'Arjun Tendulkar': {'balls': 83, 'wickets': 4.0},
#  'Parvez Rasool': {'balls': 200, 'wickets': 4.0},
#  'DP Vijaykumar': {'balls': 159, 'wickets': 4.0},
#  'Shivam Sharma': {'balls': 114, 'wickets': 4.0},
#  'Y Nagar': {'balls': 72, 'wickets': 4.0},
#  'Yudhvir Singh': {'balls': 74, 'wickets': 4.0},
#  'Azmatullah Omarzai': {'balls': 131, 'wickets': 4.0},
#  'T Stubbs': {'balls': 25, 'wickets': 4.0},
#  'GHS Garton': {'balls': 97, 'wickets': 3.0},
#  'T Shamsi': {'balls': 120, 'wickets': 3.0},
#  'JA Richardson': {'balls': 94, 'wickets': 3.0},
#  'SM Harwood': {'balls': 67, 'wickets': 3.0},
#  'DAJ Bracewell': {'balls': 25, 'wickets': 3.0},
#  'Sikandar Raza': {'balls': 88, 'wickets': 3.0},
#  'A Uniyal': {'balls': 38, 'wickets': 3.0},
#  'MJ Clarke': {'balls': 66, 'wickets': 3.0},
#  'TM Head': {'balls': 58, 'wickets': 3.0},
#  'DJ Thornely': {'balls': 44, 'wickets': 3.0},
#  'MJ Henry': {'balls': 105, 'wickets': 3.0},
#  'SM Boland': {'balls': 43, 'wickets': 3.0},
#  'Gagandeep Singh': {'balls': 84, 'wickets': 3.0},
#  'AL Menaria': {'balls': 113, 'wickets': 3.0},
#  'RS Hangargekar': {'balls': 43, 'wickets': 3.0},
#  'VR Iyer': {'balls': 84, 'wickets': 3.0},
#  'Sachin Baby': {'balls': 10, 'wickets': 3.0},
#  'RJ Peterson': {'balls': 48, 'wickets': 3.0},
#  'JM Kemp': {'balls': 47, 'wickets': 3.0},
#  'P Sahu': {'balls': 107, 'wickets': 3.0},
#  'K Santokie': {'balls': 51, 'wickets': 3.0},
#  'RN ten Doeschate': {'balls': 83, 'wickets': 3.0},
#  'JJ van der Wath': {'balls': 76, 'wickets': 3.0},
#  'R Ninan': {'balls': 36, 'wickets': 3.0},
#  'JW Hastings': {'balls': 61, 'wickets': 3.0},
#  'JPR Scantlebury-Searles': {'balls': 45, 'wickets': 2.0},
#  'MA Khote': {'balls': 30, 'wickets': 2.0},
#  'Shoaib Malik': {'balls': 58, 'wickets': 2.0},
#  'A Badoni': {'balls': 25, 'wickets': 2.0},
#  'V Kaverappa': {'balls': 24, 'wickets': 2.0},
#  'A Flintoff': {'balls': 66, 'wickets': 2.0},
#  'D Kalyankrishna': {'balls': 50, 'wickets': 2.0},
#  'A Kamboj': {'balls': 68, 'wickets': 2.0},
#  'LJ Wright': {'balls': 75, 'wickets': 2.0},
#  'WG Jacks': {'balls': 55, 'wickets': 2.0},
#  'K Yadav': {'balls': 54, 'wickets': 2.0},
#  'KA Maharaj': {'balls': 36, 'wickets': 2.0},
#  'C Nanda': {'balls': 50, 'wickets': 2.0},
#  'KJ Abbott': {'balls': 102, 'wickets': 2.0},
#  'FA Allen': {'balls': 91, 'wickets': 2.0},
#  'MK Lomror': {'balls': 94, 'wickets': 2.0},
#  'B Geeves': {'balls': 49, 'wickets': 2.0},
#  'PH Solanki': {'balls': 36, 'wickets': 2.0},
#  'Abdul Samad': {'balls': 55, 'wickets': 2.0},
#  'GD Phillips': {'balls': 31, 'wickets': 2.0},
#  'SC Kuggeleijn': {'balls': 50, 'wickets': 2.0},
#  'SD Chitnis': {'balls': 38, 'wickets': 2.0},
#  'DNT Zoysa': {'balls': 69, 'wickets': 2.0},
#  'Mohammad Hafeez': {'balls': 63, 'wickets': 2.0},
#  'P Suyal': {'balls': 107, 'wickets': 2.0},
#  'Mayank Dagar': {'balls': 138, 'wickets': 2.0},
#  'AK Markram': {'balls': 123, 'wickets': 2.0},
#  'ND Doshi': {'balls': 57, 'wickets': 2.0},
#  'AU Rashid': {'balls': 60, 'wickets': 2.0},
#  'Y Prithvi Raj': {'balls': 33, 'wickets': 1.0},
#  'S Vidyut': {'balls': 13, 'wickets': 1.0},
#  'IC Porel': {'balls': 26, 'wickets': 1.0},
#  'RJ Gleeson': {'balls': 51, 'wickets': 1.0},
#  'KT Maphaka': {'balls': 39, 'wickets': 1.0},
#  'SA Abbott': {'balls': 59, 'wickets': 1.0},
#  'V Viyaskanth': {'balls': 60, 'wickets': 1.0},
#  'GS Sandhu': {'balls': 48, 'wickets': 1.0},
#  'DJM Short': {'balls': 18, 'wickets': 1.0},
#  'CJ McKay': {'balls': 42, 'wickets': 1.0},
#  'A Nel': {'balls': 18, 'wickets': 1.0},
#  'AM Rahane': {'balls': 6, 'wickets': 1.0},
#  'D Jansen': {'balls': 28, 'wickets': 1.0},
#  'CL White': {'balls': 46, 'wickets': 1.0},
#  'P Dubey': {'balls': 67, 'wickets': 1.0},
#  'R Powell': {'balls': 21, 'wickets': 1.0},
#  'DJ Mitchell': {'balls': 51, 'wickets': 1.0},
#  'GR Napier': {'balls': 24, 'wickets': 1.0},
#  'AJ Finch': {'balls': 44, 'wickets': 1.0},
#  'AJ Hosein': {'balls': 24, 'wickets': 1.0},
#  'PM Sarvesh Kumar': {'balls': 31, 'wickets': 1.0},
#  'MK Tiwary': {'balls': 45, 'wickets': 1.0},
#  'NB Singh': {'balls': 25, 'wickets': 1.0},
#  'SB Joshi': {'balls': 55, 'wickets': 1.0},
#  'L Wood': {'balls': 38, 'wickets': 1.0},
#  'AA Kazi': {'balls': 13, 'wickets': 1.0},
#  'RG More': {'balls': 37, 'wickets': 1.0},
#  'SSB Magala': {'balls': 37, 'wickets': 1.0},
#  'AA Jhunjhunwala': {'balls': 88, 'wickets': 1.0},
#  'Shashank Singh': {'balls': 19, 'wickets': 1.0},
#  'SS Sarkar': {'balls': 25, 'wickets': 1.0},
#  'SS Mundhe': {'balls': 7, 'wickets': 1.0},
#  'Mashrafe Mortaza': {'balls': 28, 'wickets': 1.0},
#  'M Siddharth': {'balls': 58, 'wickets': 1.0},
#  'SS Agarwal': {'balls': 24, 'wickets': 1.0},
#  'AA Noffke': {'balls': 25, 'wickets': 1.0},
#  'BMAJ Mendis': {'balls': 30, 'wickets': 1.0},
#  'GH Vihari': {'balls': 43, 'wickets': 1.0},
#  'D Salunkhe': {'balls': 51, 'wickets': 1.0},
#  'T Henderson': {'balls': 36, 'wickets': 1.0},
#  'LMP Simmons': {'balls': 18, 'wickets': 1.0},
#  'AC Gilchrist': {'balls': 1, 'wickets': 1.0},
#  'AC Voges': {'balls': 56, 'wickets': 1.0},
#  'FY Fazal': {'balls': 12, 'wickets': 1.0},
#  'SE Rutherford': {'balls': 46, 'wickets': 1.0},
#  'LI Meriwala': {'balls': 19, 'wickets': 1.0},
#  'DB Ravi Teja': {'balls': 18, 'wickets': 1.0},
#  'TP Sudhindra': {'balls': 74, 'wickets': 1.0},
#  'LB Williams': {'balls': 42, 'wickets': 1.0},
#  'LA Carseldine': {'balls': 7, 'wickets': 1.0},
#  'D Brevis': {'balls': 3, 'wickets': 1.0}}

# %%
top_players('batter')
# Out:
# {'J Fraser-McGurk': {'runs': 330, 'balls': 150, 'strike_rate': 220.0},
#  'Shahid Afridi': {'runs': 81, 'balls': 46, 'strike_rate': 176.09},
#  'WG Jacks': {'runs': 230, 'balls': 133, 'strike_rate': 172.93},
#  'PD Salt': {'runs': 653, 'balls': 385, 'strike_rate': 169.61},
#  'T Stubbs': {'runs': 405, 'balls': 239, 'strike_rate': 169.46},
#  'R Shepherd': {'runs': 115, 'balls': 68, 'strike_rate': 169.12},
#  'TM Head': {'runs': 772, 'balls': 458, 'strike_rate': 168.56},
#  'LJ Wright': {'runs': 106, 'balls': 63, 'strike_rate': 168.25},
#  'Naman Dhir': {'runs': 140, 'balls': 84, 'strike_rate': 166.67},
#  'KK Cooper': {'runs': 116, 'balls': 70, 'strike_rate': 165.71},
#  'AD Russell': {'runs': 2488, 'balls': 1515, 'strike_rate': 164.22},
#  'Kamran Akmal': {'runs': 128, 'balls': 78, 'strike_rate': 164.1},
#  'Avesh Khan': {'runs': 41, 'balls': 25, 'strike_rate': 164.0},
#  'BCJ Cutting': {'runs': 238, 'balls': 146, 'strike_rate': 163.01},
#  'H Klaasen': {'runs': 993, 'balls': 613, 'strike_rate': 161.99},
#  'Ramandeep Singh': {'runs': 170, 'balls': 106, 'strike_rate': 160.38},
#  'Ashutosh Sharma': {'runs': 189, 'balls': 118, 'strike_rate': 160.17},
#  'TH David': {'runs': 659, 'balls': 417, 'strike_rate': 158.03},
#  'D Pretorius': {'runs': 44, 'balls': 28, 'strike_rate': 157.14},
#  'SB Dubey': {'runs': 33, 'balls': 21, 'strike_rate': 157.14},
#  'SP Narine': {'runs': 1534, 'balls': 984, 'strike_rate': 155.89},
#  'Shashank Singh': {'runs': 423, 'balls': 272, 'strike_rate': 155.51},
#  'K Gowtham': {'runs': 247, 'balls': 159, 'strike_rate': 155.35},
#  'N Pooran': {'runs': 1769, 'balls': 1143, 'strike_rate': 154.77},
#  'LS Livingstone': {'runs': 939, 'balls': 609, 'strike_rate': 154.19},
#  'Rashid Khan': {'runs': 545, 'balls': 355, 'strike_rate': 153.52},
#  'R Ravindra': {'runs': 222, 'balls': 146, 'strike_rate': 152.05},
#  'CR Brathwaite': {'runs': 181, 'balls': 120, 'strike_rate': 150.83},
#  'Bipul Sharma': {'runs': 187, 'balls': 124, 'strike_rate': 150.81},
#  'JC Archer': {'runs': 199, 'balls': 132, 'strike_rate': 150.76},
#  'GJ Maxwell': {'runs': 2772, 'balls': 1842, 'strike_rate': 150.49},
#  'AUK Pathan': {'runs': 39, 'balls': 26, 'strike_rate': 150.0},
#  'C Green': {'runs': 707, 'balls': 472, 'strike_rate': 149.79},
#  'CH Morris': {'runs': 618, 'balls': 413, 'strike_rate': 149.64},
#  'RM Patidar': {'runs': 799, 'balls': 534, 'strike_rate': 149.63},
#  'A Raghuvanshi': {'runs': 163, 'balls': 109, 'strike_rate': 149.54},
#  'Abhishek Sharma': {'runs': 1377, 'balls': 925, 'strike_rate': 148.86},
#  'V Sehwag': {'runs': 2728, 'balls': 1833, 'strike_rate': 148.83},
#  'AB de Villiers': {'runs': 5181, 'balls': 3487, 'strike_rate': 148.58},
#  'LPC Silva': {'runs': 40, 'balls': 27, 'strike_rate': 148.15},
#  'AP Dole': {'runs': 34, 'balls': 23, 'strike_rate': 147.83},
#  'Abishek Porel': {'runs': 360, 'balls': 244, 'strike_rate': 147.54},
#  'RR Rossouw': {'runs': 473, 'balls': 321, 'strike_rate': 147.35},
#  'YBK Jaiswal': {'runs': 1607, 'balls': 1095, 'strike_rate': 146.76},
#  'Dhruv Jurel': {'runs': 347, 'balls': 237, 'strike_rate': 146.41},
#  'SD Hope': {'runs': 183, 'balls': 125, 'strike_rate': 146.4},
#  'JM Sharma': {'runs': 730, 'balls': 501, 'strike_rate': 145.71},
#  'SO Hetmyer': {'runs': 1243, 'balls': 854, 'strike_rate': 145.55},
#  'RR Pant': {'runs': 3297, 'balls': 2296, 'strike_rate': 143.6},
#  'PJ Cummins': {'runs': 515, 'balls': 359, 'strike_rate': 143.45},
#  'Arshad Khan': {'runs': 96, 'balls': 67, 'strike_rate': 143.28},
#  'PP Shaw': {'runs': 1892, 'balls': 1321, 'strike_rate': 143.22},
#  'P Simran Singh': {'runs': 756, 'balls': 528, 'strike_rate': 143.18},
#  'A Ashish Reddy': {'runs': 280, 'balls': 196, 'strike_rate': 142.86},
#  'MF Maharoof': {'runs': 177, 'balls': 124, 'strike_rate': 142.74},
#  'Misbah-ul-Haq': {'runs': 117, 'balls': 82, 'strike_rate': 142.68},
#  'SA Yadav': {'runs': 3594, 'balls': 2522, 'strike_rate': 142.51},
#  'JC Buttler': {'runs': 3583, 'balls': 2519, 'strike_rate': 142.24},
#  'CH Gayle': {'runs': 4997, 'balls': 3516, 'strike_rate': 142.12},
#  'Abdul Samad': {'runs': 579, 'balls': 408, 'strike_rate': 141.91},
#  'R Powell': {'runs': 360, 'balls': 254, 'strike_rate': 141.73},
#  'LH Ferguson': {'runs': 68, 'balls': 48, 'strike_rate': 141.67},
#  'D Wiese': {'runs': 148, 'balls': 105, 'strike_rate': 140.95},
#  'Vivrant Sharma': {'runs': 69, 'balls': 49, 'strike_rate': 140.82},
#  'Mohammad Nabi': {'runs': 221, 'balls': 157, 'strike_rate': 140.76},
#  'KA Pollard': {'runs': 3437, 'balls': 2447, 'strike_rate': 140.46},
#  'MJ Lumb': {'runs': 278, 'balls': 198, 'strike_rate': 140.4},
#  'JM Bairstow': {'runs': 1589, 'balls': 1132, 'strike_rate': 140.37},
#  'HH Pandya': {'runs': 2534, 'balls': 1814, 'strike_rate': 139.69},
#  'Atharva Taide': {'runs': 247, 'balls': 177, 'strike_rate': 139.55},
#  'S Dube': {'runs': 1502, 'balls': 1077, 'strike_rate': 139.46},
#  'Tilak Varma': {'runs': 1156, 'balls': 830, 'strike_rate': 139.28},
#  'Sunny Singh': {'runs': 43, 'balls': 31, 'strike_rate': 138.71},
#  'DP Conway': {'runs': 924, 'balls': 669, 'strike_rate': 138.12},
#  'YK Pathan': {'runs': 3222, 'balls': 2334, 'strike_rate': 138.05},
#  'HM Amla': {'runs': 577, 'balls': 418, 'strike_rate': 138.04},
#  'PBB Rajapaksa': {'runs': 277, 'balls': 201, 'strike_rate': 137.81},
#  'MJ Guptill': {'runs': 271, 'balls': 197, 'strike_rate': 137.56},
#  'D Salunkhe': {'runs': 33, 'balls': 24, 'strike_rate': 137.5},
#  'KR Mayers': {'runs': 379, 'balls': 276, 'strike_rate': 137.32},
#  'Nithish Kumar Reddy': {'runs': 303, 'balls': 221, 'strike_rate': 137.1},
#  'RN ten Doeschate': {'runs': 326, 'balls': 238, 'strike_rate': 136.97},
#  'JA Morkel': {'runs': 975, 'balls': 712, 'strike_rate': 136.94},
#  'MM Ali': {'runs': 1162, 'balls': 849, 'strike_rate': 136.87},
#  'MP Stoinis': {'runs': 1866, 'balls': 1366, 'strike_rate': 136.6},
#  'RK Singh': {'runs': 893, 'balls': 654, 'strike_rate': 136.54},
#  'CA Lynn': {'runs': 1329, 'balls': 974, 'strike_rate': 136.45},
#  'RA Tripathi': {'runs': 2236, 'balls': 1650, 'strike_rate': 135.52},
#  'M Morkel': {'runs': 126, 'balls': 93, 'strike_rate': 135.48},
#  'MK Lomror': {'runs': 527, 'balls': 389, 'strike_rate': 135.48},
#  'DA Warner': {'runs': 6567, 'balls': 4849, 'strike_rate': 135.43},
#  'SV Samson': {'runs': 4419, 'balls': 3270, 'strike_rate': 135.14},
#  'DA Miller': {'runs': 2924, 'balls': 2171, 'strike_rate': 134.68},
#  'SN Thakur': {'runs': 307, 'balls': 228, 'strike_rate': 134.65},
#  'PVD Chameera': {'runs': 43, 'balls': 32, 'strike_rate': 134.38},
#  'B Sai Sudharsan': {'runs': 1034, 'balls': 770, 'strike_rate': 134.29},
#  'SR Watson': {'runs': 3880, 'balls': 2892, 'strike_rate': 134.16},
#  'N Wadhera': {'runs': 350, 'balls': 261, 'strike_rate': 134.1},
#  'ST Jayasuriya': {'runs': 768, 'balls': 573, 'strike_rate': 134.03},
#  'M Shahrukh Khan': {'runs': 553, 'balls': 413, 'strike_rate': 133.9},
#  'RD Gaikwad': {'runs': 2380, 'balls': 1781, 'strike_rate': 133.63},
#  'JJ Roy': {'runs': 614, 'balls': 460, 'strike_rate': 133.48},
#  'AN Ahmed': {'runs': 36, 'balls': 27, 'strike_rate': 133.33},
#  'B Akhil': {'runs': 76, 'balls': 57, 'strike_rate': 133.33},
#  'F du Plessis': {'runs': 4571, 'balls': 3435, 'strike_rate': 133.07},
#  'AC Gilchrist': {'runs': 2069, 'balls': 1555, 'strike_rate': 133.05},
#  'MS Dhoni': {'runs': 5243, 'balls': 3947, 'strike_rate': 132.84},
#  'Ishan Kishan': {'runs': 2644, 'balls': 1991, 'strike_rate': 132.8},
#  'JR Hopes': {'runs': 417, 'balls': 314, 'strike_rate': 132.8},
#  'VR Iyer': {'runs': 1326, 'balls': 1000, 'strike_rate': 132.6},
#  'SK Raina': {'runs': 5536, 'balls': 4177, 'strike_rate': 132.54},
#  'C de Grandhomme': {'runs': 303, 'balls': 229, 'strike_rate': 132.31},
#  'DR Smith': {'runs': 2385, 'balls': 1803, 'strike_rate': 132.28},
#  'Shubman Gill': {'runs': 3216, 'balls': 2432, 'strike_rate': 132.24},
#  'BJ Rohrer': {'runs': 193, 'balls': 146, 'strike_rate': 132.19},
#  'KP Pietersen': {'runs': 1001, 'balls': 758, 'strike_rate': 132.06},
#  'ML Hayden': {'runs': 1107, 'balls': 839, 'strike_rate': 131.94},
#  'AC Blizzard': {'runs': 120, 'balls': 91, 'strike_rate': 131.87},
#  'KD Karthik': {'runs': 4843, 'balls': 3687, 'strike_rate': 131.35},
#  'SM Curran': {'runs': 883, 'balls': 673, 'strike_rate': 131.2},
#  'DL Chahar': {'runs': 80, 'balls': 61, 'strike_rate': 131.15},
#  'Q de Kock': {'runs': 3160, 'balls': 2410, 'strike_rate': 131.12},
#  'E Lewis': {'runs': 654, 'balls': 499, 'strike_rate': 131.06},
#  'KL Rahul': {'runs': 4689, 'balls': 3578, 'strike_rate': 131.05},
#  'Harbhajan Singh': {'runs': 833, 'balls': 636, 'strike_rate': 130.97},
#  'N Rana': {'runs': 2636, 'balls': 2015, 'strike_rate': 130.82},
#  'A Mithun': {'runs': 34, 'balls': 26, 'strike_rate': 130.77},
#  'D Brevis': {'runs': 230, 'balls': 176, 'strike_rate': 130.68},
#  'MS Gony': {'runs': 99, 'balls': 76, 'strike_rate': 130.26},
#  'BA Stokes': {'runs': 935, 'balls': 718, 'strike_rate': 130.22},
#  'SE Marsh': {'runs': 2489, 'balls': 1913, 'strike_rate': 130.11},
#  'NLTC Perera': {'runs': 424, 'balls': 326, 'strike_rate': 130.06},
#  'JP Faulkner': {'runs': 527, 'balls': 406, 'strike_rate': 129.8},
#  'JD Ryder': {'runs': 604, 'balls': 466, 'strike_rate': 129.61},
#  'PN Mankad': {'runs': 97, 'balls': 75, 'strike_rate': 129.33},
#  'R Parag': {'runs': 1173, 'balls': 909, 'strike_rate': 129.04},
#  'R Tewatia': {'runs': 1013, 'balls': 788, 'strike_rate': 128.55},
#  'V Kohli': {'runs': 8014, 'balls': 6236, 'strike_rate': 128.51},
#  'SN Khan': {'runs': 585, 'balls': 456, 'strike_rate': 128.29},
#  'MA Agarwal': {'runs': 2669, 'balls': 2081, 'strike_rate': 128.26},
#  'DJ Mitchell': {'runs': 351, 'balls': 274, 'strike_rate': 128.1},
#  'KH Pandya': {'runs': 1647, 'balls': 1287, 'strike_rate': 127.97},
#  'RG Sharma': {'runs': 6630, 'balls': 5183, 'strike_rate': 127.92},
#  'PD Collingwood': {'runs': 203, 'balls': 159, 'strike_rate': 127.67},
#  'A Manohar': {'runs': 231, 'balls': 181, 'strike_rate': 127.62},
#  'S Narwal': {'runs': 37, 'balls': 29, 'strike_rate': 127.59},
#  'Sikandar Raza': {'runs': 182, 'balls': 143, 'strike_rate': 127.27},
#  'TR Birt': {'runs': 75, 'balls': 59, 'strike_rate': 127.12},
#  'BB McCullum': {'runs': 2882, 'balls': 2272, 'strike_rate': 126.85},
#  'Rahmanullah Gurbaz': {'runs': 289, 'balls': 228, 'strike_rate': 126.75},
#  'SM Pollock': {'runs': 147, 'balls': 116, 'strike_rate': 126.72},
#  'AC Voges': {'runs': 181, 'balls': 143, 'strike_rate': 126.57},
#  'AK Markram': {'runs': 995, 'balls': 787, 'strike_rate': 126.43},
#  'SM Katich': {'runs': 241, 'balls': 191, 'strike_rate': 126.18},
#  'RV Uthappa': {'runs': 4954, 'balls': 3927, 'strike_rate': 126.15},
#  'Ankit Sharma': {'runs': 87, 'balls': 69, 'strike_rate': 126.09},
#  'S Vidyut': {'runs': 145, 'balls': 115, 'strike_rate': 126.09},
#  'SW Billings': {'runs': 503, 'balls': 399, 'strike_rate': 126.07},
#  'STR Binny': {'runs': 880, 'balls': 700, 'strike_rate': 125.71},
#  'A Badoni': {'runs': 634, 'balls': 505, 'strike_rate': 125.54},
#  'KK Nair': {'runs': 1496, 'balls': 1192, 'strike_rate': 125.5},
#  'M Vohra': {'runs': 1083, 'balls': 863, 'strike_rate': 125.49},
#  'CL White': {'runs': 971, 'balls': 774, 'strike_rate': 125.45},
#  'AR Patel': {'runs': 1653, 'balls': 1318, 'strike_rate': 125.42},
#  'DJ Hooda': {'runs': 1466, 'balls': 1170, 'strike_rate': 125.3},
#  'V Shankar': {'runs': 1115, 'balls': 890, 'strike_rate': 125.28},
#  'DJ Bravo': {'runs': 1560, 'balls': 1247, 'strike_rate': 125.1},
#  'MR Marsh': {'runs': 665, 'balls': 532, 'strike_rate': 125.0},
#  'OA Shah': {'runs': 506, 'balls': 405, 'strike_rate': 124.94},
#  'MC Henriques': {'runs': 1000, 'balls': 801, 'strike_rate': 124.84},
#  'SPD Smith': {'runs': 2495, 'balls': 1999, 'strike_rate': 124.81},
#  'Yuvraj Singh': {'runs': 2754, 'balls': 2207, 'strike_rate': 124.78},
#  'Azhar Mahmood': {'runs': 388, 'balls': 311, 'strike_rate': 124.76},
#  'A Symonds': {'runs': 974, 'balls': 781, 'strike_rate': 124.71},
#  'AT Rayudu': {'runs': 4348, 'balls': 3490, 'strike_rate': 124.58},
#  'RA Jadeja': {'runs': 2959, 'balls': 2378, 'strike_rate': 124.43},
#  'AD Hales': {'runs': 148, 'balls': 119, 'strike_rate': 124.37},
#  'WP Saha': {'runs': 2934, 'balls': 2368, 'strike_rate': 123.9},
#  'MV Boucher': {'runs': 394, 'balls': 318, 'strike_rate': 123.9},
#  'MN van Wyk': {'runs': 167, 'balls': 135, 'strike_rate': 123.7},
#  'Azmatullah Omarzai': {'runs': 42, 'balls': 34, 'strike_rate': 123.53},
#  'S Dhawan': {'runs': 6769, 'balls': 5483, 'strike_rate': 123.45},
#  'CJ Anderson': {'runs': 538, 'balls': 436, 'strike_rate': 123.39},
#  'AJ Finch': {'runs': 2092, 'balls': 1696, 'strike_rate': 123.35},
#  'SS Iyer': {'runs': 3131, 'balls': 2545, 'strike_rate': 123.03},
#  'KS Williamson': {'runs': 2132, 'balls': 1734, 'strike_rate': 122.95},
#  'C Munro': {'runs': 177, 'balls': 144, 'strike_rate': 122.92},
#  'LMP Simmons': {'runs': 1079, 'balls': 878, 'strike_rate': 122.89},
#  'AS Yadav': {'runs': 49, 'balls': 40, 'strike_rate': 122.5},
#  'B Lee': {'runs': 124, 'balls': 102, 'strike_rate': 121.57},
#  'BJ Hodge': {'runs': 1400, 'balls': 1153, 'strike_rate': 121.42},
#  'P Negi': {'runs': 365, 'balls': 301, 'strike_rate': 121.26},
#  'UT Khawaja': {'runs': 127, 'balls': 105, 'strike_rate': 120.95},
#  'AD Mathews': {'runs': 724, 'balls': 599, 'strike_rate': 120.87},
#  'JP Duminy': {'runs': 2029, 'balls': 1680, 'strike_rate': 120.77},
#  'AM Rahane': {'runs': 4642, 'balls': 3858, 'strike_rate': 120.32},
#  'LA Pomersbach': {'runs': 302, 'balls': 251, 'strike_rate': 120.32},
#  'Mandeep Singh': {'runs': 1706, 'balls': 1418, 'strike_rate': 120.31},
#  'SA Asnodkar': {'runs': 423, 'balls': 352, 'strike_rate': 120.17},
#  'GJ Bailey': {'runs': 663, 'balls': 552, 'strike_rate': 120.11},
#  'DJ Hussey': {'runs': 1322, 'balls': 1101, 'strike_rate': 120.07},
#  'LRPL Taylor': {'runs': 1017, 'balls': 847, 'strike_rate': 120.07},
#  'Joginder Sharma': {'runs': 36, 'balls': 30, 'strike_rate': 120.0},
#  'MEK Hussey': {'runs': 1977, 'balls': 1648, 'strike_rate': 119.96},
#  'DH Yagnik': {'runs': 170, 'balls': 142, 'strike_rate': 119.72},
#  'G Gambhir': {'runs': 4217, 'balls': 3524, 'strike_rate': 119.67},
#  'Shakib Al Hasan': {'runs': 795, 'balls': 665, 'strike_rate': 119.55},
#  'HC Brook': {'runs': 190, 'balls': 159, 'strike_rate': 119.5},
#  'AB McDonald': {'runs': 123, 'balls': 103, 'strike_rate': 119.42},
#  'KM Jadhav': {'runs': 1208, 'balls': 1012, 'strike_rate': 119.37},
#  'JO Holder': {'runs': 259, 'balls': 217, 'strike_rate': 119.35},
#  'T Taibu': {'runs': 31, 'balls': 26, 'strike_rate': 119.23},
#  'EJG Morgan': {'runs': 1406, 'balls': 1181, 'strike_rate': 119.05},
#  'AP Tare': {'runs': 339, 'balls': 285, 'strike_rate': 118.95},
#  'Anmolpreet Singh': {'runs': 139, 'balls': 117, 'strike_rate': 118.8},
#  'DPMD Jayawardene': {'runs': 1808, 'balls': 1522, 'strike_rate': 118.79},
#  'M Vijay': {'runs': 2619, 'balls': 2208, 'strike_rate': 118.61},
#  'Sameer Rizvi': {'runs': 51, 'balls': 43, 'strike_rate': 118.6},
#  'KC Sangakkara': {'runs': 1687, 'balls': 1424, 'strike_rate': 118.47},
#  'KS Bharat': {'runs': 199, 'balls': 168, 'strike_rate': 118.45},
#  'MG Bracewell': {'runs': 58, 'balls': 49, 'strike_rate': 118.37},
#  'S Sohal': {'runs': 368, 'balls': 311, 'strike_rate': 118.33},
#  'GD Phillips': {'runs': 65, 'balls': 55, 'strike_rate': 118.18},
#  'KA Jamieson': {'runs': 65, 'balls': 55, 'strike_rate': 118.18},
#  'MW Short': {'runs': 117, 'balls': 99, 'strike_rate': 118.18},
#  'R Bhatia': {'runs': 342, 'balls': 290, 'strike_rate': 117.93},
#  'D Padikkal': {'runs': 1559, 'balls': 1323, 'strike_rate': 117.84},
#  'TK Curran': {'runs': 127, 'balls': 108, 'strike_rate': 117.59},
#  'DJG Sammy': {'runs': 295, 'balls': 251, 'strike_rate': 117.53},
#  'MK Pandey': {'runs': 3859, 'balls': 3288, 'strike_rate': 117.37},
#  'Gurkeerat Singh': {'runs': 511, 'balls': 436, 'strike_rate': 117.2},
#  'Sachin Baby': {'runs': 144, 'balls': 123, 'strike_rate': 117.07},
#  'PC Valthaty': {'runs': 505, 'balls': 432, 'strike_rate': 116.9},
#  'IK Pathan': {'runs': 1150, 'balls': 985, 'strike_rate': 116.75},
#  'PA Patel': {'runs': 2848, 'balls': 2442, 'strike_rate': 116.63},
#  'MJ McClenaghan': {'runs': 85, 'balls': 73, 'strike_rate': 116.44},
#  'HV Patel': {'runs': 249, 'balls': 214, 'strike_rate': 116.36},
#  'Sohail Tanvir': {'runs': 36, 'balls': 31, 'strike_rate': 116.13},
#  'Harpreet Brar': {'runs': 233, 'balls': 201, 'strike_rate': 115.92},
#  'JD Unadkat': {'runs': 197, 'balls': 170, 'strike_rate': 115.88},
#  'S Badrinath': {'runs': 1441, 'balls': 1245, 'strike_rate': 115.74},
#  'SS Tiwary': {'runs': 1494, 'balls': 1291, 'strike_rate': 115.72},
#  'DB Ravi Teja': {'runs': 375, 'balls': 325, 'strike_rate': 115.38},
#  'Anuj Rawat': {'runs': 318, 'balls': 276, 'strike_rate': 115.22},
#  'AJ Tye': {'runs': 91, 'balls': 79, 'strike_rate': 115.19},
#  'TL Suman': {'runs': 676, 'balls': 587, 'strike_rate': 115.16},
#  'Shahbaz Ahmed': {'runs': 536, 'balls': 467, 'strike_rate': 114.78},
#  'KV Sharma': {'runs': 351, 'balls': 306, 'strike_rate': 114.71},
#  'SP Fleming': {'runs': 196, 'balls': 171, 'strike_rate': 114.62},
#  'R Ashwin': {'runs': 800, 'balls': 698, 'strike_rate': 114.61},
#  'R Sathish': {'runs': 270, 'balls': 236, 'strike_rate': 114.41},
#  'KC Cariappa': {'runs': 24, 'balls': 21, 'strike_rate': 114.29},
#  'AM Nayar': {'runs': 672, 'balls': 588, 'strike_rate': 114.29},
#  'NV Ojha': {'runs': 1554, 'balls': 1360, 'strike_rate': 114.26},
#  'SR Tendulkar': {'runs': 2334, 'balls': 2044, 'strike_rate': 114.19},
#  'LA Carseldine': {'runs': 81, 'balls': 71, 'strike_rate': 114.08},
#  'Y Venugopal Rao': {'runs': 985, 'balls': 865, 'strike_rate': 113.87},
#  'DB Das': {'runs': 304, 'balls': 267, 'strike_rate': 113.86},
#  'MK Tiwary': {'runs': 1695, 'balls': 1489, 'strike_rate': 113.83},
#  'Sanvir Singh': {'runs': 25, 'balls': 22, 'strike_rate': 113.64},
#  'RS Bopara': {'runs': 531, 'balls': 468, 'strike_rate': 113.46},
#  'R Dravid': {'runs': 2174, 'balls': 1918, 'strike_rate': 113.35},
#  'LR Shukla': {'runs': 405, 'balls': 358, 'strike_rate': 113.13},
#  'NL McCullum': {'runs': 26, 'balls': 23, 'strike_rate': 113.04},
#  'AP Majumdar': {'runs': 87, 'balls': 77, 'strike_rate': 112.99},
#  'J Suchith': {'runs': 70, 'balls': 62, 'strike_rate': 112.9},
#  'AS Raut': {'runs': 194, 'balls': 172, 'strike_rate': 112.79},
#  'DJM Short': {'runs': 115, 'balls': 102, 'strike_rate': 112.75},
#  'DT Christian': {'runs': 460, 'balls': 408, 'strike_rate': 112.75},
#  'S Anirudha': {'runs': 136, 'balls': 121, 'strike_rate': 112.4},
#  'J Botha': {'runs': 409, 'balls': 364, 'strike_rate': 112.36},
#  'Salman Butt': {'runs': 193, 'balls': 172, 'strike_rate': 112.21},
#  'RE Levi': {'runs': 83, 'balls': 74, 'strike_rate': 112.16},
#  'CA Ingram': {'runs': 205, 'balls': 183, 'strike_rate': 112.02},
#  'AB Agarkar': {'runs': 179, 'balls': 160, 'strike_rate': 111.87},
#  'R Dhawan': {'runs': 210, 'balls': 188, 'strike_rate': 111.7},
#  'VH Zol': {'runs': 29, 'balls': 26, 'strike_rate': 111.54},
#  'SS Prabhudessai': {'runs': 126, 'balls': 113, 'strike_rate': 111.5},
#  'MD Mishra': {'runs': 237, 'balls': 213, 'strike_rate': 111.27},
#  'BR Dunk': {'runs': 40, 'balls': 36, 'strike_rate': 111.11},
#  'TG Southee': {'runs': 120, 'balls': 108, 'strike_rate': 111.11},
#  'S Rana': {'runs': 91, 'balls': 82, 'strike_rate': 110.98},
#  'WPUJC Vaas': {'runs': 81, 'balls': 73, 'strike_rate': 110.96},
#  'Swapnil Singh': {'runs': 51, 'balls': 46, 'strike_rate': 110.87},
#  'Washington Sundar': {'runs': 378, 'balls': 341, 'strike_rate': 110.85},
#  'PK Garg': {'runs': 273, 'balls': 247, 'strike_rate': 110.53},
#  'RE van der Merwe': {'runs': 159, 'balls': 144, 'strike_rate': 110.42},
#  'AT Carey': {'runs': 32, 'balls': 29, 'strike_rate': 110.34},
#  'TM Dilshan': {'runs': 1153, 'balls': 1047, 'strike_rate': 110.12},
#  'B Chipli': {'runs': 280, 'balls': 256, 'strike_rate': 109.38},
#  'NM Coulter-Nile': {'runs': 82, 'balls': 75, 'strike_rate': 109.33},
#  'AL Menaria': {'runs': 401, 'balls': 367, 'strike_rate': 109.26},
#  'M Markande': {'runs': 48, 'balls': 44, 'strike_rate': 109.09},
#  'MA Khote': {'runs': 24, 'balls': 22, 'strike_rate': 109.09},
#  'A Flintoff': {'runs': 62, 'balls': 57, 'strike_rate': 108.77},
#  'AS Roy': {'runs': 26, 'balls': 24, 'strike_rate': 108.33},
#  'MS Bisla': {'runs': 798, 'balls': 737, 'strike_rate': 108.28},
#  'DJ Harris': {'runs': 111, 'balls': 103, 'strike_rate': 107.77},
#  'BB Samantray': {'runs': 125, 'balls': 116, 'strike_rate': 107.76},
#  'SD Chitnis': {'runs': 99, 'balls': 92, 'strike_rate': 107.61},
#  'PP Chawla': {'runs': 624, 'balls': 580, 'strike_rate': 107.59},
#  'J Syed Mohammad': {'runs': 29, 'balls': 27, 'strike_rate': 107.41},
#  'R Vinay Kumar': {'runs': 310, 'balls': 289, 'strike_rate': 107.27},
#  'SP Jackson': {'runs': 61, 'balls': 57, 'strike_rate': 107.02},
#  'CM Gautam': {'runs': 169, 'balls': 158, 'strike_rate': 106.96},
#  'GC Smith': {'runs': 739, 'balls': 691, 'strike_rate': 106.95},
#  'Shoaib Malik': {'runs': 52, 'balls': 49, 'strike_rate': 106.12},
#  'JH Kallis': {'runs': 2427, 'balls': 2291, 'strike_rate': 105.94},
#  'HH Gibbs': {'runs': 886, 'balls': 837, 'strike_rate': 105.85},
#  'JEC Franklin': {'runs': 327, 'balls': 309, 'strike_rate': 105.83},
#  'M Manhas': {'runs': 514, 'balls': 486, 'strike_rate': 105.76},
#  'Aman Hakim Khan': {'runs': 115, 'balls': 109, 'strike_rate': 105.5},
#  'P Kumar': {'runs': 340, 'balls': 323, 'strike_rate': 105.26},
#  'J Yadav': {'runs': 40, 'balls': 38, 'strike_rate': 105.26},
#  'RV Patel': {'runs': 80, 'balls': 76, 'strike_rate': 105.26},
#  'Y Nagar': {'runs': 285, 'balls': 271, 'strike_rate': 105.17},
#  'YV Takawale': {'runs': 192, 'balls': 183, 'strike_rate': 104.92},
#  'RR Powar': {'runs': 67, 'balls': 64, 'strike_rate': 104.69},
#  'N Jagadeesan': {'runs': 162, 'balls': 155, 'strike_rate': 104.52},
#  'RJ Harris': {'runs': 117, 'balls': 112, 'strike_rate': 104.46},
#  'VVS Laxman': {'runs': 282, 'balls': 271, 'strike_rate': 104.06},
#  'S Gopal': {'runs': 180, 'balls': 173, 'strike_rate': 104.05},
#  'JM Kemp': {'runs': 26, 'balls': 25, 'strike_rate': 104.0},
#  'M Kartik': {'runs': 113, 'balls': 109, 'strike_rate': 103.67},
#  'Harpreet Singh': {'runs': 123, 'balls': 119, 'strike_rate': 103.36},
#  'DL Vettori': {'runs': 121, 'balls': 118, 'strike_rate': 102.54},
#  'DW Steyn': {'runs': 167, 'balls': 163, 'strike_rate': 102.45},
#  'Iqbal Abdulla': {'runs': 88, 'balls': 86, 'strike_rate': 102.33},
#  'FY Fazal': {'runs': 183, 'balls': 179, 'strike_rate': 102.23},
#  'MJ Clarke': {'runs': 98, 'balls': 96, 'strike_rate': 102.08},
#  'OF Smith': {'runs': 51, 'balls': 50, 'strike_rate': 102.0},
#  'SC Ganguly': {'runs': 1349, 'balls': 1326, 'strike_rate': 101.73},
#  'RD Chahar': {'runs': 129, 'balls': 127, 'strike_rate': 101.57},
#  'Lalit Yadav': {'runs': 305, 'balls': 301, 'strike_rate': 101.33},
#  'CR Woakes': {'runs': 78, 'balls': 77, 'strike_rate': 101.3},
#  'TA Boult': {'runs': 83, 'balls': 82, 'strike_rate': 101.22},
#  'W Jaffer': {'runs': 130, 'balls': 129, 'strike_rate': 100.78},
#  'M Kaif': {'runs': 259, 'balls': 258, 'strike_rate': 100.39},
#  'CJ Jordan': {'runs': 81, 'balls': 81, 'strike_rate': 100.0},
#  'DJ Malan': {'runs': 26, 'balls': 26, 'strike_rate': 100.0},
#  'RJ Peterson': {'runs': 32, 'balls': 32, 'strike_rate': 100.0},
#  'AD Mascarenhas': {'runs': 79, 'balls': 79, 'strike_rate': 100.0},
#  'Rasikh Salam': {'runs': 40, 'balls': 40, 'strike_rate': 100.0},
#  'S Aravind': {'runs': 59, 'balls': 59, 'strike_rate': 100.0},
#  'GB Hogg': {'runs': 22, 'balls': 22, 'strike_rate': 100.0},
#  'TL Seifert': {'runs': 26, 'balls': 26, 'strike_rate': 100.0},
#  'MD Shanaka': {'runs': 26, 'balls': 26, 'strike_rate': 100.0},
#  'AA Jhunjhunwala': {'runs': 217, 'balls': 218, 'strike_rate': 99.54},
#  'K Rabada': {'runs': 206, 'balls': 207, 'strike_rate': 99.52},
#  'MG Johnson': {'runs': 167, 'balls': 168, 'strike_rate': 99.4},
#  'SE Rutherford': {'runs': 106, 'balls': 107, 'strike_rate': 99.07},
#  'JDS Neesham': {'runs': 92, 'balls': 93, 'strike_rate': 98.92},
#  'MS Wade': {'runs': 183, 'balls': 185, 'strike_rate': 98.92},
#  'UT Yadav': {'runs': 208, 'balls': 211, 'strike_rate': 98.58},
#  'HR Shokeen': {'runs': 66, 'balls': 67, 'strike_rate': 98.51},
#  'PA Reddy': {'runs': 164, 'balls': 167, 'strike_rate': 98.2},
#  'RJ Quiney': {'runs': 103, 'balls': 105, 'strike_rate': 98.1},
#  'R Rampaul': {'runs': 51, 'balls': 52, 'strike_rate': 98.08},
#  'N Saini': {'runs': 140, 'balls': 143, 'strike_rate': 97.9},
#  'SB Styris': {'runs': 131, 'balls': 134, 'strike_rate': 97.76},
#  'AB Barath': {'runs': 42, 'balls': 43, 'strike_rate': 97.67},
#  'NK Patel': {'runs': 121, 'balls': 124, 'strike_rate': 97.58},
#  'JR Philippe': {'runs': 78, 'balls': 80, 'strike_rate': 97.5},
#  'CA Pujara': {'runs': 390, 'balls': 403, 'strike_rate': 96.77},
#  'Vishnu Vinod': {'runs': 56, 'balls': 58, 'strike_rate': 96.55},
#  'JDP Oram': {'runs': 106, 'balls': 110, 'strike_rate': 96.36},
#  'MA Starc': {'runs': 105, 'balls': 109, 'strike_rate': 96.33},
#  'KB Arun Karthik': {'runs': 51, 'balls': 53, 'strike_rate': 96.23},
#  'A Nortje': {'runs': 49, 'balls': 51, 'strike_rate': 96.08},
#  'J Arunkumar': {'runs': 23, 'balls': 24, 'strike_rate': 95.83},
#  'UBT Chand': {'runs': 300, 'balls': 314, 'strike_rate': 95.54},
#  'SP Goswami': {'runs': 293, 'balls': 307, 'strike_rate': 95.44},
#  'NJ Maddinson': {'runs': 20, 'balls': 21, 'strike_rate': 95.24},
#  'MM Patel': {'runs': 39, 'balls': 41, 'strike_rate': 95.12},
#  'PR Shah': {'runs': 92, 'balls': 97, 'strike_rate': 94.85},
#  'RV Gomez': {'runs': 50, 'balls': 53, 'strike_rate': 94.34},
#  'M Klinger': {'runs': 73, 'balls': 78, 'strike_rate': 93.59},
#  'RR Sarwan': {'runs': 73, 'balls': 78, 'strike_rate': 93.59},
#  'SB Jakati': {'runs': 28, 'balls': 30, 'strike_rate': 93.33},
#  'MC Juneja': {'runs': 125, 'balls': 134, 'strike_rate': 93.28},
#  'M Jansen': {'runs': 66, 'balls': 71, 'strike_rate': 92.96},
#  'Mohsin Khan': {'runs': 25, 'balls': 27, 'strike_rate': 92.59},
#  'MN Samuels': {'runs': 161, 'balls': 174, 'strike_rate': 92.53},
#  'KW Richardson': {'runs': 36, 'balls': 39, 'strike_rate': 92.31},
#  'B Sumanth': {'runs': 35, 'balls': 38, 'strike_rate': 92.11},
#  'DS Kulkarni': {'runs': 104, 'balls': 113, 'strike_rate': 92.04},
#  'L Ronchi': {'runs': 34, 'balls': 37, 'strike_rate': 91.89},
#  'DR Sams': {'runs': 44, 'balls': 48, 'strike_rate': 91.67},
#  'Anirudh Singh': {'runs': 63, 'balls': 69, 'strike_rate': 91.3},
#  'DE Bollinger': {'runs': 21, 'balls': 23, 'strike_rate': 91.3},
#  'K Goel': {'runs': 218, 'balls': 239, 'strike_rate': 91.21},
#  'DJ Jacobs': {'runs': 92, 'balls': 101, 'strike_rate': 91.09},
#  'MJ Santner': {'runs': 70, 'balls': 77, 'strike_rate': 90.91},
#  'AD Nath': {'runs': 90, 'balls': 99, 'strike_rate': 90.91},
#  'B Kumar': {'runs': 306, 'balls': 338, 'strike_rate': 90.53},
#  'MM Sharma': {'runs': 124, 'balls': 137, 'strike_rate': 90.51},
#  'SK Warne': {'runs': 198, 'balls': 219, 'strike_rate': 90.41},
#  'Mohammed Shami': {'runs': 74, 'balls': 82, 'strike_rate': 90.24},
#  'P Dogra': {'runs': 127, 'balls': 141, 'strike_rate': 90.07},
#  'PWH de Silva': {'runs': 72, 'balls': 80, 'strike_rate': 90.0},
#  'Mohammed Siraj': {'runs': 109, 'balls': 122, 'strike_rate': 89.34},
#  'R McLaren': {'runs': 159, 'balls': 178, 'strike_rate': 89.33},
#  'Imran Tahir': {'runs': 33, 'balls': 37, 'strike_rate': 89.19},
#  'T Kohler-Cadmore': {'runs': 48, 'balls': 54, 'strike_rate': 88.89},
#  'SW Tait': {'runs': 23, 'balls': 26, 'strike_rate': 88.46},
#  'HE van der Dussen': {'runs': 22, 'balls': 25, 'strike_rate': 88.0},
#  'Shivam Mavi': {'runs': 51, 'balls': 58, 'strike_rate': 87.93},
#  'Navdeep Saini': {'runs': 33, 'balls': 38, 'strike_rate': 86.84},
#  'A Mishra': {'runs': 381, 'balls': 440, 'strike_rate': 86.59},
#  'Basil Thampi': {'runs': 32, 'balls': 37, 'strike_rate': 86.49},
#  'GH Vihari': {'runs': 284, 'balls': 331, 'strike_rate': 85.8},
#  'R Sharma': {'runs': 66, 'balls': 77, 'strike_rate': 85.71},
#  'SL Malinga': {'runs': 88, 'balls': 103, 'strike_rate': 85.44},
#  'BMAJ Mendis': {'runs': 23, 'balls': 27, 'strike_rate': 85.19},
#  'JJ Bumrah': {'runs': 68, 'balls': 80, 'strike_rate': 85.0},
#  'SB Bangar': {'runs': 49, 'balls': 58, 'strike_rate': 84.48},
#  'AS Joseph': {'runs': 27, 'balls': 32, 'strike_rate': 84.38},
#  'Z Khan': {'runs': 117, 'balls': 141, 'strike_rate': 82.98},
#  'DJ Willey': {'runs': 53, 'balls': 64, 'strike_rate': 82.81},
#  'R Shukla': {'runs': 19, 'balls': 23, 'strike_rate': 82.61},
#  'A Mukund': {'runs': 19, 'balls': 23, 'strike_rate': 82.61},
#  'CJ Ferguson': {'runs': 98, 'balls': 119, 'strike_rate': 82.35},
#  'T Banton': {'runs': 18, 'balls': 22, 'strike_rate': 81.82},
#  'Kuldeep Yadav': {'runs': 183, 'balls': 224, 'strike_rate': 81.7},
#  'S Sriram': {'runs': 31, 'balls': 38, 'strike_rate': 81.58},
#  'AG Paunikar': {'runs': 49, 'balls': 61, 'strike_rate': 80.33},
#  'I Sharma': {'runs': 57, 'balls': 71, 'strike_rate': 80.28},
#  'M Rawat': {'runs': 55, 'balls': 70, 'strike_rate': 78.57},
#  'AA Bilakhia': {'runs': 69, 'balls': 88, 'strike_rate': 78.41},
#  'AJ Turner': {'runs': 24, 'balls': 31, 'strike_rate': 77.42},
#  'Anureet Singh': {'runs': 36, 'balls': 47, 'strike_rate': 76.6},
#  'Mohammad Hafeez': {'runs': 64, 'balls': 84, 'strike_rate': 76.19},
#  'IR Jaggi': {'runs': 76, 'balls': 100, 'strike_rate': 76.0},
#  'P Ray Barman': {'runs': 19, 'balls': 25, 'strike_rate': 76.0},
#  'S Chanderpaul': {'runs': 25, 'balls': 33, 'strike_rate': 75.76},
#  'WD Parnell': {'runs': 65, 'balls': 86, 'strike_rate': 75.58},
#  'Tanush Kotian': {'runs': 24, 'balls': 32, 'strike_rate': 75.0},
#  'AF Milne': {'runs': 23, 'balls': 31, 'strike_rate': 74.19},
#  'Sandeep Sharma': {'runs': 54, 'balls': 73, 'strike_rate': 73.97},
#  'WA Mota': {'runs': 56, 'balls': 76, 'strike_rate': 73.68},
#  'DR Martyn': {'runs': 19, 'balls': 26, 'strike_rate': 73.08},
#  'NT Ellis': {'runs': 19, 'balls': 26, 'strike_rate': 73.08},
#  'DJ Thornely': {'runs': 39, 'balls': 54, 'strike_rate': 72.22},
#  'L Balaji': {'runs': 36, 'balls': 50, 'strike_rate': 72.0},
#  'A Kumble': {'runs': 35, 'balls': 49, 'strike_rate': 71.43},
#  'C Madan': {'runs': 15, 'balls': 21, 'strike_rate': 71.43},
#  'A Chopra': {'runs': 53, 'balls': 75, 'strike_rate': 70.67},
#  'RT Ponting': {'runs': 91, 'balls': 129, 'strike_rate': 70.54},
#  'Yashpal Singh': {'runs': 47, 'balls': 67, 'strike_rate': 70.15},
#  'M Ashwin': {'runs': 35, 'balls': 50, 'strike_rate': 70.0},
#  'P Dubey': {'runs': 23, 'balls': 33, 'strike_rate': 69.7},
#  'YV Dhull': {'runs': 16, 'balls': 23, 'strike_rate': 69.57},
#  'Sumit Kumar': {'runs': 18, 'balls': 26, 'strike_rate': 69.23},
#  'KMA Paul': {'runs': 18, 'balls': 26, 'strike_rate': 69.23},
#  'Naveen-ul-Haq': {'runs': 18, 'balls': 26, 'strike_rate': 69.23},
#  'Arshdeep Singh': {'runs': 29, 'balls': 42, 'strike_rate': 69.05},
#  'SK Trivedi': {'runs': 42, 'balls': 61, 'strike_rate': 68.85},
#  'VR Aaron': {'runs': 50, 'balls': 73, 'strike_rate': 68.49},
#  'B Indrajith': {'runs': 21, 'balls': 31, 'strike_rate': 67.74},
#  'RP Singh': {'runs': 52, 'balls': 78, 'strike_rate': 66.67},
#  'M Muralitharan': {'runs': 20, 'balls': 30, 'strike_rate': 66.67},
#  'CK Kapugedera': {'runs': 16, 'balls': 24, 'strike_rate': 66.67},
#  'JR Hazlewood': {'runs': 19, 'balls': 29, 'strike_rate': 65.52},
#  'A Nehra': {'runs': 41, 'balls': 63, 'strike_rate': 65.08},
#  'KL Nagarkoti': {'runs': 22, 'balls': 34, 'strike_rate': 64.71},
#  'C Sakariya': {'runs': 20, 'balls': 31, 'strike_rate': 64.52},
#  'KS Sharma': {'runs': 16, 'balls': 25, 'strike_rate': 64.0},
#  'G Coetzee': {'runs': 14, 'balls': 22, 'strike_rate': 63.64},
#  'AS Rajpoot': {'runs': 26, 'balls': 41, 'strike_rate': 63.41},
#  'JA Richardson': {'runs': 17, 'balls': 27, 'strike_rate': 62.96},
#  'Ravi Bishnoi': {'runs': 32, 'balls': 52, 'strike_rate': 61.54},
#  'A Zampa': {'runs': 15, 'balls': 25, 'strike_rate': 60.0},
#  'S Sreesanth': {'runs': 34, 'balls': 57, 'strike_rate': 59.65},
#  'NS Naik': {'runs': 31, 'balls': 53, 'strike_rate': 58.49},
#  'Virat Singh': {'runs': 15, 'balls': 26, 'strike_rate': 57.69},
#  'Mustafizur Rahman': {'runs': 13, 'balls': 23, 'strike_rate': 56.52},
#  'S Kaul': {'runs': 20, 'balls': 36, 'strike_rate': 55.56},
#  'PJ Sangwan': {'runs': 26, 'balls': 47, 'strike_rate': 55.32},
#  'VY Mahesh': {'runs': 15, 'balls': 28, 'strike_rate': 53.57},
#  'AB Dinda': {'runs': 26, 'balls': 50, 'strike_rate': 52.0},
#  'S Badree': {'runs': 13, 'balls': 25, 'strike_rate': 52.0},
#  'CV Varun': {'runs': 25, 'balls': 49, 'strike_rate': 51.02},
#  'PV Tambe': {'runs': 18, 'balls': 39, 'strike_rate': 46.15},
#  'S Nadeem': {'runs': 39, 'balls': 88, 'strike_rate': 44.32},
#  'YS Chahal': {'runs': 37, 'balls': 89, 'strike_rate': 41.57},
#  'M Prasidh Krishna': {'runs': 9, 'balls': 24, 'strike_rate': 37.5},
#  'RK Bhui': {'runs': 10, 'balls': 27, 'strike_rate': 37.04},
#  'PP Ojha': {'runs': 16, 'balls': 45, 'strike_rate': 35.56},
#  'TD Paine': {'runs': 10, 'balls': 29, 'strike_rate': 34.48}}

# %% [markdown]
# # D) Venue

# %% [markdown]
# ## 1) Venue Statistics

# %% [markdown]
# - stats of matches played on a specific venue,average score, winning Rate by chasing or defending , wickets , teams played till now, which toss decisions teams prefer,seasons played

# %%
def venue_stat(venue):
    # Fetching data for the respective venue
    records = ipl2[ipl2['venue'] == venue][['id', 'season', 'city', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner']]
    if not records.empty:
        # Seasons held at the venue
        seasons_played = sorted(records['season'].unique())

        # city
        city=records['city'].unique()[0]
        
        # Teams that played at the venue
        teams_played = list(set(list(records['team1'].unique()) + list(records['team2'].unique())))

        # Most preferred toss decision
        prefered_toss_decision = records['toss_decision'].value_counts().idxmax()

        # Fetch statistics from the related dataset
        new_records = ipl1[ipl1['match_id'].isin(records['id'])]
        grouped_data = new_records.groupby(['match_id', 'inning'])
        avg_runs = round(grouped_data['batsman_runs'].sum().mean(), 2)
        wickets_taken = new_records[new_records['is_wicket'] == 1]['is_wicket'].count()

        # number of matches played
        num_matches=records.shape[0]

        
        # Chasing and defending rates
        inning1_runs = new_records[new_records['inning'] == 1].groupby('match_id')['batsman_runs'].sum()
        inning2_runs = new_records[new_records['inning'] == 2].groupby('match_id')['batsman_runs'].sum()
        margin = inning1_runs - inning2_runs
        chased_match = (margin < 0).sum()
        defended_match = (margin >= 0).sum()

        chasing_rate = round((chased_match / margin.shape[0]) * 100, 2)
        defending_rate = round((defended_match / margin.shape[0]) * 100, 2)
        
        # min and max score of venue
        min_score=min(inning1_runs.min(),inning2_runs.min())
        max_score=max(inning1_runs.max(),inning2_runs.max())
        
        # Creating output dictionary
        venue_stats = {
            'venue': f'{venue}, {city}',
            'seasons_held': seasons_played,
            'teams_played': sorted(teams_played),
            'prefered_toss_decision': prefered_toss_decision,
            'number_matches':num_matches,
            'avg_score': avg_runs,
            'min_score':min_score,
            'max_score':max_score,
            'num_wickets': wickets_taken,
            'chasing_rate': chasing_rate,
            'defending_rate': defending_rate
        }
        return venue_stats
    else:
        return {'error': 'This venue is not represented in our data'}

# %%
venue_stat('Eden Gardens')
# Out:
# {'venue': 'Eden Gardens, Kolkata',
#  'seasons_held': [2008,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018,
#   2019,
#   2022,
#   2023,
#   2024],
#  'teams_played': ['Chennai Super Kings',
#   'Deccan Chargers',
#   'Delhi Capitals',
#   'Delhi Daredevils',
#   'Gujarat Lions',
#   'Gujarat Titans',
#   'Kings XI Punjab',
#   'Kochi Tuskers Kerala',
#   'Kolkata Knight Riders',
#   'Lucknow Super Giants',
#   'Mumbai Indians',
#   'Pune Warriors',
#   'Punjab Kings',
#   'Rajasthan Royals',
#   'Rising Pune Supergiant',
#   'Royal Challengers Bangalore',
#   'Sunrisers Hyderabad'],
#  'prefered_toss_decision': 'field',
#  'number_matches': 93,
#  'avg_score': 151.52,
#  'min_score': 42,
#  'max_score': 256,
#  'num_wickets': 1071,
#  'chasing_rate': 35.48,
#  'defending_rate': 64.52}

# %% [markdown]
# ## 2) top venues

# %%
def top_venues():
    # Initialize a list to store venue statistics
    venue_stats = []

    for venue in ipl2['venue'].unique():
        # Extract records for the venue
        records = ipl2[ipl2['venue'] == venue][['id', 'toss_decision']]
        
        # Calculate matches played
        num_matches = records['id'].nunique()

        # Check if matches played are more than 10
        if num_matches > 10:
            # Fetch data from ipl1 for the venue
            venue_matches = ipl1[ipl1['match_id'].isin(records['id'])]
            grouped_data = venue_matches.groupby(['match_id', 'inning'])
            
            # Calculate total runs scored at the venue
            total_runs = grouped_data['batsman_runs'].sum().sum()
            
            # Count total wickets taken at the venue
            total_wickets = venue_matches[venue_matches['is_wicket'] == 1]['is_wicket'].count()
            
            # Apply remaining criteria
            if total_runs > 1000 and total_wickets > 20:
                # Calculate average runs per inning
                avg_runs = round(grouped_data['batsman_runs'].sum().mean(), 2)

                # Most preferred toss decision
                prefered_toss_decision = records['toss_decision'].value_counts().idxmax()
                
                # Append venue statistics
                venue_stats.append({
                    'venue': venue,
                    'num_matches': num_matches,
                    'total_runs': total_runs,
                    'total_wickets': total_wickets,
                    'avg_runs': avg_runs,
                    'prefered_toss_decision': prefered_toss_decision
                })

    # Convert to DataFrame for sorting
    venue_df = pd.DataFrame(venue_stats)

    # Sort by total_runs (descending) and total_wickets (descending)
    sorted_venues = venue_df.sort_values(by=['total_runs', 'total_wickets'], ascending=[False, False])
    
    #  Convert to a dictionary with venues as keys
    response = sorted_venues.set_index('venue').T.to_dict()
    return response

# %%
top_venues()
# Out:
# {'Wankhede Stadium': {'num_matches': 118,
#   'total_runs': 36919,
#   'total_wickets': 1422,
#   'avg_runs': 155.12,
#   'prefered_toss_decision': 'field'},
#  'M Chinnaswamy Stadium': {'num_matches': 94,
#   'total_runs': 29075,
#   'total_wickets': 1101,
#   'avg_runs': 153.84,
#   'prefered_toss_decision': 'field'},
#  'Eden Gardens': {'num_matches': 93,
#   'total_runs': 28182,
#   'total_wickets': 1071,
#   'avg_runs': 151.52,
#   'prefered_toss_decision': 'field'},
#  'MA Chidambaram Stadium': {'num_matches': 85,
#   'total_runs': 25295,
#   'total_wickets': 1023,
#   'avg_runs': 145.37,
#   'prefered_toss_decision': 'bat'},
#  'Rajiv Gandhi International Stadium': {'num_matches': 77,
#   'total_runs': 23158,
#   'total_wickets': 899,
#   'avg_runs': 148.45,
#   'prefered_toss_decision': 'field'},
#  'Punjab Cricket Association IS Bindra Stadium': {'num_matches': 61,
#   'total_runs': 18929,
#   'total_wickets': 690,
#   'avg_runs': 155.16,
#   'prefered_toss_decision': 'field'},
#  'Feroz Shah Kotla': {'num_matches': 60,
#   'total_runs': 17499,
#   'total_wickets': 697,
#   'avg_runs': 147.05,
#   'prefered_toss_decision': 'field'},
#  'Sawai Mansingh Stadium': {'num_matches': 57,
#   'total_runs': 16746,
#   'total_wickets': 623,
#   'avg_runs': 146.89,
#   'prefered_toss_decision': 'field'},
#  'Dubai International Cricket Stadium': {'num_matches': 46,
#   'total_runs': 13753,
#   'total_wickets': 545,
#   'avg_runs': 137.53,
#   'prefered_toss_decision': 'field'},
#  'Dr DY Patil Sports Academy': {'num_matches': 37,
#   'total_runs': 10689,
#   'total_wickets': 470,
#   'avg_runs': 144.45,
#   'prefered_toss_decision': 'field'},
#  'Maharashtra Cricket Association Stadium': {'num_matches': 35,
#   'total_runs': 10600,
#   'total_wickets': 434,
#   'avg_runs': 151.43,
#   'prefered_toss_decision': 'field'},
#  'Arun Jaitley Stadium': {'num_matches': 30,
#   'total_runs': 10159,
#   'total_wickets': 364,
#   'avg_runs': 163.85,
#   'prefered_toss_decision': 'field'},
#  'Brabourne Stadium': {'num_matches': 27,
#   'total_runs': 8760,
#   'total_wickets': 331,
#   'avg_runs': 162.22,
#   'prefered_toss_decision': 'field'},
#  'Sheikh Zayed Stadium': {'num_matches': 29,
#   'total_runs': 8467,
#   'total_wickets': 329,
#   'avg_runs': 136.56,
#   'prefered_toss_decision': 'bat'},
#  'Sharjah Cricket Stadium': {'num_matches': 28,
#   'total_runs': 8159,
#   'total_wickets': 322,
#   'avg_runs': 145.7,
#   'prefered_toss_decision': 'field'},
#  'Narendra Modi Stadium': {'num_matches': 24,
#   'total_runs': 7808,
#   'total_wickets': 284,
#   'avg_runs': 162.67,
#   'prefered_toss_decision': 'field'},
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': {'num_matches': 15,
#   'total_runs': 4323,
#   'total_wickets': 191,
#   'avg_runs': 144.1,
#   'prefered_toss_decision': 'field'},
#  'Subrata Roy Sahara Stadium': {'num_matches': 16,
#   'total_runs': 4296,
#   'total_wickets': 183,
#   'avg_runs': 134.25,
#   'prefered_toss_decision': 'bat'},
#  'Himachal Pradesh Cricket Association Stadium': {'num_matches': 13,
#   'total_runs': 4176,
#   'total_wickets': 160,
#   'avg_runs': 160.62,
#   'prefered_toss_decision': 'field'},
#  'Kingsmead': {'num_matches': 15,
#   'total_runs': 4076,
#   'total_wickets': 201,
#   'avg_runs': 135.87,
#   'prefered_toss_decision': 'bat'},
#  'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium': {'num_matches': 14,
#   'total_runs': 4069,
#   'total_wickets': 176,
#   'avg_runs': 150.7,
#   'prefered_toss_decision': 'field'},
#  'Sardar Patel Stadium, Motera': {'num_matches': 12,
#   'total_runs': 3589,
#   'total_wickets': 145,
#   'avg_runs': 138.04,
#   'prefered_toss_decision': 'field'},
#  'SuperSport Park': {'num_matches': 12,
#   'total_runs': 3440,
#   'total_wickets': 133,
#   'avg_runs': 143.33,
#   'prefered_toss_decision': 'bat'}}

# %%
ipl1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0         NaN          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0         NaN          0              NaN
# 4                0           0         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1         NaN          0              NaN
# 260916           0           1         NaN          0              NaN
# 260917           0           1         NaN          0              NaN
# 260918           0           1         NaN          0              NaN
# 260919           0           1         NaN          0              NaN
#
#        dismissal_kind fielder  season
# 0                 NaN     NaN    2008
# 1                 NaN     NaN    2008
# 2                 NaN     NaN    2008
# 3                 NaN     NaN    2008
# 4                 NaN     NaN    2008
# ...               ...     ...     ...
# 260915            NaN     NaN    2024
# 260916            NaN     NaN    2024
# 260917            NaN     NaN    2024
# 260918            NaN     NaN    2024
# 260919            NaN     NaN    2024
#
# [260920 rows x 18 columns]

# %%
ipl2.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
# ## 3) season Summary

# %%
def season_winners():
    winning_team=(ipl2[ipl2['match_type']=='Final'][['season','winner']].to_dict(orient='records'))
    return winning_team

# %%
season_winners()
# Out:
# [{'season': 2008, 'winner': 'Rajasthan Royals'},
#  {'season': 2009, 'winner': 'Deccan Chargers'},
#  {'season': 2010, 'winner': 'Chennai Super Kings'},
#  {'season': 2011, 'winner': 'Chennai Super Kings'},
#  {'season': 2012, 'winner': 'Kolkata Knight Riders'},
#  {'season': 2013, 'winner': 'Mumbai Indians'},
#  {'season': 2014, 'winner': 'Kolkata Knight Riders'},
#  {'season': 2015, 'winner': 'Mumbai Indians'},
#  {'season': 2016, 'winner': 'Sunrisers Hyderabad'},
#  {'season': 2017, 'winner': 'Mumbai Indians'},
#  {'season': 2018, 'winner': 'Chennai Super Kings'},
#  {'season': 2019, 'winner': 'Mumbai Indians'},
#  {'season': 2020, 'winner': 'Mumbai Indians'},
#  {'season': 2021, 'winner': 'Chennai Super Kings'},
#  {'season': 2022, 'winner': 'Gujarat Titans'},
#  {'season': 2023, 'winner': 'Chennai Super Kings'},
#  {'season': 2024, 'winner': 'Kolkata Knight Riders'}]

# %%
ipl2
# Out:
#            id  season       city       date   match_type  player_of_match  \
# 0      335982    2008  Bengaluru 2008-04-18       League      BB McCullum
# 1      335983    2008     Mohali 2008-04-19       League       MEK Hussey
# 2      335984    2008      Delhi 2008-04-19       League      MF Maharoof
# 3      335985    2008     Mumbai 2008-04-20       League       MV Boucher
# 4      335986    2008    Kolkata 2008-04-20       League        DJ Hussey
# ...       ...     ...        ...        ...          ...              ...
# 1090  1426307    2024  Hyderabad 2024-05-19       League  Abhishek Sharma
# 1091  1426309    2024  Ahmedabad 2024-05-21  Qualifier 1         MA Starc
# 1092  1426310    2024  Ahmedabad 2024-05-22   Eliminator         R Ashwin
# 1093  1426311    2024    Chennai 2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312    2024    Chennai 2024-05-26        Final         MA Starc
#
#                                              venue  \
# 0                            M Chinnaswamy Stadium
# 1     Punjab Cricket Association IS Bindra Stadium
# 2                                 Feroz Shah Kotla
# 3                                 Wankhede Stadium
# 4                                     Eden Gardens
# ...                                            ...
# 1090            Rajiv Gandhi International Stadium
# 1091                         Narendra Modi Stadium
# 1092                         Narendra Modi Stadium
# 1093                        MA Chidambaram Stadium
# 1094                        MA Chidambaram Stadium
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bangalore             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                       toss_winner toss_decision                       winner  \
# 0     Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1             Chennai Super Kings           bat          Chennai Super Kings
# 2                Rajasthan Royals           bat             Delhi Daredevils
# 3                  Mumbai Indians           bat  Royal Challengers Bangalore
# 4                 Deccan Chargers           bat        Kolkata Knight Riders
# ...                           ...           ...                          ...
# 1090                 Punjab Kings           bat          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad           bat        Kolkata Knight Riders
# 1092             Rajasthan Royals         field             Rajasthan Royals
# 1093             Rajasthan Royals         field          Sunrisers Hyderabad
# 1094          Sunrisers Hyderabad           bat        Kolkata Knight Riders
#
#        result  result_margin  target_runs  target_overs super_over method  \
# 0        runs          140.0        223.0          20.0          N    NaN
# 1        runs           33.0        241.0          20.0          N    NaN
# 2     wickets            9.0        130.0          20.0          N    NaN
# 3     wickets            5.0        166.0          20.0          N    NaN
# 4     wickets            5.0        111.0          20.0          N    NaN
# ...       ...            ...          ...           ...        ...    ...
# 1090  wickets            4.0        215.0          20.0          N    NaN
# 1091  wickets            8.0        160.0          20.0          N    NaN
# 1092  wickets            4.0        173.0          20.0          N    NaN
# 1093     runs           36.0        176.0          20.0          N    NaN
# 1094  wickets            8.0        114.0          20.0          N    NaN
#
#                     umpire1               umpire2
# 0                 Asad Rauf           RE Koertzen
# 1                 MR Benson            SL Shastri
# 2                 Aleem Dar        GA Pratapkumar
# 3                  SJ Davis             DJ Harper
# 4                 BF Bowden           K Hariharan
# ...                     ...                   ...
# 1090            Nitin Menon             VK Sharma
# 1091           AK Chaudhary              R Pandit
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar
# 1093            Nitin Menon             VK Sharma
# 1094          J Madanagopal           Nitin Menon
#
# [1095 rows x 20 columns]
