# %%
import numpy as np
import pandas as pd

# %%
deliveries=pd.read_csv(r"C:\Users\pooja\OneDrive\Desktop\ipl-rough\deliveries.csv")
deliveries.sample(7)
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 195905   1254067       1  Royal Challengers Bangalore  Kolkata Knight Riders
# 123717    980911       1      Rising Pune Supergiants          Gujarat Lions
# 79198     598009       2                Pune Warriors       Rajasthan Royals
# 230550   1359493       2        Kolkata Knight Riders    Sunrisers Hyderabad
# 45807     501216       1              Deccan Chargers       Delhi Daredevils
# 101623    733989       2             Rajasthan Royals    Sunrisers Hyderabad
# 224577   1304115       1               Delhi Capitals         Mumbai Indians
#
#         over  ball          batter       bowler   non_striker  batsman_runs  \
# 195905    14     3  AB de Villiers     CV Varun    GJ Maxwell             4
# 123717    11     3    KP Pietersen  JP Faulkner  F du Plessis             1
# 79198     10     4        AJ Finch    KK Cooper   LRPL Taylor             0
# 230550    14     5          N Rana      B Kumar      RK Singh             1
# 45807      1     4   KC Sangakkara    IK Pathan       S Sohal             0
# 101623     4     4       SR Watson      B Kumar     SV Samson             0
# 224577    11     2        R Powell   HR Shokeen       RR Pant             0
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 195905           0           4         NaN          0              NaN
# 123717           0           1         NaN          0              NaN
# 79198            0           0         NaN          0              NaN
# 230550           0           1         NaN          0              NaN
# 45807            0           0         NaN          0              NaN
# 101623           1           1       wides          0              NaN
# 224577           1           1       wides          0              NaN
#
#        dismissal_kind fielder
# 195905            NaN     NaN
# 123717            NaN     NaN
# 79198             NaN     NaN
# 230550            NaN     NaN
# 45807             NaN     NaN
# 101623            NaN     NaN
# 224577            NaN     NaN

# %%
matches=pd.read_csv(r"C:\Users\pooja\OneDrive\Desktop\ipl-rough\matches.csv")
matches.sample(7)
# Out:
#            id   season        city        date match_type player_of_match  \
# 739   1178419     2019     Chennai  2019-04-26     League       RG Sharma
# 788   1216509  2020/21         NaN  2020-10-17     League        S Dhawan
# 1018  1359543     2023      Mumbai  2023-05-21     League         C Green
# 1050  1426265     2024      Mohali  2024-04-13     League      SO Hetmyer
# 858   1254103     2021       Dubai  2021-09-29     League       YS Chahal
# 117    419108  2009/10  Chandigarh  2010-03-13     League       G Gambhir
# 6      335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
#
#                                                   venue                team1  \
# 739                              MA Chidambaram Stadium       Mumbai Indians
# 788                             Sharjah Cricket Stadium  Chennai Super Kings
# 1018                           Wankhede Stadium, Mumbai  Sunrisers Hyderabad
# 1050  Maharaja Yadavindra Singh International Cricke...         Punjab Kings
# 858                 Dubai International Cricket Stadium     Rajasthan Royals
# 117          Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
# 6             Rajiv Gandhi International Stadium, Uppal      Deccan Chargers
#
#                             team2                  toss_winner toss_decision  \
# 739           Chennai Super Kings          Chennai Super Kings         field
# 788                Delhi Capitals          Chennai Super Kings           bat
# 1018               Mumbai Indians               Mumbai Indians         field
# 1050             Rajasthan Royals             Rajasthan Royals         field
# 858   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 117              Delhi Daredevils             Delhi Daredevils         field
# 6                Delhi Daredevils              Deccan Chargers           bat
#
#                            winner   result  result_margin  target_runs  \
# 739                Mumbai Indians     runs           46.0        156.0
# 788                Delhi Capitals  wickets            5.0        180.0
# 1018               Mumbai Indians  wickets            8.0        201.0
# 1050             Rajasthan Royals  wickets            3.0        148.0
# 858   Royal Challengers Bangalore  wickets            7.0        150.0
# 117              Delhi Daredevils  wickets            5.0        143.0
# 6                Delhi Daredevils  wickets            9.0        143.0
#
#       target_overs super_over method                umpire1  \
# 739           20.0          N    NaN           AK Chaudhary
# 788           20.0          N    NaN  KN Ananthapadmanabhan
# 1018          20.0          N    NaN  KN Ananthapadmanabhan
# 1050          20.0          N    NaN           AK Chaudhary
# 858           20.0          N    NaN            AY Dandekar
# 117           20.0          N    NaN            BR Doctrove
# 6             20.0          N    NaN              IL Howell
#
#                     umpire2
# 739                NJ Llong
# 788          RK Illingworth
# 1018              RJ Tucker
# 1050           Tapan Sharma
# 858   KN Ananthapadmanabhan
# 117                  S Ravi
# 6                 AM Saheba

# %%
def change_name(team_name):
    if team_name in ['Rising Pune Supergiants','Pune Warriors']:
        return 'Rising Pune Supergiant'
    elif team_name=='Royal Challengers Bengaluru':
        return 'Royal Challengers Bangalore'
    elif team_name=='Deccan Chargers':
        return 'Sunrisers Hyderabad'
    elif team_name == 'Delhi Daredevils':
        return 'Delhi Capitals'
    elif team_name== 'Gujarat Lions':
        return 'Gujarat Titans'
    elif team_name == 'Kings XI Punjab':
        return 'Punjab Kings'
    else:
        return team_name

# %%
deliveries['batting_team']=deliveries['batting_team'].apply(change_name)
deliveries['bowling_team']=deliveries['bowling_team'].apply(change_name)
matches['team1']=matches['team1'].apply(change_name)
matches['team2']=matches['team2'].apply(change_name)
matches['winner']=matches['winner'].apply(change_name)
matches['toss_winner']=matches['toss_winner'].apply(change_name)

# %%
# Mapping dictionary for cleaning
venue_mapping = {
    'M Chinnaswamy Stadium, Bengaluru': 'M Chinnaswamy Stadium',
    'M.Chinnaswamy Stadium': 'M Chinnaswamy Stadium',
    'Punjab Cricket Association Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh': 'Punjab Cricket Association IS Bindra Stadium',
    'MA Chidambaram Stadium, Chepauk': 'MA Chidambaram Stadium',
    'MA Chidambaram Stadium, Chepauk, Chennai': 'MA Chidambaram Stadium',
    'Wankhede Stadium, Mumbai': 'Wankhede Stadium',
    'Arun Jaitley Stadium, Delhi': 'Arun Jaitley Stadium',
    'Eden Gardens, Kolkata': 'Eden Gardens',
    'Rajiv Gandhi International Stadium, Uppal': 'Rajiv Gandhi International Stadium',
    'Rajiv Gandhi International Stadium, Uppal, Hyderabad': 'Rajiv Gandhi International Stadium',
    'Dr DY Patil Sports Academy, Mumbai': 'Dr DY Patil Sports Academy',
    'Maharashtra Cricket Association Stadium, Pune': 'Maharashtra Cricket Association Stadium',
    'Himachal Pradesh Cricket Association Stadium, Dharamsala': 'Himachal Pradesh Cricket Association Stadium',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam': 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
    'Brabourne Stadium, Mumbai':'Brabourne Stadium',
    'Sawai Mansingh Stadium, Jaipur':'Sawai Mansingh Stadium',
    'Narendra Modi Stadium, Ahmedabad': 'Narendra Modi Stadium',
    'Zayed Cricket Stadium, Abu Dhabi': 'Zayed Cricket Stadium',
    'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow': 'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium',
    'Barsapara Cricket Stadium, Guwahati': 'Barsapara Cricket Stadium',
    'Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur': 'Maharaja Yadavindra Singh International Cricket Stadium'
    
    # Add more mappings as necessary
}

# Replace venue names
matches['venue']=matches['venue'].replace(venue_mapping)

# %%
venue_to_city = {
    'M Chinnaswamy Stadium': 'Bengaluru',
    'Punjab Cricket Association IS Bindra Stadium': 'Mohali',
    'Feroz Shah Kotla': 'Delhi',
    'Wankhede Stadium': 'Mumbai',
    'Eden Gardens': 'Kolkata',
    'Sawai Mansingh Stadium': 'Jaipur',
    'Rajiv Gandhi International Stadium': 'Hyderabad',
    'MA Chidambaram Stadium': 'Chennai',
    'Dr DY Patil Sports Academy': 'Mumbai',
    'Newlands': 'Cape Town',
    "St George's Park": 'Port Elizabeth',
    'Kingsmead': 'Durban',
    'SuperSport Park': 'Centurion',
    'Buffalo Park': 'East London',
    'New Wanderers Stadium': 'Johannesburg',
    'De Beers Diamond Oval': 'Kimberley',
    'OUTsurance Oval': 'Bloemfontein',
    'Brabourne Stadium': 'Mumbai',
    'Sardar Patel Stadium, Motera': 'Ahmedabad',
    'Barabati Stadium': 'Cuttack',
    'Vidarbha Cricket Association Stadium, Jamtha': 'Nagpur',
    'Himachal Pradesh Cricket Association Stadium': 'Dharamshala',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': 'Visakhapatnam',
    'Subrata Roy Sahara Stadium': 'Pune',
    'Shaheed Veer Narayan Singh International Stadium': 'Raipur',
    'JSCA International Stadium Complex': 'Ranchi',
    'Sheikh Zayed Stadium': 'Abu Dhabi',
    'Sharjah Cricket Stadium': 'Sharjah',
    'Dubai International Cricket Stadium': 'Dubai',
    'Maharashtra Cricket Association Stadium': 'Pune',
    'Saurashtra Cricket Association Stadium': 'Rajkot',
    'Green Park': 'Kanpur',
    'Holkar Cricket Stadium': 'Indore',
    'Arun Jaitley Stadium': 'Delhi',
    'Narendra Modi Stadium': 'Ahmedabad',
    'Zayed Cricket Stadium': 'Abu Dhabi',
    'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium': 'Lucknow',
    'Barsapara Cricket Stadium': 'Guwahati',
    'Maharaja Yadavindra Singh International Cricket Stadium': 'Chandigarh'
}

matches['city']=matches['venue'].map(venue_to_city)

# %%
matches.rename(columns={'id':'match_id'},inplace=True)

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1090 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
matches['date']=pd.to_datetime(matches['date'])
matches['season']=matches['date'].dt.year

# %% [markdown]
# ### Plan of action

# %% [markdown]
# - creating a dataframe containing
#     - team1
#     - team2
#     - season
#     - city
#     - venue
#     - winner
#     - target runs of both teams
#     - inning

# %%
dashboard_data=matches[['match_id','team1','team2','city','venue','season','team1_runs','team2_runs','winner']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dashboard_data=matches[['match_id','team1','team2','city','venue','season','team1_runs','team2_runs','winner']]
#
# NameError: name 'matches' is not defined

# %%
dashboard_data=dashboard_data.dropna()

# %%
dashboard_data.astype()

# %%
dashboard_data.to_csv('dashboard_ipl.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dashboard_data.to_csv('dashboard_ipl.csv',index=False)
#
# NameError: name 'dashboard_data' is not defined
