# %%
# importing basic libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score,r2_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Gathering

# %%
deliveries=pd.read_csv(r"C:\Users\pooja\OneDrive\Desktop\ipl-rough\deliveries.csv")
deliveries.sample(7)
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 175789   1178421       2  Royal Challengers Bangalore         Delhi Capitals
# 170817   1178400       2          Chennai Super Kings       Rajasthan Royals
# 111383    829725       1              Kings XI Punjab       Delhi Daredevils
# 260772   1426312       1          Sunrisers Hyderabad  Kolkata Knight Riders
# 37778     419149       2              Kings XI Punjab       Delhi Daredevils
# 68207     548348       1              Deccan Chargers          Pune Warriors
# 31292     419123       1  Royal Challengers Bangalore    Chennai Super Kings
#
#         over  ball         batter      bowler          non_striker  \
# 175789     3     5        V Kohli    K Rabada             PA Patel
# 170817    19     8     MJ Santner   BA Stokes            RA Jadeja
# 111383    13     1        WP Saha    A Mishra             V Sehwag
# 260772     5     4     AK Markram    VG Arora  Nithish Kumar Reddy
# 37778     16     6   Yuvraj Singh  DL Vettori        KC Sangakkara
# 68207      9     1  KC Sangakkara    M Kartik             CL White
# 31292     13     4        V Kohli    L Balaji           RV Uthappa
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 175789             1           0           1         NaN          0
# 170817             6           0           6         NaN          0
# 111383             1           0           1         NaN          0
# 260772             1           0           1         NaN          0
# 37778              4           0           4         NaN          0
# 68207              1           0           1         NaN          0
# 31292              1           0           1         NaN          0
#
#        player_dismissed dismissal_kind fielder
# 175789              NaN            NaN     NaN
# 170817              NaN            NaN     NaN
# 111383              NaN            NaN     NaN
# 260772              NaN            NaN     NaN
# 37778               NaN            NaN     NaN
# 68207               NaN            NaN     NaN
# 31292               NaN            NaN     NaN

# %%
matches=pd.read_csv(r"C:\Users\pooja\OneDrive\Desktop\ipl-rough\matches.csv")
matches.sample(7)
# Out:
#           id   season        city        date  match_type  player_of_match  \
# 633  1082648     2017   Bangalore  2017-05-17  Eliminator  NM Coulter-Nile
# 543   980953     2016   Hyderabad  2016-04-30      League        DA Warner
# 387   598063     2013      Mumbai  2013-05-15      League          AP Tare
# 611  1082626     2017  Chandigarh  2017-04-30      League   Sandeep Sharma
# 480   829751     2015      Mumbai  2015-04-25      League       SL Malinga
# 995  1359520     2023  Chandigarh  2023-05-03      League     Ishan Kishan
# 809  1216530  2020/21         NaN  2020-11-01      League       PJ Cummins
#
#                                                  venue                  team1  \
# 633                              M Chinnaswamy Stadium    Sunrisers Hyderabad
# 543          Rajiv Gandhi International Stadium, Uppal    Sunrisers Hyderabad
# 387                                   Wankhede Stadium         Mumbai Indians
# 611  Punjab Cricket Association IS Bindra Stadium, ...        Kings XI Punjab
# 480                                   Wankhede Stadium         Mumbai Indians
# 995  Punjab Cricket Association IS Bindra Stadium, ...           Punjab Kings
# 809                Dubai International Cricket Stadium  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 543  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 387             Rajasthan Royals             Rajasthan Royals         field
# 611             Delhi Daredevils              Kings XI Punjab         field
# 480          Sunrisers Hyderabad               Mumbai Indians           bat
# 995               Mumbai Indians               Mumbai Indians         field
# 809             Rajasthan Royals             Rajasthan Royals         field
#
#                     winner   result  result_margin  target_runs  target_overs  \
# 633  Kolkata Knight Riders  wickets            7.0         48.0           6.0
# 543    Sunrisers Hyderabad     runs           15.0        195.0          20.0
# 387         Mumbai Indians     runs           14.0        167.0          20.0
# 611        Kings XI Punjab  wickets           10.0         68.0          20.0
# 480         Mumbai Indians     runs           20.0        158.0          20.0
# 995         Mumbai Indians  wickets            6.0        215.0          20.0
# 809  Kolkata Knight Riders     runs           60.0        192.0          20.0
#
#     super_over method          umpire1          umpire2
# 633          N    D/L     AK Chaudhary      Nitin Menon
# 543          N    NaN     AK Chaudhary  HDPK Dharmasena
# 387          N    NaN        Asad Rauf         S Asnani
# 611          N    NaN         YC Barde        CK Nandan
# 480          N    NaN  HDPK Dharmasena      CB Gaffaney
# 995          N    NaN    J Madanagopal        RJ Tucker
# 809          N    NaN      Nitin Menon       PR Reiffel

# %% [markdown]
# ### Data Cleaning

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
deliveries['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %% [markdown]
# 1. due to change in names of teams their are many teams so will convert into 8 teams.
# 2. as we are creating predictor we will consider only present 8 teams.

# %%
def change_name(team_name):
    if team_name in ['Rising Pune Supergiants','Pune Warriors']:
        return 'Rising Pune Supergiant'
    elif team_name=='Royal Challengers Bengaluru':
        return 'Royal Challengers Bangalore'
    elif team_name=='Deccan Chargers':
        return 'Sunrisers Hyderabad'
    elif team_name == 'Delhi Daredevils':
        return 'Delhi Capitals'
    elif team_name== 'Gujarat Lions':
        return 'Gujarat Titans'
    elif team_name == 'Kings XI Punjab':
        return 'Punjab Kings'
    else:
        return team_name

# %%
deliveries['batting_team']=deliveries['batting_team'].apply(change_name)
deliveries['bowling_team']=deliveries['bowling_team'].apply(change_name)
matches['team1']=matches['team1'].apply(change_name)
matches['team2']=matches['team2'].apply(change_name)

# %%
deliveries=deliveries[(deliveries['batting_team']!='Kochi Tuskers Kerala')&(deliveries['bowling_team']!='Kochi Tuskers Kerala')]
deliveries=deliveries[(deliveries['batting_team']!='Rising Pune Supergiant')&(deliveries['bowling_team']!='Rising Pune Supergiant')]
matches=matches[(matches['team1']!='Kochi Tuskers Kerala')&(matches['team2']!='Kochi Tuskers Kerala')]
matches=matches[(matches['team1']!='Rising Pune Supergiant')&(matches['team2']!='Rising Pune Supergiant')]

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240047 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          240047 non-null  int64
#  1   inning            240047 non-null  int64
#  2   batting_team      240047 non-null  object
#  3   bowling_team      240047 non-null  object
#  4   over              240047 non-null  int64
#  5   ball              240047 non-null  int64
#  6   batter            240047 non-null  object
#  7   bowler            240047 non-null  object
#  8   non_striker       240047 non-null  object
#  9   batsman_runs      240047 non-null  int64
#  10  extra_runs        240047 non-null  int64
#  11  total_runs        240047 non-null  int64
#  12  extras_type       13091 non-null   object
#  13  is_wicket         240047 non-null  int64
#  14  player_dismissed  11921 non-null   object
#  15  dismissal_kind    11921 non-null   object
#  16  fielder           8628 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.0+ MB

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1006 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1006 non-null   int64
#  1   season           1006 non-null   object
#  2   city             955 non-null    object
#  3   date             1006 non-null   object
#  4   match_type       1006 non-null   object
#  5   player_of_match  1002 non-null   object
#  6   venue            1006 non-null   object
#  7   team1            1006 non-null   object
#  8   team2            1006 non-null   object
#  9   toss_winner      1006 non-null   object
#  10  toss_decision    1006 non-null   object
#  11  winner           1002 non-null   object
#  12  result           1006 non-null   object
#  13  result_margin    988 non-null    float64
#  14  target_runs      1004 non-null   float64
#  15  target_overs     1004 non-null   float64
#  16  super_over       1006 non-null   object
#  17  method           17 non-null     object
#  18  umpire1          1006 non-null   object
#  19  umpire2          1006 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 165.0+ KB

# %% [markdown]
# ## runs left

# %%
total_runs_df=deliveries.groupby(['match_id','inning'])['total_runs'].sum().reset_index()
total_runs_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 1       335982       2          82
# 2       335983       1         240
# 3       335983       2         207
# 4       335984       1         129
# ...        ...     ...         ...
# 2035   1426310       2         174
# 2036   1426311       1         175
# 2037   1426311       2         139
# 2038   1426312       1         113
# 2039   1426312       2         114
#
# [2040 rows x 3 columns]

# %%
total_runs_df=total_runs_df[total_runs_df['inning']==1]

# %%
matches_df=matches.merge(total_runs_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
matches_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %%
matches_df=matches_df[['match_id','city','winner','total_runs','venue']]

# %%
delivery_df=matches_df.merge(deliveries,on='match_id')

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           222
# 125       335982  Bangalore  Kolkata Knight Riders           222
# 126       335982  Bangalore  Kolkata Knight Riders           222
# 127       335982  Bangalore  Kolkata Knight Riders           222
# 128       335982  Bangalore  Kolkata Knight Riders           222
# ...          ...        ...                    ...           ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113
# 240043   1426312    Chennai  Kolkata Knight Riders           113
# 240044   1426312    Chennai  Kolkata Knight Riders           113
# 240045   1426312    Chennai  Kolkata Knight Riders           113
# 240046   1426312    Chennai  Kolkata Knight Riders           113
#
#                                            venue  inning  \
# 124                        M Chinnaswamy Stadium       2
# 125                        M Chinnaswamy Stadium       2
# 126                        M Chinnaswamy Stadium       2
# 127                        M Chinnaswamy Stadium       2
# 128                        M Chinnaswamy Stadium       2
# ...                                          ...     ...
# 240042  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240043  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240044  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240045  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240046  MA Chidambaram Stadium, Chepauk, Chennai       2
#
#                        batting_team           bowling_team  over  ball  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5  ...
# ...                             ...                    ...   ...   ...  ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5  ...
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6  ...
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1  ...
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2  ...
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3  ...
#
#                bowler non_striker batsman_runs  extra_runs  total_runs_y  \
# 124          AB Dinda    W Jaffer            1           0             1
# 125          AB Dinda    R Dravid            0           1             1
# 126          AB Dinda    R Dravid            0           0             0
# 127          AB Dinda    R Dravid            1           0             1
# 128          AB Dinda    W Jaffer            1           0             1
# ...               ...         ...          ...         ...           ...
# 240042     AK Markram     VR Iyer            1           0             1
# 240043     AK Markram     SS Iyer            1           0             1
# 240044  Shahbaz Ahmed     SS Iyer            1           0             1
# 240045  Shahbaz Ahmed     VR Iyer            1           0             1
# 240046  Shahbaz Ahmed     SS Iyer            1           0             1
#
#         extras_type is_wicket  player_dismissed dismissal_kind fielder
# 124             NaN         0               NaN            NaN     NaN
# 125           wides         0               NaN            NaN     NaN
# 126             NaN         0               NaN            NaN     NaN
# 127             NaN         0               NaN            NaN     NaN
# 128             NaN         0               NaN            NaN     NaN
# ...             ...       ...               ...            ...     ...
# 240042          NaN         0               NaN            NaN     NaN
# 240043          NaN         0               NaN            NaN     NaN
# 240044          NaN         0               NaN            NaN     NaN
# 240045          NaN         0               NaN            NaN     NaN
# 240046          NaN         0               NaN            NaN     NaN
#
# [115732 rows x 21 columns]

# %%
delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           222
# 125       335982  Bangalore  Kolkata Knight Riders           222
# 126       335982  Bangalore  Kolkata Knight Riders           222
# 127       335982  Bangalore  Kolkata Knight Riders           222
# 128       335982  Bangalore  Kolkata Knight Riders           222
# ...          ...        ...                    ...           ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113
# 240043   1426312    Chennai  Kolkata Knight Riders           113
# 240044   1426312    Chennai  Kolkata Knight Riders           113
# 240045   1426312    Chennai  Kolkata Knight Riders           113
# 240046   1426312    Chennai  Kolkata Knight Riders           113
#
#                                            venue  inning  \
# 124                        M Chinnaswamy Stadium       2
# 125                        M Chinnaswamy Stadium       2
# 126                        M Chinnaswamy Stadium       2
# 127                        M Chinnaswamy Stadium       2
# 128                        M Chinnaswamy Stadium       2
# ...                                          ...     ...
# 240042  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240043  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240044  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240045  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240046  MA Chidambaram Stadium, Chepauk, Chennai       2
#
#                        batting_team           bowling_team  over  ball  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5  ...
# ...                             ...                    ...   ...   ...  ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5  ...
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6  ...
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1  ...
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2  ...
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3  ...
#
#        batsman_runs extra_runs total_runs_y  extras_type  is_wicket  \
# 124               1          0            1          NaN          0
# 125               0          1            1        wides          0
# 126               0          0            0          NaN          0
# 127               1          0            1          NaN          0
# 128               1          0            1          NaN          0
# ...             ...        ...          ...          ...        ...
# 240042            1          0            1          NaN          0
# 240043            1          0            1          NaN          0
# 240044            1          0            1          NaN          0
# 240045            1          0            1          NaN          0
# 240046            1          0            1          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_score runs_left
# 124                  NaN            NaN      NaN             1       221
# 125                  NaN            NaN      NaN             2       220
# 126                  NaN            NaN      NaN             2       220
# 127                  NaN            NaN      NaN             3       219
# 128                  NaN            NaN      NaN             4       218
# ...                  ...            ...      ...           ...       ...
# 240042               NaN            NaN      NaN           110         3
# 240043               NaN            NaN      NaN           111         2
# 240044               NaN            NaN      NaN           112         1
# 240045               NaN            NaN      NaN           113         0
# 240046               NaN            NaN      NaN           114        -1
#
# [115732 rows x 23 columns]

# %% [markdown]
# - Ball left

# %%
delivery_df['ball_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           222
# 125       335982  Bangalore  Kolkata Knight Riders           222
# 126       335982  Bangalore  Kolkata Knight Riders           222
# 127       335982  Bangalore  Kolkata Knight Riders           222
# 128       335982  Bangalore  Kolkata Knight Riders           222
# ...          ...        ...                    ...           ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113
# 240043   1426312    Chennai  Kolkata Knight Riders           113
# 240044   1426312    Chennai  Kolkata Knight Riders           113
# 240045   1426312    Chennai  Kolkata Knight Riders           113
# 240046   1426312    Chennai  Kolkata Knight Riders           113
#
#                                            venue  inning  \
# 124                        M Chinnaswamy Stadium       2
# 125                        M Chinnaswamy Stadium       2
# 126                        M Chinnaswamy Stadium       2
# 127                        M Chinnaswamy Stadium       2
# 128                        M Chinnaswamy Stadium       2
# ...                                          ...     ...
# 240042  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240043  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240044  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240045  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240046  MA Chidambaram Stadium, Chepauk, Chennai       2
#
#                        batting_team           bowling_team  over  ball  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5  ...
# ...                             ...                    ...   ...   ...  ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5  ...
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6  ...
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1  ...
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2  ...
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3  ...
#
#        extra_runs total_runs_y extras_type  is_wicket  player_dismissed  \
# 124             0            1         NaN          0               NaN
# 125             1            1       wides          0               NaN
# 126             0            0         NaN          0               NaN
# 127             0            1         NaN          0               NaN
# 128             0            1         NaN          0               NaN
# ...           ...          ...         ...        ...               ...
# 240042          0            1         NaN          0               NaN
# 240043          0            1         NaN          0               NaN
# 240044          0            1         NaN          0               NaN
# 240045          0            1         NaN          0               NaN
# 240046          0            1         NaN          0               NaN
#
#         dismissal_kind fielder  current_score runs_left ball_left
# 124                NaN     NaN              1       221       119
# 125                NaN     NaN              2       220       118
# 126                NaN     NaN              2       220       117
# 127                NaN     NaN              3       219       116
# 128                NaN     NaN              4       218       115
# ...                ...     ...            ...       ...       ...
# 240042             NaN     NaN            110         3        61
# 240043             NaN     NaN            111         2        60
# 240044             NaN     NaN            112         1        59
# 240045             NaN     NaN            113         0        58
# 240046             NaN     NaN            114        -1        57
#
# [115732 rows x 24 columns]

# %% [markdown]
# - wicket left

# %%
wicket=delivery_df.groupby('match_id')['is_wicket'].cumsum()
delivery_df['wicket_left']=10-wicket

# %%
delivery_df.head(20)
# Out:
#      match_id       city                 winner  total_runs_x  \
# 124    335982  Bangalore  Kolkata Knight Riders           222
# 125    335982  Bangalore  Kolkata Knight Riders           222
# 126    335982  Bangalore  Kolkata Knight Riders           222
# 127    335982  Bangalore  Kolkata Knight Riders           222
# 128    335982  Bangalore  Kolkata Knight Riders           222
# 129    335982  Bangalore  Kolkata Knight Riders           222
# 130    335982  Bangalore  Kolkata Knight Riders           222
# 131    335982  Bangalore  Kolkata Knight Riders           222
# 132    335982  Bangalore  Kolkata Knight Riders           222
# 133    335982  Bangalore  Kolkata Knight Riders           222
# 134    335982  Bangalore  Kolkata Knight Riders           222
# 135    335982  Bangalore  Kolkata Knight Riders           222
# 136    335982  Bangalore  Kolkata Knight Riders           222
# 137    335982  Bangalore  Kolkata Knight Riders           222
# 138    335982  Bangalore  Kolkata Knight Riders           222
# 139    335982  Bangalore  Kolkata Knight Riders           222
# 140    335982  Bangalore  Kolkata Knight Riders           222
# 141    335982  Bangalore  Kolkata Knight Riders           222
# 142    335982  Bangalore  Kolkata Knight Riders           222
# 143    335982  Bangalore  Kolkata Knight Riders           222
#
#                      venue  inning                 batting_team  \
# 124  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 125  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 126  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 127  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 128  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 129  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 130  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 131  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 132  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 133  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 134  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 135  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 136  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 137  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 138  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 139  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 140  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 141  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 142  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
# 143  M Chinnaswamy Stadium       2  Royal Challengers Bangalore
#
#               bowling_team  over  ball  ... total_runs_y extras_type  \
# 124  Kolkata Knight Riders     0     1  ...            1         NaN
# 125  Kolkata Knight Riders     0     2  ...            1       wides
# 126  Kolkata Knight Riders     0     3  ...            0         NaN
# 127  Kolkata Knight Riders     0     4  ...            1         NaN
# 128  Kolkata Knight Riders     0     5  ...            1         NaN
# 129  Kolkata Knight Riders     0     6  ...            0         NaN
# 130  Kolkata Knight Riders     0     7  ...            0         NaN
# 131  Kolkata Knight Riders     1     1  ...            0         NaN
# 132  Kolkata Knight Riders     1     2  ...            0         NaN
# 133  Kolkata Knight Riders     1     3  ...            4     legbyes
# 134  Kolkata Knight Riders     1     4  ...            1         NaN
# 135  Kolkata Knight Riders     1     5  ...            0         NaN
# 136  Kolkata Knight Riders     1     6  ...            0         NaN
# 137  Kolkata Knight Riders     2     1  ...            0         NaN
# 138  Kolkata Knight Riders     2     2  ...            0         NaN
# 139  Kolkata Knight Riders     2     3  ...            1         NaN
# 140  Kolkata Knight Riders     2     4  ...            0         NaN
# 141  Kolkata Knight Riders     2     5  ...            1       wides
# 142  Kolkata Knight Riders     2     6  ...            0         NaN
# 143  Kolkata Knight Riders     2     7  ...            1         NaN
#
#     is_wicket  player_dismissed  dismissal_kind  fielder current_score  \
# 124         0               NaN             NaN      NaN             1
# 125         0               NaN             NaN      NaN             2
# 126         0               NaN             NaN      NaN             2
# 127         0               NaN             NaN      NaN             3
# 128         0               NaN             NaN      NaN             4
# 129         0               NaN             NaN      NaN             4
# 130         0               NaN             NaN      NaN             4
# 131         1          R Dravid          bowled      NaN             4
# 132         0               NaN             NaN      NaN             4
# 133         0               NaN             NaN      NaN             8
# 134         0               NaN             NaN      NaN             9
# 135         0               NaN             NaN      NaN             9
# 136         0               NaN             NaN      NaN             9
# 137         0               NaN             NaN      NaN             9
# 138         1           V Kohli          bowled      NaN             9
# 139         0               NaN             NaN      NaN            10
# 140         0               NaN             NaN      NaN            10
# 141         0               NaN             NaN      NaN            11
# 142         0               NaN             NaN      NaN            11
# 143         0               NaN             NaN      NaN            12
#
#      runs_left ball_left wicket_left
# 124        221       119          10
# 125        220       118          10
# 126        220       117          10
# 127        219       116          10
# 128        218       115          10
# 129        218       114          10
# 130        218       113          10
# 131        218       113           9
# 132        218       112           9
# 133        214       111           9
# 134        213       110           9
# 135        213       109           9
# 136        213       108           9
# 137        213       107           9
# 138        213       106           8
# 139        212       105           8
# 140        212       104           8
# 141        211       103           8
# 142        211       102           8
# 143        210       101           8
#
# [20 rows x 25 columns]

# %% [markdown]
# - current_runrate

# %%
delivery_df['crr']=round(delivery_df['current_score']*6/(120-delivery_df['ball_left']),2)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           222
# 125       335982  Bangalore  Kolkata Knight Riders           222
# 126       335982  Bangalore  Kolkata Knight Riders           222
# 127       335982  Bangalore  Kolkata Knight Riders           222
# 128       335982  Bangalore  Kolkata Knight Riders           222
# ...          ...        ...                    ...           ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113
# 240043   1426312    Chennai  Kolkata Knight Riders           113
# 240044   1426312    Chennai  Kolkata Knight Riders           113
# 240045   1426312    Chennai  Kolkata Knight Riders           113
# 240046   1426312    Chennai  Kolkata Knight Riders           113
#
#                                            venue  inning  \
# 124                        M Chinnaswamy Stadium       2
# 125                        M Chinnaswamy Stadium       2
# 126                        M Chinnaswamy Stadium       2
# 127                        M Chinnaswamy Stadium       2
# 128                        M Chinnaswamy Stadium       2
# ...                                          ...     ...
# 240042  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240043  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240044  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240045  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240046  MA Chidambaram Stadium, Chepauk, Chennai       2
#
#                        batting_team           bowling_team  over  ball  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5  ...
# ...                             ...                    ...   ...   ...  ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5  ...
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6  ...
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1  ...
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2  ...
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3  ...
#
#        extras_type is_wicket player_dismissed  dismissal_kind  fielder  \
# 124            NaN         0              NaN             NaN      NaN
# 125          wides         0              NaN             NaN      NaN
# 126            NaN         0              NaN             NaN      NaN
# 127            NaN         0              NaN             NaN      NaN
# 128            NaN         0              NaN             NaN      NaN
# ...            ...       ...              ...             ...      ...
# 240042         NaN         0              NaN             NaN      NaN
# 240043         NaN         0              NaN             NaN      NaN
# 240044         NaN         0              NaN             NaN      NaN
# 240045         NaN         0              NaN             NaN      NaN
# 240046         NaN         0              NaN             NaN      NaN
#
#         current_score runs_left  ball_left wicket_left    crr
# 124                 1       221        119          10   6.00
# 125                 2       220        118          10   6.00
# 126                 2       220        117          10   4.00
# 127                 3       219        116          10   4.50
# 128                 4       218        115          10   4.80
# ...               ...       ...        ...         ...    ...
# 240042            110         3         61           8  11.19
# 240043            111         2         60           8  11.10
# 240044            112         1         59           8  11.02
# 240045            113         0         58           8  10.94
# 240046            114        -1         57           8  10.86
#
# [115732 rows x 26 columns]

# %% [markdown]
# - rrr

# %%
delivery_df['rrr']=round((delivery_df['runs_left']*6)/delivery_df['ball_left'],2)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           222
# 125       335982  Bangalore  Kolkata Knight Riders           222
# 126       335982  Bangalore  Kolkata Knight Riders           222
# 127       335982  Bangalore  Kolkata Knight Riders           222
# 128       335982  Bangalore  Kolkata Knight Riders           222
# ...          ...        ...                    ...           ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113
# 240043   1426312    Chennai  Kolkata Knight Riders           113
# 240044   1426312    Chennai  Kolkata Knight Riders           113
# 240045   1426312    Chennai  Kolkata Knight Riders           113
# 240046   1426312    Chennai  Kolkata Knight Riders           113
#
#                                            venue  inning  \
# 124                        M Chinnaswamy Stadium       2
# 125                        M Chinnaswamy Stadium       2
# 126                        M Chinnaswamy Stadium       2
# 127                        M Chinnaswamy Stadium       2
# 128                        M Chinnaswamy Stadium       2
# ...                                          ...     ...
# 240042  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240043  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240044  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240045  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240046  MA Chidambaram Stadium, Chepauk, Chennai       2
#
#                        batting_team           bowling_team  over  ball  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5  ...
# ...                             ...                    ...   ...   ...  ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5  ...
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6  ...
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1  ...
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2  ...
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3  ...
#
#        is_wicket player_dismissed dismissal_kind  fielder  current_score  \
# 124            0              NaN            NaN      NaN              1
# 125            0              NaN            NaN      NaN              2
# 126            0              NaN            NaN      NaN              2
# 127            0              NaN            NaN      NaN              3
# 128            0              NaN            NaN      NaN              4
# ...          ...              ...            ...      ...            ...
# 240042         0              NaN            NaN      NaN            110
# 240043         0              NaN            NaN      NaN            111
# 240044         0              NaN            NaN      NaN            112
# 240045         0              NaN            NaN      NaN            113
# 240046         0              NaN            NaN      NaN            114
#
#         runs_left ball_left  wicket_left    crr    rrr
# 124           221       119           10   6.00  11.14
# 125           220       118           10   6.00  11.19
# 126           220       117           10   4.00  11.28
# 127           219       116           10   4.50  11.33
# 128           218       115           10   4.80  11.37
# ...           ...       ...          ...    ...    ...
# 240042          3        61            8  11.19   0.30
# 240043          2        60            8  11.10   0.20
# 240044          1        59            8  11.02   0.10
# 240045          0        58            8  10.94   0.00
# 240046         -1        57            8  10.86  -0.11
#
# [115732 rows x 27 columns]

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           222
# 125       335982  Bangalore  Kolkata Knight Riders           222
# 126       335982  Bangalore  Kolkata Knight Riders           222
# 127       335982  Bangalore  Kolkata Knight Riders           222
# 128       335982  Bangalore  Kolkata Knight Riders           222
# ...          ...        ...                    ...           ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113
# 240043   1426312    Chennai  Kolkata Knight Riders           113
# 240044   1426312    Chennai  Kolkata Knight Riders           113
# 240045   1426312    Chennai  Kolkata Knight Riders           113
# 240046   1426312    Chennai  Kolkata Knight Riders           113
#
#                                            venue  inning  \
# 124                        M Chinnaswamy Stadium       2
# 125                        M Chinnaswamy Stadium       2
# 126                        M Chinnaswamy Stadium       2
# 127                        M Chinnaswamy Stadium       2
# 128                        M Chinnaswamy Stadium       2
# ...                                          ...     ...
# 240042  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240043  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240044  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240045  MA Chidambaram Stadium, Chepauk, Chennai       2
# 240046  MA Chidambaram Stadium, Chepauk, Chennai       2
#
#                        batting_team           bowling_team  over  ball  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5  ...
# ...                             ...                    ...   ...   ...  ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5  ...
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6  ...
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1  ...
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2  ...
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3  ...
#
#        player_dismissed dismissal_kind fielder  current_score  runs_left  \
# 124                 NaN            NaN     NaN              1        221
# 125                 NaN            NaN     NaN              2        220
# 126                 NaN            NaN     NaN              2        220
# 127                 NaN            NaN     NaN              3        219
# 128                 NaN            NaN     NaN              4        218
# ...                 ...            ...     ...            ...        ...
# 240042              NaN            NaN     NaN            110          3
# 240043              NaN            NaN     NaN            111          2
# 240044              NaN            NaN     NaN            112          1
# 240045              NaN            NaN     NaN            113          0
# 240046              NaN            NaN     NaN            114         -1
#
#         ball_left wicket_left    crr    rrr result
# 124           119          10   6.00  11.14      0
# 125           118          10   6.00  11.19      0
# 126           117          10   4.00  11.28      0
# 127           116          10   4.50  11.33      0
# 128           115          10   4.80  11.37      0
# ...           ...         ...    ...    ...    ...
# 240042         61           8  11.19   0.30      1
# 240043         60           8  11.10   0.20      1
# 240044         59           8  11.02   0.10      1
# 240045         58           8  10.94   0.00      1
# 240046         57           8  10.86  -0.11      1
#
# [115732 rows x 28 columns]

# %%
final_df=delivery_df[['batting_team','bowling_team','city','runs_left','venue','ball_left','wicket_left','crr','rrr','result']]

# %%
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left                                     venue  ball_left  \
# 124           221                     M Chinnaswamy Stadium        119
# 125           220                     M Chinnaswamy Stadium        118
# 126           220                     M Chinnaswamy Stadium        117
# 127           219                     M Chinnaswamy Stadium        116
# 128           218                     M Chinnaswamy Stadium        115
# ...           ...                                       ...        ...
# 240042          3  MA Chidambaram Stadium, Chepauk, Chennai         61
# 240043          2  MA Chidambaram Stadium, Chepauk, Chennai         60
# 240044          1  MA Chidambaram Stadium, Chepauk, Chennai         59
# 240045          0  MA Chidambaram Stadium, Chepauk, Chennai         58
# 240046         -1  MA Chidambaram Stadium, Chepauk, Chennai         57
#
#         wicket_left    crr    rrr  result
# 124              10   6.00  11.14       0
# 125              10   6.00  11.19       0
# 126              10   4.00  11.28       0
# 127              10   4.50  11.33       0
# 128              10   4.80  11.37       0
# ...             ...    ...    ...     ...
# 240042            8  11.19   0.30       1
# 240043            8  11.10   0.20       1
# 240044            8  11.02   0.10       1
# 240045            8  10.94   0.00       1
# 240046            8  10.86  -0.11       1
#
# [115732 rows x 10 columns]

# %%
final_df.venue.unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association IS Bindra Stadium', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium', 'MA Chidambaram Stadium',
#        'Dr DY Patil Sports Academy', 'Newlands', "St George's Park",
#        'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Brabourne Stadium, Mumbai',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
#        'Sharjah Cricket Stadium', 'Dubai International Cricket Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Saurashtra Cricket Association Stadium', 'Green Park',
#        'Holkar Cricket Stadium', 'Arun Jaitley Stadium',
#        'Narendra Modi Stadium, Ahmedabad',
#        'Zayed Cricket Stadium, Abu Dhabi',
#        'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow',
#        'Barsapara Cricket Stadium, Guwahati',
#        'Sawai Mansingh Stadium, Jaipur',
#        'Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur'],
#       dtype=object)

# %%
# Mapping dictionary for cleaning
venue_mapping = {
    'M Chinnaswamy Stadium, Bengaluru': 'M Chinnaswamy Stadium',
    'M.Chinnaswamy Stadium': 'M Chinnaswamy Stadium',
    'Punjab Cricket Association Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali': 'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh': 'Punjab Cricket Association IS Bindra Stadium',
    'MA Chidambaram Stadium, Chepauk': 'MA Chidambaram Stadium',
    'MA Chidambaram Stadium, Chepauk, Chennai': 'MA Chidambaram Stadium',
    'Wankhede Stadium, Mumbai': 'Wankhede Stadium',
    'Arun Jaitley Stadium, Delhi': 'Arun Jaitley Stadium',
    'Eden Gardens, Kolkata': 'Eden Gardens',
    'Rajiv Gandhi International Stadium, Uppal': 'Rajiv Gandhi International Stadium',
    'Rajiv Gandhi International Stadium, Uppal, Hyderabad': 'Rajiv Gandhi International Stadium',
    'Dr DY Patil Sports Academy, Mumbai': 'Dr DY Patil Sports Academy',
    'Maharashtra Cricket Association Stadium, Pune': 'Maharashtra Cricket Association Stadium',
    'Himachal Pradesh Cricket Association Stadium, Dharamsala': 'Himachal Pradesh Cricket Association Stadium',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam': 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
    'Brabourne Stadium, Mumbai':'Brabourne Stadium',
    'Sawai Mansingh Stadium, Jaipur':'Sawai Mansingh Stadium',
    'Narendra Modi Stadium, Ahmedabad': 'Narendra Modi Stadium',
    'Zayed Cricket Stadium, Abu Dhabi': 'Zayed Cricket Stadium',
    'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow': 'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium',
    'Barsapara Cricket Stadium, Guwahati': 'Barsapara Cricket Stadium',
    'Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur': 'Maharaja Yadavindra Singh International Cricket Stadium'
    
    # Add more mappings as necessary
}

# Replace venue names
final_df['venue']=final_df['venue'].replace(venue_mapping)
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_3256\3290223191.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['venue']=final_df['venue'].replace(venue_mapping)

# %%
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# ...                             ...                    ...        ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left                   venue  ball_left  wicket_left    crr  \
# 124           221   M Chinnaswamy Stadium        119           10   6.00
# 125           220   M Chinnaswamy Stadium        118           10   6.00
# 126           220   M Chinnaswamy Stadium        117           10   4.00
# 127           219   M Chinnaswamy Stadium        116           10   4.50
# 128           218   M Chinnaswamy Stadium        115           10   4.80
# ...           ...                     ...        ...          ...    ...
# 240042          3  MA Chidambaram Stadium         61            8  11.19
# 240043          2  MA Chidambaram Stadium         60            8  11.10
# 240044          1  MA Chidambaram Stadium         59            8  11.02
# 240045          0  MA Chidambaram Stadium         58            8  10.94
# 240046         -1  MA Chidambaram Stadium         57            8  10.86
#
#           rrr  result
# 124     11.14       0
# 125     11.19       0
# 126     11.28       0
# 127     11.33       0
# 128     11.37       0
# ...       ...     ...
# 240042   0.30       1
# 240043   0.20       1
# 240044   0.10       1
# 240045   0.00       1
# 240046  -0.11       1
#
# [115732 rows x 10 columns]

# %%
venue_to_city = {
    'M Chinnaswamy Stadium': 'Bengaluru',
    'Punjab Cricket Association IS Bindra Stadium': 'Mohali',
    'Feroz Shah Kotla': 'Delhi',
    'Wankhede Stadium': 'Mumbai',
    'Eden Gardens': 'Kolkata',
    'Sawai Mansingh Stadium': 'Jaipur',
    'Rajiv Gandhi International Stadium': 'Hyderabad',
    'MA Chidambaram Stadium': 'Chennai',
    'Dr DY Patil Sports Academy': 'Mumbai',
    'Newlands': 'Cape Town',
    "St George's Park": 'Port Elizabeth',
    'Kingsmead': 'Durban',
    'SuperSport Park': 'Centurion',
    'Buffalo Park': 'East London',
    'New Wanderers Stadium': 'Johannesburg',
    'De Beers Diamond Oval': 'Kimberley',
    'OUTsurance Oval': 'Bloemfontein',
    'Brabourne Stadium': 'Mumbai',
    'Sardar Patel Stadium, Motera': 'Ahmedabad',
    'Barabati Stadium': 'Cuttack',
    'Vidarbha Cricket Association Stadium, Jamtha': 'Nagpur',
    'Himachal Pradesh Cricket Association Stadium': 'Dharamshala',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': 'Visakhapatnam',
    'Subrata Roy Sahara Stadium': 'Pune',
    'Shaheed Veer Narayan Singh International Stadium': 'Raipur',
    'JSCA International Stadium Complex': 'Ranchi',
    'Sheikh Zayed Stadium': 'Abu Dhabi',
    'Sharjah Cricket Stadium': 'Sharjah',
    'Dubai International Cricket Stadium': 'Dubai',
    'Maharashtra Cricket Association Stadium': 'Pune',
    'Saurashtra Cricket Association Stadium': 'Rajkot',
    'Green Park': 'Kanpur',
    'Holkar Cricket Stadium': 'Indore',
    'Arun Jaitley Stadium': 'Delhi',
    'Narendra Modi Stadium': 'Ahmedabad',
    'Zayed Cricket Stadium': 'Abu Dhabi',
    'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium': 'Lucknow',
    'Barsapara Cricket Stadium': 'Guwahati',
    'Maharaja Yadavindra Singh International Cricket Stadium': 'Chandigarh'
}

final_df['city']=final_df['venue'].map(venue_to_city)
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_3256\385027823.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['city']=final_df['venue'].map(venue_to_city)

# %%
final_df['venue'].unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association IS Bindra Stadium', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium', 'MA Chidambaram Stadium',
#        'Dr DY Patil Sports Academy', 'Newlands', "St George's Park",
#        'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
#        'Sharjah Cricket Stadium', 'Dubai International Cricket Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Saurashtra Cricket Association Stadium', 'Green Park',
#        'Holkar Cricket Stadium', 'Arun Jaitley Stadium',
#        'Narendra Modi Stadium', 'Zayed Cricket Stadium',
#        'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium',
#        'Barsapara Cricket Stadium',
#        'Maharaja Yadavindra Singh International Cricket Stadium'],
#       dtype=object)

# %%
# Out:
# 0
